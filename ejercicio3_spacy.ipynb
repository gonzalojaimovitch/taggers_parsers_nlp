# %%
# !pip install -U pip setuptools wheel
# !pip install -U 'spacy[transformers,lookups]'
# !python -m spacy download en_core_web_sm
# !python -m spacy download es_core_news_sm
# Out:
# Collecting pip
#   Using cached pip-23.1.2-py3-none-any.whl (2.1 MB)
# Collecting setuptools
#   Using cached setuptools-67.7.2-py3-none-any.whl (1.1 MB)
# Collecting wheel
#   Using cached wheel-0.40.0-py3-none-any.whl (64 kB)
# Installing collected packages: pip, setuptools, wheel
#   Attempting uninstall: pip
#     Found existing installation: pip 20.2.3
#     Uninstalling pip-20.2.3:
#       Successfully uninstalled pip-20.2.3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 49.2.1
#     Uninstalling setuptools-49.2.1:
#       Successfully uninstalled setuptools-49.2.1
# Successfully installed pip-23.1.2 setuptools-67.7.2 wheel-0.40.0
# Collecting spacy[lookups,transformers]
#   Using cached spacy-3.5.2-cp38-cp38-macosx_10_9_x86_64.whl (6.8 MB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy[lookups,transformers])
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy[lookups,transformers])
#   Using cached spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy[lookups,transformers])
#   Using cached murmurhash-1.0.9-cp38-cp38-macosx_10_9_x86_64.whl (18 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy[lookups,transformers])
#   Using cached cymem-2.0.7-cp38-cp38-macosx_10_9_x86_64.whl (32 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy[lookups,transformers])
#   Using cached preshed-3.0.8-cp38-cp38-macosx_10_9_x86_64.whl (107 kB)
# Collecting thinc<8.2.0,>=8.1.8 (from spacy[lookups,transformers])
#   Using cached thinc-8.1.10-cp38-cp38-macosx_10_9_x86_64.whl (850 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy[lookups,transformers])
#   Using cached wasabi-1.1.1-py3-none-any.whl (27 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy[lookups,transformers])
#   Using cached srsly-2.4.6-cp38-cp38-macosx_10_9_x86_64.whl (490 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy[lookups,transformers])
#   Using cached catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting typer<0.8.0,>=0.3.0 (from spacy[lookups,transformers])
#   Using cached typer-0.7.0-py3-none-any.whl (38 kB)
# Collecting pathy>=0.10.0 (from spacy[lookups,transformers])
#   Using cached pathy-0.10.1-py3-none-any.whl (48 kB)
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy[lookups,transformers])
#   Using cached smart_open-6.3.0-py3-none-any.whl (56 kB)
# Collecting tqdm<5.0.0,>=4.38.0 (from spacy[lookups,transformers])
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Collecting numpy>=1.15.0 (from spacy[lookups,transformers])
#   Using cached numpy-1.24.3-cp38-cp38-macosx_10_9_x86_64.whl (19.8 MB)
# Collecting requests<3.0.0,>=2.13.0 (from spacy[lookups,transformers])
#   Using cached requests-2.30.0-py3-none-any.whl (62 kB)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 (from spacy[lookups,transformers])
#   Using cached pydantic-1.10.7-cp38-cp38-macosx_10_9_x86_64.whl (2.9 MB)
# Collecting jinja2 (from spacy[lookups,transformers])
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Requirement already satisfied: setuptools in ./.env/lib/python3.8/site-packages (from spacy[lookups,transformers]) (67.7.2)
# Collecting packaging>=20.0 (from spacy[lookups,transformers])
#   Using cached packaging-23.1-py3-none-any.whl (48 kB)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy[lookups,transformers])
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting spacy-transformers<1.3.0,>=1.1.2 (from spacy[lookups,transformers])
#   Using cached spacy_transformers-1.2.3-cp38-cp38-macosx_10_9_x86_64.whl (178 kB)
# Collecting spacy-lookups-data<1.1.0,>=1.0.3 (from spacy[lookups,transformers])
#   Using cached spacy_lookups_data-1.0.3-py2.py3-none-any.whl (98.5 MB)
# Collecting typing-extensions>=4.2.0 (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy[lookups,transformers])
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3.0.0,>=2.13.0->spacy[lookups,transformers])
#   Using cached charset_normalizer-3.1.0-cp38-cp38-macosx_10_9_x86_64.whl (123 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.13.0->spacy[lookups,transformers])
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy[lookups,transformers])
#   Downloading urllib3-2.0.2-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.2/123.2 kB 2.1 MB/s eta 0:00:0000:01
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.13.0->spacy[lookups,transformers])
#   Downloading certifi-2023.5.7-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.0/157.0 kB 5.4 MB/s eta 0:00:00
# Collecting transformers<4.29.0,>=3.4.0 (from spacy-transformers<1.3.0,>=1.1.2->spacy[lookups,transformers])
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 10.1 MB/s eta 0:00:0000:0100:01
# Collecting torch>=1.8.0 (from spacy-transformers<1.3.0,>=1.1.2->spacy[lookups,transformers])
#   Using cached torch-2.0.1-cp38-none-macosx_10_9_x86_64.whl (143.1 MB)
# Collecting spacy-alignments<1.0.0,>=0.7.2 (from spacy-transformers<1.3.0,>=1.1.2->spacy[lookups,transformers])
#   Using cached spacy_alignments-0.9.0-cp38-cp38-macosx_10_9_x86_64.whl (319 kB)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.2.0,>=8.1.8->spacy[lookups,transformers])
#   Using cached blis-0.7.9-cp38-cp38-macosx_10_9_x86_64.whl (6.1 MB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.2.0,>=8.1.8->spacy[lookups,transformers])
#   Using cached confection-0.0.4-py3-none-any.whl (32 kB)
# Collecting click<9.0.0,>=7.1.1 (from typer<0.8.0,>=0.3.0->spacy[lookups,transformers])
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->spacy[lookups,transformers])
#   Using cached MarkupSafe-2.1.2-cp38-cp38-macosx_10_9_x86_64.whl (13 kB)
# Collecting filelock (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.1.2->spacy[lookups,transformers])
#   Using cached filelock-3.12.0-py3-none-any.whl (10 kB)
# Collecting sympy (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.1.2->spacy[lookups,transformers])
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 10.7 MB/s eta 0:00:0000:0100:01
# Collecting networkx (from torch>=1.8.0->spacy-transformers<1.3.0,>=1.1.2->spacy[lookups,transformers])
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Collecting huggingface-hub<1.0,>=0.11.0 (from transformers<4.29.0,>=3.4.0->spacy-transformers<1.3.0,>=1.1.2->spacy[lookups,transformers])
#   Using cached huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
# Collecting pyyaml>=5.1 (from transformers<4.29.0,>=3.4.0->spacy-transformers<1.3.0,>=1.1.2->spacy[lookups,transformers])
#   Using cached PyYAML-6.0-cp38-cp38-macosx_10_9_x86_64.whl (192 kB)
# Collecting regex!=2019.12.17 (from transformers<4.29.0,>=3.4.0->spacy-transformers<1.3.0,>=1.1.2->spacy[lookups,transformers])
#   Using cached regex-2023.5.5-cp38-cp38-macosx_10_9_x86_64.whl (294 kB)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<4.29.0,>=3.4.0->spacy-transformers<1.3.0,>=1.1.2->spacy[lookups,transformers])
#   Using cached tokenizers-0.13.3-cp38-cp38-macosx_10_11_x86_64.whl (4.0 MB)
# Collecting fsspec (from huggingface-hub<1.0,>=0.11.0->transformers<4.29.0,>=3.4.0->spacy-transformers<1.3.0,>=1.1.2->spacy[lookups,transformers])
#   Downloading fsspec-2023.5.0-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 4.5 MB/s eta 0:00:00
# Collecting mpmath>=0.19 (from sympy->torch>=1.8.0->spacy-transformers<1.3.0,>=1.1.2->spacy[lookups,transformers])
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: tokenizers, mpmath, cymem, wasabi, urllib3, typing-extensions, tqdm, sympy, spacy-lookups-data, spacy-loggers, spacy-legacy, spacy-alignments, smart-open, regex, pyyaml, packaging, numpy, networkx, murmurhash, MarkupSafe, langcodes, idna, fsspec, filelock, click, charset-normalizer, certifi, catalogue, typer, srsly, requests, pydantic, preshed, jinja2, blis, torch, pathy, huggingface-hub, confection, transformers, thinc, spacy, spacy-transformers
# Successfully installed MarkupSafe-2.1.2 blis-0.7.9 catalogue-2.0.8 certifi-2023.5.7 charset-normalizer-3.1.0 click-8.1.3 confection-0.0.4 cymem-2.0.7 filelock-3.12.0 fsspec-2023.5.0 huggingface-hub-0.14.1 idna-3.4 jinja2-3.1.2 langcodes-3.3.0 mpmath-1.3.0 murmurhash-1.0.9 networkx-3.1 numpy-1.24.3 packaging-23.1 pathy-0.10.1 preshed-3.0.8 pydantic-1.10.7 pyyaml-6.0 regex-2023.5.5 requests-2.30.0 smart-open-6.3.0 spacy-3.5.2 spacy-alignments-0.9.0 spacy-legacy-3.0.12 spacy-loggers-1.0.4 spacy-lookups-data-1.0.3 spacy-transformers-1.2.3 srsly-2.4.6 sympy-1.12 thinc-8.1.10 tokenizers-0.13.3 torch-2.0.1 tqdm-4.65.0 transformers-4.28.1 typer-0.7.0 typing-extensions-4.5.0 urllib3-2.0.2 wasabi-1.1.1
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 10.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in ./.env/lib/python3.8/site-packages (from en-core-web-sm==3.5.0) (3.5.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.30.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.7)
# Requirement already satisfied: jinja2 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./.env/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.env/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.env/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.env/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.env/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./.env/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./.env/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./.env/lib/python3.8/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.env/lib/python3.8/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.2)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Collecting es-core-news-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.5.0/es_core_news_sm-3.5.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 10.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in ./.env/lib/python3.8/site-packages (from es-core-news-sm==3.5.0) (3.5.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (2.30.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (1.10.7)
# Requirement already satisfied: jinja2 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./.env/lib/python3.8/site-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./.env/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.env/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.env/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.env/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.env/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./.env/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./.env/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./.env/lib/python3.8/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.env/lib/python3.8/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (2.1.2)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')

# %% [markdown]
# # Librerías

# %%
import spacy

# %%
# %cd parser_ud_en
import time
start = time.time()

# !spacy project assets
# !spacy project run all

end = time.time()
print(end - start)
# %cd ..
# Out:
# /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/parser_ud_en_copy
# ℹ Fetching 1 asset(s)
# ✔ Downloaded asset
# /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/parser_ud_en_copy/assets/UD_English-EWT
# ℹ Running workflow 'all'
#
# ================================= preprocess =================================
# Running command: mkdir -p corpus/UD_English-EWT
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 -m spacy convert assets/UD_English-EWT/en_ewt-ud-train.conllu corpus/UD_English-EWT/ --converter conllu --n-sents 10 --merge-subtokens
# ℹ Grouping every 10 sentences into a document.
# ✔ Generated output file (1255 documents):
# corpus/UD_English-EWT/en_ewt-ud-train.spacy
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 -m spacy convert assets/UD_English-EWT/en_ewt-ud-dev.conllu corpus/UD_English-EWT/ --converter conllu --n-sents 10 --merge-subtokens
# ℹ Grouping every 10 sentences into a document.
# ✔ Generated output file (201 documents):
# corpus/UD_English-EWT/en_ewt-ud-dev.spacy
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 -m spacy convert assets/UD_English-EWT/en_ewt-ud-test.conllu corpus/UD_English-EWT/ --converter conllu --n-sents 10 --merge-subtokens
# ℹ Grouping every 10 sentences into a document.
# ✔ Generated output file (208 documents):
# corpus/UD_English-EWT/en_ewt-ud-test.spacy
# Running command: mv corpus/UD_English-EWT/en_ewt-ud-train.spacy corpus/UD_English-EWT/train.spacy
# Running command: mv corpus/UD_English-EWT/en_ewt-ud-dev.spacy corpus/UD_English-EWT/dev.spacy
# Running command: mv corpus/UD_English-EWT/en_ewt-ud-test.spacy corpus/UD_English-EWT/test.spacy
#
# =================================== train ===================================
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 -m spacy train configs/default.cfg --output training/UD_English-EWT --gpu-id -1 --paths.train corpus/UD_English-EWT/train.spacy --paths.dev corpus/UD_English-EWT/dev.spacy --nlp.lang=en
# ✔ Created output directory: training/UD_English-EWT
# ℹ Saving to output directory: training/UD_English-EWT
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# [2023-05-20 17:48:13,745] [INFO] Set up nlp object from config
# [2023-05-20 17:48:13,762] [INFO] Pipeline: ['tok2vec', 'tagger', 'morphologizer', 'trainable_lemmatizer', 'parser']
# [2023-05-20 17:48:13,768] [INFO] Created vocabulary
# [2023-05-20 17:48:13,770] [INFO] Finished initializing nlp object
# [2023-05-20 17:48:33,446] [INFO] Initialized pipeline components: ['tok2vec', 'tagger', 'morphologizer', 'trainable_lemmatizer', 'parser']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'tagger', 'morphologizer',
# 'trainable_lemmatizer', 'parser']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS TAGGER  LOSS MORPH...  LOSS TRAIN...  LOSS PARSER  TAG_ACC  POS_ACC  MORPH_ACC  LEMMA_ACC  DEP_UAS  DEP_LAS  SENTS_F  SCORE
# ---  ------  ------------  -----------  -------------  -------------  -----------  -------  -------  ---------  ---------  -------  -------  -------  ------
#   0       0          0.00       148.31         149.54         149.73       297.31    20.97    22.76      24.15      77.20    19.65     5.67     0.98    0.29
#   0     200       3958.68     17669.49       19037.26        9743.24     30734.00    81.83    83.88      82.44      87.07    62.40    51.62    49.57    0.76
#   0     400       6089.49      7200.29        8703.03        4301.44     21752.61    86.64    87.98      88.08      88.80    67.82    58.02    54.40    0.81
#   0     600       6510.62      5503.53        6802.37        3382.83     19509.80    88.55    89.91      89.53      89.82    72.44    64.83    65.37    0.84
#   0     800       7025.12      5086.50        6212.66        3241.96     18112.83    89.24    90.25      90.81      90.59    73.65    67.01    64.97    0.85
#   0    1000       7469.10      4577.75        5583.79        2913.81     18049.02    89.80    90.84      91.29      91.04    74.29    67.35    64.90    0.86
#   0    1200       8419.12      4712.79        6013.20        2959.29     18321.57    90.31    91.65      91.62      91.18    75.52    69.13    68.31    0.87
#   1    1400       7881.35      3745.02        4695.00        2439.70     17015.63    91.07    92.09      92.25      91.56    76.10    69.82    68.13    0.87
#   1    1600       9848.72      4218.34        5496.27        2636.78     20118.05    91.25    92.33      92.52      91.93    77.55    71.66    67.76    0.88
#   1    1800      12479.36      5199.06        6733.84        3020.48     23580.35    91.67    92.71      92.85      92.10    78.17    72.38    68.74    0.88
#   1    2000      16217.37      6754.50        8667.21        3732.31     30495.36    91.78    93.04      93.24      92.53    78.74    73.73    70.71    0.89
#   2    2200      18612.58      6463.80        8609.82        3630.47     34269.48    91.95    93.10      93.12      92.46    80.01    74.98    68.65    0.89
#   2    2400      24706.89      8041.14       10701.92        4371.51     42515.61    92.27    93.38      93.44      92.89    79.91    75.24    71.13    0.90
#   3    2600      28602.25      8216.77       11204.63        4250.93     47306.02    92.52    93.52      93.72      93.09    81.46    76.87    71.77    0.90
#   4    2800      34706.47      9031.94       12842.43        4560.47     55204.70    92.46    93.49      93.60      93.00    81.74    77.24    72.84    0.90
#   5    3000      36361.86      8595.59       12086.36        4021.04     54460.68    92.55    93.66      93.71      93.06    81.58    77.01    71.68    0.90
#   6    3200      36439.42      7895.56       11330.60        3630.76     52306.21    92.43    93.24      93.70      93.18    81.47    77.13    72.35    0.90
#   7    3400      37258.98      7460.57       10811.16        3350.20     49944.02    92.76    93.70      93.89      93.22    81.94    77.61    72.37    0.91
#   7    3600      37153.61      6770.37       10019.48        2924.47     47976.21    92.80    93.82      93.84      93.31    82.67    78.40    73.97    0.91
#   8    3800      36409.50      6234.47        9440.73        2618.29     45290.76    92.73    93.66      93.78      93.33    82.32    77.93    73.98    0.91
#   9    4000      37102.11      5951.41        8713.78        2495.65     44040.88    92.73    93.82      93.80      93.26    82.39    78.39    72.98    0.91
#  10    4200      37273.92      5493.27        8432.88        2318.77     42976.49    92.67    93.59      93.71      93.26    81.85    77.70    73.56    0.91
#  11    4400      38740.79      5268.55        8022.82        2219.83     42880.63    92.71    93.68      93.78      93.34    82.58    78.46    74.22    0.91
#  12    4600      39183.79      5260.55        8209.51        2158.39     41909.50    92.73    93.66      93.75      93.27    82.22    78.16    74.08    0.91
#  13    4800      38208.03      4770.01        7373.03        2038.83     39333.25    92.73    93.76      93.76      93.30    82.69    78.51    74.12    0.91
#  14    5000      39719.62      4662.71        7542.82        1963.44     38850.43    92.60    93.43      93.80      93.17    82.62    78.44    73.41    0.91
#  14    5200      39591.38      4577.09        7000.41        1885.73     37539.41    92.79    93.80      93.81      93.27    82.63    78.44    74.92    0.91
# ✔ Saved pipeline to output directory
# training/UD_English-EWT/model-last
#
# ================================== evaluate ==================================
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 scripts/evaluate.py training/UD_English-EWT/model-best assets/UD_English-EWT/ --output metrics/UD_English-EWT.default --gpu-id -1
#
# ================================== package ==================================
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 -m spacy package training/UD_English-EWT/model-best packages --name ud_en_ewt --version 0.0.0 --force
# ℹ Building package artifacts: sdist
# ✔ Loaded meta.json from file
# training/UD_English-EWT/model-best/meta.json
# ℹ Using existing README.md from pipeline directory
# ✔ Successfully created package directory 'en_ud_en_ewt-0.0.0'
# packages/en_ud_en_ewt-0.0.0
# running sdist
# running egg_info
# writing en_ud_en_ewt.egg-info/PKG-INFO
# writing dependency_links to en_ud_en_ewt.egg-info/dependency_links.txt
# writing entry points to en_ud_en_ewt.egg-info/entry_points.txt
# writing requirements to en_ud_en_ewt.egg-info/requires.txt
# writing top-level names to en_ud_en_ewt.egg-info/top_level.txt
# reading manifest file 'en_ud_en_ewt.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'LICENSE'
# warning: no files found matching 'LICENSES_SOURCES'
# writing manifest file 'en_ud_en_ewt.egg-info/SOURCES.txt'
# running check
# creating en_ud_en_ewt-0.0.0
# creating en_ud_en_ewt-0.0.0/en_ud_en_ewt
# creating en_ud_en_ewt-0.0.0/en_ud_en_ewt.egg-info
# creating en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0
# creating en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/morphologizer
# creating en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/parser
# creating en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/tagger
# creating en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/tok2vec
# creating en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/trainable_lemmatizer
# creating en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/vocab
# copying files to en_ud_en_ewt-0.0.0...
# copying MANIFEST.in -> en_ud_en_ewt-0.0.0
# copying README.md -> en_ud_en_ewt-0.0.0
# copying meta.json -> en_ud_en_ewt-0.0.0
# copying setup.py -> en_ud_en_ewt-0.0.0
# copying en_ud_en_ewt/__init__.py -> en_ud_en_ewt-0.0.0/en_ud_en_ewt
# copying en_ud_en_ewt/meta.json -> en_ud_en_ewt-0.0.0/en_ud_en_ewt
# copying en_ud_en_ewt.egg-info/PKG-INFO -> en_ud_en_ewt-0.0.0/en_ud_en_ewt.egg-info
# copying en_ud_en_ewt.egg-info/SOURCES.txt -> en_ud_en_ewt-0.0.0/en_ud_en_ewt.egg-info
# copying en_ud_en_ewt.egg-info/dependency_links.txt -> en_ud_en_ewt-0.0.0/en_ud_en_ewt.egg-info
# copying en_ud_en_ewt.egg-info/entry_points.txt -> en_ud_en_ewt-0.0.0/en_ud_en_ewt.egg-info
# copying en_ud_en_ewt.egg-info/not-zip-safe -> en_ud_en_ewt-0.0.0/en_ud_en_ewt.egg-info
# copying en_ud_en_ewt.egg-info/requires.txt -> en_ud_en_ewt-0.0.0/en_ud_en_ewt.egg-info
# copying en_ud_en_ewt.egg-info/top_level.txt -> en_ud_en_ewt-0.0.0/en_ud_en_ewt.egg-info
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/config.cfg -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/meta.json -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/tokenizer -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/morphologizer/cfg -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/morphologizer
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/morphologizer/model -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/morphologizer
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/parser/cfg -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/parser
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/parser/model -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/parser
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/parser/moves -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/parser
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/tagger/cfg -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/tagger
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/tagger/model -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/tagger
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/tok2vec/cfg -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/tok2vec
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/tok2vec/model -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/tok2vec
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/trainable_lemmatizer/cfg -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/trainable_lemmatizer
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/trainable_lemmatizer/model -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/trainable_lemmatizer
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/trainable_lemmatizer/trees -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/trainable_lemmatizer
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/vocab/key2row -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/vocab
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/vocab/lookups.bin -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/vocab
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/vocab/strings.json -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/vocab
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/vocab/vectors -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/vocab
# copying en_ud_en_ewt/en_ud_en_ewt-0.0.0/vocab/vectors.cfg -> en_ud_en_ewt-0.0.0/en_ud_en_ewt/en_ud_en_ewt-0.0.0/vocab
# Writing en_ud_en_ewt-0.0.0/setup.cfg
# Creating tar archive
# removing 'en_ud_en_ewt-0.0.0' (and everything under it)
# ✔ Successfully created zipped Python package
# packages/en_ud_en_ewt-0.0.0/dist/en_ud_en_ewt-0.0.0.tar.gz
# 1808.2560920715332
# /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser

# %%
# %cd parser_ud_es
import time
start = time.time()

# !spacy project assets
# !spacy project run all

end = time.time()
print(end - start)
# %cd ..
# Out:
# /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/parser_ud_es_copy
# ℹ Fetching 1 asset(s)
# ✔ Downloaded asset
# /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/parser_ud_es_copy/assets/UD_Spanish-GSD
# ℹ Running workflow 'all'
#
# ================================= preprocess =================================
# Running command: mkdir -p corpus/UD_Spanish-GSD
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 -m spacy convert assets/UD_Spanish-GSD/es_gsd-ud-train.conllu corpus/UD_Spanish-GSD/ --converter conllu --n-sents 10 --merge-subtokens
# ℹ Grouping every 10 sentences into a document.
# ✔ Generated output file (1419 documents):
# corpus/UD_Spanish-GSD/es_gsd-ud-train.spacy
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 -m spacy convert assets/UD_Spanish-GSD/es_gsd-ud-dev.conllu corpus/UD_Spanish-GSD/ --converter conllu --n-sents 10 --merge-subtokens
# ℹ Grouping every 10 sentences into a document.
# ✔ Generated output file (140 documents):
# corpus/UD_Spanish-GSD/es_gsd-ud-dev.spacy
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 -m spacy convert assets/UD_Spanish-GSD/es_gsd-ud-test.conllu corpus/UD_Spanish-GSD/ --converter conllu --n-sents 10 --merge-subtokens
# ℹ Grouping every 10 sentences into a document.
# ✔ Generated output file (43 documents):
# corpus/UD_Spanish-GSD/es_gsd-ud-test.spacy
# Running command: mv corpus/UD_Spanish-GSD/es_gsd-ud-train.spacy corpus/UD_Spanish-GSD/train.spacy
# Running command: mv corpus/UD_Spanish-GSD/es_gsd-ud-dev.spacy corpus/UD_Spanish-GSD/dev.spacy
# Running command: mv corpus/UD_Spanish-GSD/es_gsd-ud-test.spacy corpus/UD_Spanish-GSD/test.spacy
#
# =================================== train ===================================
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 -m spacy train configs/default.cfg --output training/UD_Spanish-GSD --gpu-id -1 --paths.train corpus/UD_Spanish-GSD/train.spacy --paths.dev corpus/UD_Spanish-GSD/dev.spacy --nlp.lang=es
# ✔ Created output directory: training/UD_Spanish-GSD
# ℹ Saving to output directory: training/UD_Spanish-GSD
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# [2023-05-20 18:20:01,531] [INFO] Set up nlp object from config
# [2023-05-20 18:20:01,543] [INFO] Pipeline: ['tok2vec', 'tagger', 'morphologizer', 'trainable_lemmatizer', 'parser']
# [2023-05-20 18:20:01,549] [INFO] Created vocabulary
# [2023-05-20 18:20:01,550] [INFO] Finished initializing nlp object
# [2023-05-20 18:20:28,708] [INFO] Initialized pipeline components: ['tok2vec', 'tagger', 'morphologizer', 'trainable_lemmatizer', 'parser']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'tagger', 'morphologizer',
# 'trainable_lemmatizer', 'parser']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS TAGGER  LOSS MORPH...  LOSS TRAIN...  LOSS PARSER  TAG_ACC  POS_ACC  MORPH_ACC  LEMMA_ACC  DEP_UAS  DEP_LAS  SENTS_F  SCORE
# ---  ------  ------------  -----------  -------------  -------------  -----------  -------  -------  ---------  ---------  -------  -------  -------  ------
#   0       0          0.00       295.24         309.49         309.65       640.17    40.88    37.09      32.64      63.90    13.25     5.95     0.00    0.33
#   0     200       5369.28     15787.18       23120.61       19173.09     41801.87    91.52    91.17      86.55      89.47    74.51    66.67    68.76    0.85
#   0     400       7738.07      6820.64       11614.76        7474.78     28145.11    93.65    93.27      92.23      93.50    80.18    73.57    89.18    0.89
#   0     600       7969.00      5558.58        8835.29        5255.74     24413.44    94.23    94.01      93.79      94.78    82.34    76.13    94.09    0.91
#   0     800       8212.78      5109.08        7948.04        4505.33     23265.35    94.46    94.40      94.43      95.54    83.17    77.24    95.05    0.92
#   0    1000       8259.75      4768.34        7252.00        3831.68     21966.00    94.71    94.72      94.86      95.80    83.93    77.90    96.03    0.92
#   0    1200       8486.47      4462.19        6857.12        3635.84     21332.42    94.92    94.88      95.15      96.17    84.27    78.81    96.28    0.93
#   0    1400       8493.21      4239.22        6508.96        3294.36     20142.54    95.15    94.99      95.22      96.36    85.32    80.07    95.72    0.93
#   1    1600       8439.02      3803.60        5929.81        2785.36     18742.60    95.12    95.18      95.32      96.66    84.95    79.63    96.55    0.93
#   1    1800       8889.85      3892.35        5988.83        2629.22     19078.21    95.16    95.18      95.65      96.67    85.76    80.54    96.38    0.93
#   1    2000       9105.12      3646.35        5689.61        2576.25     18426.80    95.34    95.25      95.64      96.71    85.41    80.09    97.36    0.93
#   1    2200       9260.57      3750.32        5653.11        2451.51     17858.96    95.29    95.36      95.61      96.76    85.92    80.96    96.70    0.93
#   1    2400       9621.36      3730.33        5713.51        2501.13     18102.18    95.37    95.41      95.78      96.94    86.43    81.36    97.36    0.94
#   1    2600       9614.81      3743.69        5688.90        2424.14     18059.78    95.51    95.49      95.72      97.02    86.55    81.60    97.24    0.94
#   1    2800       9593.57      3811.40        5844.08        2310.03     18012.01    95.57    95.57      95.83      97.04    86.43    81.61    97.06    0.94
#   8   12400      20956.84      2252.88        3612.68         998.70     12811.87    96.01    95.92      96.35      97.70    88.56    84.41    97.10    0.95
#   8   12600      19291.23      2074.53        3490.64         898.46     12147.08    95.90    95.89      96.34      97.73    88.26    84.11    97.07    0.95
#   9   12800      19742.24      2067.91        3415.56         882.49     12217.35    96.00    96.01      96.51      97.70    88.66    84.43    97.46    0.95
#   9   13000      19166.67      1745.36        2975.03         814.47     11513.60    95.96    95.91      96.41      97.65    88.53    84.26    97.60    0.95
#   9   13200      19571.28      1828.77        3038.12         781.17     11653.78    95.98    95.93      96.37      97.71    88.53    84.25    97.24    0.95
#   9   13400      20004.62      1805.79        3084.74         758.86     11866.18    95.92    96.01      96.46      97.70    88.95    84.85    98.14    0.95
#   9   13600      20561.55      1920.68        3152.68         823.50     11751.27    95.76    95.94      96.36      97.62    88.51    84.22    97.57    0.95
#   9   13800      21720.01      1962.52        3312.35         880.47     12309.14    95.94    95.91      96.39      97.76    88.18    84.14    97.60    0.95
#   9   14000      22084.65      2006.26        3275.71         882.36     12407.09    95.89    95.85      96.44      97.65    88.47    84.24    97.39    0.95
#  10   14200      22308.70      2059.96        3319.11         937.28     12279.70    96.00    95.99      96.44      97.68    88.71    84.58    97.46    0.95
#  10   14400      20842.26      1713.86        2849.51         672.48     11316.60    95.95    95.96      96.36      97.68    88.45    84.31    97.42    0.95
#  10   14600      20863.77      1641.15        2799.55         719.02     11291.21    95.99    95.99      96.44      97.67    88.09    83.91    97.46    0.95
#  10   14800      22612.79      1915.71        3146.73         788.36     11665.47    95.96    95.93      96.38      97.73    88.73    84.54    97.53    0.95
#  10   15000      21872.09      1769.66        2981.54         781.52     11162.29    95.88    95.94      96.46      97.68    88.51    84.38    97.57    0.95
# ✔ Saved pipeline to output directory
# training/UD_Spanish-GSD/model-last
#
# ================================== evaluate ==================================
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 scripts/evaluate.py training/UD_Spanish-GSD/model-best assets/UD_Spanish-GSD/ --output metrics/UD_Spanish-GSD.default --gpu-id -1
#
# ================================== package ==================================
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 -m spacy package training/UD_Spanish-GSD/model-best packages --name ud_es_gsd --version 0.0.0 --force
# ℹ Building package artifacts: sdist
# ✔ Loaded meta.json from file
# training/UD_Spanish-GSD/model-best/meta.json
# ℹ Using existing README.md from pipeline directory
# ✔ Successfully created package directory 'es_ud_es_gsd-0.0.0'
# packages/es_ud_es_gsd-0.0.0
# running sdist
# running egg_info
# writing es_ud_es_gsd.egg-info/PKG-INFO
# writing dependency_links to es_ud_es_gsd.egg-info/dependency_links.txt
# writing entry points to es_ud_es_gsd.egg-info/entry_points.txt
# writing requirements to es_ud_es_gsd.egg-info/requires.txt
# writing top-level names to es_ud_es_gsd.egg-info/top_level.txt
# reading manifest file 'es_ud_es_gsd.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'LICENSE'
# warning: no files found matching 'LICENSES_SOURCES'
# writing manifest file 'es_ud_es_gsd.egg-info/SOURCES.txt'
# running check
# creating es_ud_es_gsd-0.0.0
# creating es_ud_es_gsd-0.0.0/es_ud_es_gsd
# creating es_ud_es_gsd-0.0.0/es_ud_es_gsd.egg-info
# creating es_ud_es_gsd-0.0.0/es_ud_es_gsd/es_ud_es_gsd-0.0.0
# creating es_ud_es_gsd-0.0.0/es_ud_es_gsd/es_ud_es_gsd-0.0.0/morphologizer
# creating es_ud_es_gsd-0.0.0/es_ud_es_gsd/es_ud_es_gsd-0.0.0/parser
# creating es_ud_es_gsd-0.0.0/es_ud_es_gsd/es_ud_es_gsd-0.0.0/tagger
# creating es_ud_es_gsd-0.0.0/es_ud_es_gsd/es_ud_es_gsd-0.0.0/tok2vec
# creating es_ud_es_gsd-0.0.0/es_ud_es_gsd/es_ud_es_gsd-0.0.0/trainable_lemmatizer
# creating es_ud_es_gsd-0.0.0/es_ud_es_gsd/es_ud_es_gsd-0.0.0/vocab
# copying files to es_ud_es_gsd-0.0.0...
# copying MANIFEST.in -> es_ud_es_gsd-0.0.0
# copying README.md -> es_ud_es_gsd-0.0.0
# copying meta.json -> es_ud_es_gsd-0.0.0
# copying setup.py -> es_ud_es_gsd-0.0.0
# copying es_ud_es_gsd/__init__.py -> es_ud_es_gsd-0.0.0/es_ud_es_gsd
# copying es_ud_es_gsd/meta.json -> es_ud_es_gsd-0.0.0/es_ud_es_gsd
# copying es_ud_es_gsd.egg-info/PKG-INFO -> es_ud_es_gsd-0.0.0/es_ud_es_gsd.egg-info
# copying es_ud_es_gsd.egg-info/SOURCES.txt -> es_ud_es_gsd-0.0.0/es_ud_es_gsd.egg-info
# copying es_ud_es_gsd.egg-info/dependency_links.txt -> es_ud_es_gsd-0.0.0/es_ud_es_gsd.egg-info
# copying es_ud_es_gsd.egg-info/entry_points.txt -> es_ud_es_gsd-0.0.0/es_ud_es_gsd.egg-info
# copying es_ud_es_gsd.egg-info/not-zip-safe -> es_ud_es_gsd-0.0.0/es_ud_es_gsd.egg-info
# copying es_ud_es_gsd.egg-info/requires.txt -> es_ud_es_gsd-0.0.0/es_ud_es_gsd.egg-info
# copying es_ud_es_gsd.egg-info/top_level.txt -> es_ud_es_gsd-0.0.0/es_ud_es_gsd.egg-info
# copying es_ud_es_gsd/es_ud_es_gsd-0.0.0/config.cfg -> es_ud_es_gsd-0.0.0/es_ud_es_gsd/es_ud_es_gsd-0.0.0
# copying es_ud_es_gsd/es_ud_es_gsd-0.0.0/meta.json -> es_ud_es_gsd-0.0.0/es_ud_es_gsd/es_ud_es_gsd-0.0.0
# copying es_ud_es_gsd/es_ud_es_gsd-0.0.0/tokenizer -> es_ud_es_gsd-0.0.0/es_ud_es_gsd/es_ud_es_gsd-0.0.0
# copying es_ud_es_gsd/es_ud_es_gsd-0.0.0/morphologizer/cfg -> es_ud_es_gsd-0.0.0/es_ud_es_gsd/es_ud_es_gsd-0.0.0/morphologizer
# ✔ Successfully created zipped Python package
# packages/es_ud_es_gsd-0.0.0/dist/es_ud_es_gsd-0.0.0.tar.gz
# 8626.434937000275
# /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser

# %%
# %cd parser_ud_tr
import time
start = time.time()

# !spacy project assets
# !spacy project run all

end = time.time()
print(end - start)
# %cd ..
# Out:
# /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/parser_ud_tr_copy
# ℹ Fetching 1 asset(s)
# ✔ Downloaded asset
# /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/parser_ud_tr_copy/assets/UD_Turkish-BOUN
# ℹ Running workflow 'all'
#
# ================================= preprocess =================================
# Running command: mkdir -p corpus/UD_Turkish-BOUN
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 -m spacy convert assets/UD_Turkish-BOUN/tr_boun-ud-train.conllu corpus/UD_Turkish-BOUN/ --converter conllu --n-sents 10 --merge-subtokens
# ℹ Grouping every 10 sentences into a document.
# ✔ Generated output file (781 documents):
# corpus/UD_Turkish-BOUN/tr_boun-ud-train.spacy
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 -m spacy convert assets/UD_Turkish-BOUN/tr_boun-ud-dev.conllu corpus/UD_Turkish-BOUN/ --converter conllu --n-sents 10 --merge-subtokens
# ℹ Grouping every 10 sentences into a document.
# ✔ Generated output file (98 documents):
# corpus/UD_Turkish-BOUN/tr_boun-ud-dev.spacy
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 -m spacy convert assets/UD_Turkish-BOUN/tr_boun-ud-test.conllu corpus/UD_Turkish-BOUN/ --converter conllu --n-sents 10 --merge-subtokens
# ℹ Grouping every 10 sentences into a document.
# ✔ Generated output file (98 documents):
# corpus/UD_Turkish-BOUN/tr_boun-ud-test.spacy
# Running command: mv corpus/UD_Turkish-BOUN/tr_boun-ud-train.spacy corpus/UD_Turkish-BOUN/train.spacy
# Running command: mv corpus/UD_Turkish-BOUN/tr_boun-ud-dev.spacy corpus/UD_Turkish-BOUN/dev.spacy
# Running command: mv corpus/UD_Turkish-BOUN/tr_boun-ud-test.spacy corpus/UD_Turkish-BOUN/test.spacy
#
# =================================== train ===================================
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 -m spacy train configs/default.cfg --output training/UD_Turkish-BOUN --gpu-id -1 --paths.train corpus/UD_Turkish-BOUN/train.spacy --paths.dev corpus/UD_Turkish-BOUN/dev.spacy --nlp.lang=tr
# ✔ Created output directory: training/UD_Turkish-BOUN
# ℹ Saving to output directory: training/UD_Turkish-BOUN
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# [2023-05-20 20:45:34,892] [INFO] Set up nlp object from config
# [2023-05-20 20:45:34,908] [INFO] Pipeline: ['tok2vec', 'tagger', 'morphologizer', 'trainable_lemmatizer', 'parser']
# [2023-05-20 20:45:34,914] [INFO] Created vocabulary
# [2023-05-20 20:45:34,915] [INFO] Finished initializing nlp object
# [2023-05-20 20:45:46,415] [INFO] Initialized pipeline components: ['tok2vec', 'tagger', 'morphologizer', 'trainable_lemmatizer', 'parser']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'tagger', 'morphologizer',
# 'trainable_lemmatizer', 'parser']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS TAGGER  LOSS MORPH...  LOSS TRAIN...  LOSS PARSER  TAG_ACC  POS_ACC  MORPH_ACC  LEMMA_ACC  DEP_UAS  DEP_LAS  SENTS_F  SCORE
# ---  ------  ------------  -----------  -------------  -------------  -----------  -------  -------  ---------  ---------  -------  -------  -------  ------
#   0       0          0.00       130.35         130.94         130.93       259.78    26.56    28.77      16.41      50.25     9.53     8.67     0.03    0.24
#   0     200       3236.82     14691.04       18020.50       15082.19     22605.99    69.06    74.00      56.72      55.70    48.86    30.35    63.40    0.57
#   0     400       6584.84      9195.73       13675.12       12316.36     20236.82    75.31    82.23      67.02      64.41    56.22    40.06    72.24    0.65
#   0     600       7734.90      7789.26       11738.77       10647.62     19392.98    76.57    83.55      70.48      67.16    58.17    44.23    74.07    0.68
#   1     800       9280.10      7846.74       11917.92       10589.36     19954.74    78.15    84.97      72.07      70.85    59.91    46.84    75.49    0.70
#   1    1000      11701.87      8549.71       13269.73       11632.04     23519.76    78.87    86.07      73.21      73.03    62.90    49.93    79.18    0.72
#   1    1200      16648.83     11458.80       17691.53       14623.53     32094.03    79.15    86.71      74.66      75.54    64.69    52.74    73.21    0.74
#   2    1400      20388.67     12541.65       19843.38       15551.00     38086.24    79.56    87.29      74.76      76.88    65.12    52.96    79.52    0.74
#   3    1600      25760.91     14708.71       23184.55       17198.57     48104.29    79.59    87.63      75.06      77.75    66.01    54.34    80.38    0.75
#   4    1800      30986.62     16703.61       26264.25       18329.91     55209.45    79.71    87.49      75.01      78.47    66.54    55.27    80.55    0.75
#   5    2000      38195.71     18897.81       29079.57       18952.86     67283.11    79.97    87.97      75.20      79.14    67.44    55.90    81.43    0.76
#   7    2200      45314.72     21274.77       31291.23       19185.09     77854.14    79.88    87.62      75.45      79.43    67.75    56.12    82.38    0.76
#   8    2400      52031.62     22515.20       31817.44       18164.49     88589.69    79.52    87.69      74.95      79.54    68.00    56.98    81.77    0.76
#  10    2600      53195.99     21427.68       28935.41       15802.11     87329.35    79.89    87.84      75.49      79.71    68.38    57.08    82.15    0.76
#  12    2800      52662.60     19656.59       25784.51       13439.46     83313.67    79.46    87.80      75.48      79.57    68.76    57.25    81.43    0.76
#  14    3000      52266.20     18351.80       23579.37       11769.26     79430.08    79.67    87.66      75.05      79.70    68.30    56.99    82.80    0.76
#  16    3200      51920.06     16725.55       21243.28       10547.37     76678.93    79.76    87.79      74.75      79.69    67.96    56.82    78.37    0.76
#  18    3400      52015.91     16075.00       20187.08        9941.45     72909.75    79.57    87.82      75.18      79.81    68.05    56.64    83.07    0.76
#  20    3600      51624.63     14873.27       18462.71        9280.20     69103.98    79.93    87.92      75.28      79.92    69.18    58.14    82.22    0.77
#  22    3800      52566.48     14060.44       17328.00        8631.31     68254.98    79.63    87.85      75.00      80.00    69.01    57.75    83.03    0.76
#  24    4000      52188.37     13362.25       16310.85        8250.88     65181.95    79.54    87.55      74.88      79.83    68.16    56.85    81.77    0.76
#  26    4200      52095.42     12629.00       15597.77        7837.10     62462.74    79.59    87.72      74.82      80.00    68.62    57.35    82.67    0.76
#  27    4400      51967.61     12041.46       14795.74        7461.82     61269.61    79.61    87.62      74.90      79.74    68.82    57.43    81.26    0.76
#  29    4600      51768.58     11340.60       13946.85        6979.42     58970.12    79.24    87.74      74.76      79.88    68.20    57.32    81.44    0.76
#  31    4800      52299.67     10843.92       13502.30        6850.51     57892.85    79.33    87.75      74.69      79.84    69.17    57.66    81.85    0.76
#  33    5000      52572.35     10467.68       12697.26        6643.76     56334.92    79.44    87.72      74.90      79.79    67.32    56.31    81.63    0.76
#  35    5200      52560.34     10147.98       12373.36        6388.97     55222.69    79.51    87.56      74.60      79.82    67.82    56.60    82.72    0.76
# ✔ Saved pipeline to output directory
# training/UD_Turkish-BOUN/model-last
#
# ================================== evaluate ==================================
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 scripts/evaluate.py training/UD_Turkish-BOUN/model-best assets/UD_Turkish-BOUN/ --output metrics/UD_Turkish-BOUN.default --gpu-id -1
#
# ================================== package ==================================
# Running command: /Users/gonzalojaimovitch/Desktop/projects/master/dependency_parser/.env/bin/python3 -m spacy package training/UD_Turkish-BOUN/model-best packages --name ud_tr_boun --version 0.0.0 --force
# ℹ Building package artifacts: sdist
# ✔ Loaded meta.json from file
# training/UD_Turkish-BOUN/model-best/meta.json
# ℹ Using existing README.md from pipeline directory
# ✔ Successfully created package directory 'tr_ud_tr_boun-0.0.0'
# packages/tr_ud_tr_boun-0.0.0
# running sdist
# running egg_info
# writing tr_ud_tr_boun.egg-info/PKG-INFO
# writing dependency_links to tr_ud_tr_boun.egg-info/dependency_links.txt
# writing entry points to tr_ud_tr_boun.egg-info/entry_points.txt
# writing requirements to tr_ud_tr_boun.egg-info/requires.txt
# writing top-level names to tr_ud_tr_boun.egg-info/top_level.txt
# reading manifest file 'tr_ud_tr_boun.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'LICENSE'
# warning: no files found matching 'LICENSES_SOURCES'
# writing manifest file 'tr_ud_tr_boun.egg-info/SOURCES.txt'
# running check
# creating tr_ud_tr_boun-0.0.0
# creating tr_ud_tr_boun-0.0.0/tr_ud_tr_boun
# creating tr_ud_tr_boun-0.0.0/tr_ud_tr_boun.egg-info
# creating tr_ud_tr_boun-0.0.0/tr_ud_tr_boun/tr_ud_tr_boun-0.0.0
# creating tr_ud_tr_boun-0.0.0/tr_ud_tr_boun/tr_ud_tr_boun-0.0.0/morphologizer
# creating tr_ud_tr_boun-0.0.0/tr_ud_tr_boun/tr_ud_tr_boun-0.0.0/parser
