# %%
# !pip install stanza
# !pip install transformers
# Out:
# Collecting stanza
#   Using cached stanza-1.5.0-py3-none-any.whl (802 kB)
# Collecting tqdm
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Collecting emoji
#   Using cached emoji-2.2.0.tar.gz (240 kB)
# Collecting protobuf
#   Downloading protobuf-4.23.0-py3-none-any.whl (173 kB)
#      |████████████████████████████████| 173 kB 3.5 MB/s eta 0:00:01
# Collecting requests
#   Using cached requests-2.30.0-py3-none-any.whl (62 kB)
# Collecting six
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting numpy
#   Using cached numpy-1.24.3-cp38-cp38-macosx_10_9_x86_64.whl (19.8 MB)
# Collecting torch>=1.3.0
#   Using cached torch-2.0.1-cp38-none-macosx_10_9_x86_64.whl (143.1 MB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2023.5.7-py3-none-any.whl (156 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.0.2-py3-none-any.whl (123 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.1.0-cp38-cp38-macosx_10_9_x86_64.whl (123 kB)
# Collecting sympy
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting typing-extensions
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting jinja2
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting networkx
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Collecting filelock
#   Using cached filelock-3.12.0-py3-none-any.whl (10 kB)
# Collecting mpmath>=0.19
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.2-cp38-cp38-macosx_10_9_x86_64.whl (13 kB)
# Using legacy 'setup.py install' for emoji, since package 'wheel' is not installed.
# Installing collected packages: tqdm, emoji, protobuf, idna, certifi, urllib3, charset-normalizer, requests, six, numpy, mpmath, sympy, typing-extensions, MarkupSafe, jinja2, networkx, filelock, torch, stanza
#     Running setup.py install for emoji ... done
# Successfully installed MarkupSafe-2.1.2 certifi-2023.5.7 charset-normalizer-3.1.0 emoji-2.2.0 filelock-3.12.0 idna-3.4 jinja2-3.1.2 mpmath-1.3.0 networkx-3.1 numpy-1.24.3 protobuf-4.23.0 requests-2.30.0 six-1.16.0 stanza-1.5.0 sympy-1.12 torch-2.0.1 tqdm-4.65.0 typing-extensions-4.5.0 urllib3-2.0.2
# WARNING: You are using pip version 20.2.3; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/gonzalojaimovitch/Desktop/projects/master/constituency_parser/.env/bin/python3 -m pip install --upgrade pip' command.
# Collecting transformers
#   Downloading transformers-4.29.1-py3-none-any.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 3.1 MB/s eta 0:00:01
# Collecting regex!=2019.12.17
#   Using cached regex-2023.5.5-cp38-cp38-macosx_10_9_x86_64.whl (294 kB)
# Requirement already satisfied: requests in ./.env/lib/python3.8/site-packages (from transformers) (2.30.0)
# Collecting packaging>=20.0
#   Using cached packaging-23.1-py3-none-any.whl (48 kB)
# Collecting huggingface-hub<1.0,>=0.14.1
#   Using cached huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Using cached tokenizers-0.13.3-cp38-cp38-macosx_10_11_x86_64.whl (4.0 MB)
# Requirement already satisfied: numpy>=1.17 in ./.env/lib/python3.8/site-packages (from transformers) (1.24.3)
# Collecting pyyaml>=5.1
#   Using cached PyYAML-6.0-cp38-cp38-macosx_10_9_x86_64.whl (192 kB)
# Requirement already satisfied: tqdm>=4.27 in ./.env/lib/python3.8/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: filelock in ./.env/lib/python3.8/site-packages (from transformers) (3.12.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.env/lib/python3.8/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.env/lib/python3.8/site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.env/lib/python3.8/site-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.env/lib/python3.8/site-packages (from requests->transformers) (2.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.env/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Collecting fsspec
#   Using cached fsspec-2023.5.0-py3-none-any.whl (160 kB)
# Installing collected packages: regex, packaging, pyyaml, fsspec, huggingface-hub, tokenizers, transformers
# Successfully installed fsspec-2023.5.0 huggingface-hub-0.14.1 packaging-23.1 pyyaml-6.0 regex-2023.5.5 tokenizers-0.13.3 transformers-4.29.1
# WARNING: You are using pip version 20.2.3; however, version 23.1.2 is available.
# You should consider upgrading via the '/Users/gonzalojaimovitch/Desktop/projects/master/constituency_parser/.env/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# # Libraries

# %%
import stanza
stanza.download("en")
stanza.download("pt")
stanza.download("tr")
stanza.install_corenlp()

# %%
# %env CONSTITUENCY_BASE=./
# Out:
# env: CONSTITUENCY_BASE=./

# %% [markdown]
# ### English

# %% [markdown]
# #### Data preparation

# %%
def split_treebank(treebank, train_size, dev_size):
    """
    Split a treebank deterministically
    """
    train_end = int(len(treebank) * train_size)
    dev_end = int(len(treebank) * (train_size + dev_size))
    return treebank[:train_end], treebank[train_end:dev_end], treebank[dev_end:]


all_file = ""

for doc in range(1, 199):
    doc_str = f"wsj_{str(doc).zfill(4)}"
    with open(f"./datasets/english/penntreebank/{doc_str}.mrg") as file:
        file_text = file.read()
    all_file = all_file + file_text

all_file = all_file.replace("  ", "")
all_file = all_file.replace("\n", "")
all_file = all_file.replace("(. .) ))", "(. .) ))\n")

all_file = all_file.split("\n")
train, dev, test = split_treebank(all_file, 0.8, 0.1)

import os

os.makedirs(os.path.dirname("./datasets/english/processed/en_wsj_train.mrg"), exist_ok=True)
os.makedirs(os.path.dirname("./datasets/english/processed/en_wsj_dev.mrg"), exist_ok=True)
os.makedirs(os.path.dirname("./datasets/english/processed/en_wsj_test.mrg"), exist_ok=True)

with open("./datasets/english/processed/en_wsj_train.mrg", "w+") as file:
    file.write("\n".join(train))

with open("./datasets/english/processed/en_wsj_dev.mrg", "w+") as file:
    file.write("\n".join(dev))

with open("./datasets/english/processed/en_wsj_test.mrg", "w+") as file:
    file.write("\n".join(test))

# %% [markdown]
# #### Train

# %%
import time
start = time.time()

# !python3 -m stanza.utils.training.run_constituency --train en_wsj --save_dir ./output_stanza_en --epochs 20

end = time.time()
print(end - start)
# Out:
# 2023-04-16 21:39:34 INFO: Training program called with:
# /Users/gonzalojaimovitch/Desktop/projects/constituency_parser/.env/lib/python3.8/site-packages/stanza/utils/training/run_constituency.py --train en_wsj --save_dir ./output_stanza_en --epochs 20
# 2023-04-16 21:39:34 INFO: Save file for en_wsj model: en_wsj_constituency.pt
# 2023-04-16 21:39:34 INFO: en_wsj: ./output_stanza_en/en_wsj_constituency.pt does not exist, training new model
# 2023-04-16 21:39:34 INFO: Using default pretrain for language, found in /Users/gonzalojaimovitch/stanza_resources/en/pretrain/combined.pt  To use a different pretrain, specify --wordvec_pretrain_file
# 2023-04-16 21:39:34 INFO: Using model /Users/gonzalojaimovitch/stanza_resources/en/forward_charlm/1billion.pt for forward charlm
# 2023-04-16 21:39:34 INFO: Using model /Users/gonzalojaimovitch/stanza_resources/en/backward_charlm/1billion.pt for backward charlm
# 2023-04-16 21:39:34 INFO: Running train step with args: ['--train_file', 'data/constituency/en_wsj_train.mrg', '--eval_file', 'data/constituency/en_wsj_dev.mrg', '--shorthand', 'en_wsj', '--mode', 'train', '--wordvec_pretrain_file', '/Users/gonzalojaimovitch/stanza_resources/en/pretrain/combined.pt', '--charlm_forward_file', '/Users/gonzalojaimovitch/stanza_resources/en/forward_charlm/1billion.pt', '--charlm_backward_file', '/Users/gonzalojaimovitch/stanza_resources/en/backward_charlm/1billion.pt', '--bert_model', 'roberta-base', '--epochs', '20', '--save_dir', './output_stanza_en', '--save_name', 'en_wsj_constituency.pt']
# 2023-04-16 21:39:34 WARNING: Multistage training is set.  Best models are with MADGRAD, but it is not installed.  Will use AdamW for the second stage optimizer.  Consider installing MADGRAD
# 2023-04-16 21:39:34 INFO: Running constituency parser in train mode
# 2023-04-16 21:39:34 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json: 200kB [00:00, 35.1MB/s]
# 2023-04-16 21:39:34 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# ========================
#
# 2023-04-16 21:39:34 INFO: Using device: cpu
# 2023-04-16 21:39:34 INFO: Loading: tokenize
# 2023-04-16 21:39:34 INFO: Loading: pos
# 2023-04-16 21:39:35 INFO: Done loading processors!
# 2023-04-16 21:39:35 INFO: ARGS USED AT TRAINING TIME:
# bert_hidden_layers: 4
# bert_model: roberta-base
# charlm_backward_file: /Users/gonzalojaimovitch/stanza_resources/en/backward_charlm/1billion.pt
# charlm_forward_file: /Users/gonzalojaimovitch/stanza_resources/en/forward_charlm/1billion.pt
# checkpoint: True
# checkpoint_save_name: ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# combined_dummy_embedding: True
# constituency_composition: ConstituencyComposition.MAX
# constituent_heads: 8
# constituent_stack: StackHistory.LSTM
# data_dir: data/constituency
# delta_embedding_dim: 100
# device: cpu
# epoch_size: 5000
# epochs: 20
# eval_batch_size: 50
# eval_file: data/constituency/en_wsj_dev.mrg
# finetune: False
# grad_clipping: None
# hidden_size: 512
# lang: en
# lattn_attention_dropout: 0.2
# lattn_combine_as_self: False
# lattn_combined_input: True
# lattn_d_ff: 2048
# lattn_d_input_proj: None
# lattn_d_kv: 64
# lattn_d_l: 32
# lattn_d_proj: 64
# lattn_partitioned: True
# lattn_pwff: True
# lattn_q_as_matrix: False
# lattn_relu_dropout: 0.2
# lattn_resdrop: True
# lattn_residual_dropout: 0.2
# learning_beta2: 0.999
# learning_eps: 1e-08
# learning_momentum: None
# learning_rate: 0.0002
# learning_rate_warmup: 0
# learning_rho: 0.9
# learning_weight_decay: 0.05
# load_name: None
# log_norms: False
# loss: cross
# loss_focal_gamma: 2
# lstm_input_dropout: 0.2
# lstm_layer_dropout: 0.0
# maxout_k: None
# mode: train
# multistage: True
# nonlinearity: relu
# num_generate: 0
# num_lstm_layers: 2
# num_output_layers: 3
# num_tree_lstm_layers: 1
# optim: adamw
# oracle_forced_errors: 0.001
# oracle_frequency: 0.8
# oracle_initial_epoch: 1
# oracle_level: None
# pattn_attention_dropout: 0.2
# pattn_bias: False
# pattn_d_ff: 2048
# pattn_d_kv: 64
# pattn_d_model: 1024
# pattn_encoder_max_len: 512
# pattn_morpho_emb_dropout: 0.2
# pattn_num_heads: 8
# pattn_num_layers: 0
# pattn_relu_dropout: 0.1
# pattn_residual_dropout: 0.2
# pattn_timing: sin
# predict_dir: .
# predict_dropout: 0.2
# predict_file: None
# predict_format: {:_O}
# pretrain_max_vocab: 250000
# rare_word_threshold: 0.02
# rare_word_unknown_frequency: 0.02
# reduce_heads: 8
# reduce_position: 128
# relearn_structure: False
# retag_charlm_backward_file: None
# retag_charlm_forward_file: None
# retag_method: xpos
# retag_model_path: None
# retag_package: default
# retag_pretrain_path: None
# retag_xpos: True
# reversed: False
# save_dir: ./output_stanza_en
# save_each_name: None
# save_name: ./output_stanza_en/en_wsj_constituency.pt
# seed: 1234
# sentence_boundary_vectors: SentenceBoundary.EVERYTHING
# shorthand: en_wsj
# silver_epoch_size: None
# silver_file: None
# silver_remove_duplicates: False
# stage1_learning_rate: 1.0
# tag_embedding_dim: 20
# tag_unknown_frequency: 0.001
# tokenized_file: None
# train_batch_size: 30
# train_file: data/constituency/en_wsj_train.mrg
# transition_embedding_dim: 20
# transition_heads: 4
# transition_hidden_size: 20
# transition_scheme: TransitionScheme.IN_ORDER
# transition_stack: StackHistory.LSTM
# use_lattn: False
# use_silver_words: True
# wandb: False
# wandb_name: None
# wandb_norm_regex: None
# watch_regex: None
# word_dropout: 0.2
# wordvec_dir: extern_data/wordvec
# wordvec_file:
# wordvec_pretrain_file: /Users/gonzalojaimovitch/stanza_resources/en/pretrain/combined.pt
#
# 2023-04-16 21:39:35 INFO: Directory ./output_stanza_en does not exist; creating...
# 2023-04-16 21:39:35 INFO: Reading trees from data/constituency/en_wsj_train.mrg
# 100%|█████████████████████████████████████| 2857/2857 [00:01<00:00, 2331.43it/s]
# 2023-04-16 21:39:37 INFO: Read 3149 trees for the training set
# 2023-04-16 21:39:38 INFO: Filtered 6 duplicates from train dataset
# 2023-04-16 21:39:38 INFO: Reading trees from data/constituency/en_wsj_dev.mrg
# 2023-04-16 21:39:38 INFO: Read 380 trees for the dev set
# 2023-04-16 21:39:38 INFO: Retagging trees using the xpos tags from the default package...
# 100%|███████████████████████████████████████| 3143/3143 [03:18<00:00, 15.85it/s]
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.41it/s]
# 2023-04-16 21:43:21 INFO: Retagging finished
# 2023-04-16 21:43:21 INFO: Unique constituents in training set: ['ADJP', 'ADVP', 'ADVP|PRT', 'CONJP', 'FRAG', 'INTJ', 'LST', 'NAC', 'NP', 'NX', 'PP', 'PRN', 'PRT', 'QP', 'ROOT', 'RRC', 'S', 'SBAR', 'SBARQ', 'SINV', 'SQ', 'UCP', 'VP', 'WHADVP', 'WHNP', 'WHPP', 'X']
# 2023-04-16 21:43:21 INFO: Constituent node counts: Counter({'NP': 25032, 'VP': 11734, 'S': 7684, 'PP': 7476, 'ROOT': 3143, 'SBAR': 2331, 'ADVP': 1528, 'ADJP': 1046, 'WHNP': 609, 'QP': 545, 'PRN': 263, 'PRT': 185, 'SINV': 181, 'WHADVP': 151, 'NX': 118, 'FRAG': 94, 'NAC': 40, 'SQ': 32, 'WHPP': 30, 'UCP': 28, 'SBARQ': 26, 'CONJP': 19, 'LST': 13, 'RRC': 10, 'INTJ': 9, 'X': 6, 'ADVP|PRT': 1})
# 2023-04-16 21:43:21 INFO: Unique tags in training set: ['$', "''", ',', '-LRB-', '-RRB-', '.', ':', 'CC', 'CD', 'DT', 'EX', 'FW', 'HYPH', 'IN', 'JJ', 'JJR', 'JJS', 'LS', 'MD', 'NFP', 'NN', 'NNP', 'NNPS', 'NNS', 'PDT', 'POS', 'PRP', 'PRP$', 'RB', 'RBR', 'RBS', 'RP', 'TO', 'UH', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'WDT', 'WP', 'WP$', 'WRB', '``']
# 2023-04-16 21:43:21 INFO: Building training transition sequences
# 100%|█████████████████████████████████████| 3143/3143 [00:00<00:00, 3927.83it/s]
# 2023-04-16 21:43:22 INFO: Building dev transition sequences
# 100%|███████████████████████████████████████| 380/380 [00:00<00:00, 9482.21it/s]
# 2023-04-16 21:43:22 INFO: Building silver transition sequences
# 0it [00:00, ?it/s]
# 2023-04-16 21:43:22 INFO: Total unique transitions in train set: 29
# 2023-04-16 21:43:22 INFO: Unique transitions in training set: [Shift, CloseConstituent, OpenConstituent(('ADJP',)), OpenConstituent(('ADVP',)), OpenConstituent(('ADVP|PRT',)), OpenConstituent(('CONJP',)), OpenConstituent(('FRAG',)), OpenConstituent(('INTJ',)), OpenConstituent(('LST',)), OpenConstituent(('NAC',)), OpenConstituent(('NP',)), OpenConstituent(('NX',)), OpenConstituent(('PP',)), OpenConstituent(('PRN',)), OpenConstituent(('PRT',)), OpenConstituent(('QP',)), OpenConstituent(('ROOT',)), OpenConstituent(('RRC',)), OpenConstituent(('S',)), OpenConstituent(('SBAR',)), OpenConstituent(('SBARQ',)), OpenConstituent(('SINV',)), OpenConstituent(('SQ',)), OpenConstituent(('UCP',)), OpenConstituent(('VP',)), OpenConstituent(('WHADVP',)), OpenConstituent(('WHNP',)), OpenConstituent(('WHPP',)), OpenConstituent(('X',))]
# 2023-04-16 21:43:22 INFO: Verifying the transition sequences for 3143 trees
# 100%|██████████████████████████████████████| 3143/3143 [00:03<00:00, 806.37it/s]
# 2023-04-16 21:43:26 INFO: Verifying the transition sequences for 380 trees
# 100%|████████████████████████████████████████| 380/380 [00:00<00:00, 941.94it/s]
# 2023-04-16 21:43:27 INFO: Using the following open nodes:
#   ('ADJP',)
#   ('ADVP',)
#   ('ADVP|PRT',)
#   ('CONJP',)
#   ('FRAG',)
#   ('INTJ',)
#   ('LST',)
#   ('NAC',)
#   ('NP',)
#   ('NX',)
#   ('PP',)
#   ('PRN',)
#   ('PRT',)
#   ('QP',)
#   ('ROOT',)
#   ('RRC',)
#   ('S',)
#   ('SBAR',)
#   ('SBARQ',)
#   ('SINV',)
#   ('SQ',)
#   ('UCP',)
#   ('VP',)
#   ('WHADVP',)
#   ('WHNP',)
#   ('WHPP',)
#   ('X',)
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-04-16 21:43:31 INFO: Warming up model for 10 iterations using AdaDelta to train the embeddings
# 2023-04-16 21:43:31 INFO: Building Adadelta with lr=1.000000, eps=0.000001, weight_decay=0.020000, rho=0.900000
# 2023-04-16 21:43:31 INFO: Number of words in the training set found in the embedding: 9635 out of 10629
# 2023-04-16 21:43:31 INFO: Building CrossEntropyLoss(sum)
# 2023-04-16 21:43:32 INFO: Starting epoch 1
# 100%|████████████████████████████████| 167/167 [27:51<00:00, 10.01s/it, Epoch 1]
# 2023-04-16 22:11:23 INFO: Transitions correct: 185429
#   Counter({'Shift': 87974, 'Open': 51539, 'Close': 45916})
# 2023-04-16 22:11:23 INFO: Transitions incorrect: 108939
#   Counter({('Open', 'Shift'): 24601, ('Open', 'Close'): 18722, ('Open', 'Open'): 16418, ('Close', 'Shift'): 14915, ('Shift', 'Close'): 14790, ('Shift', 'Open'): 11414, ('Close', 'Open'): 8079})
# 2023-04-16 22:11:23 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 31525, <RepairType.OPEN_SHIFT: 6>: 17597, <RepairType.SHIFT_CLOSE: 8>: 15077, <RepairType.WRONG_OPEN_GENERAL: 4>: 13993, <RepairType.OPEN_CLOSE: 7>: 8210, <RepairType.MISSED_UNARY: 5>: 3935, <RepairType.CLOSE_SHIFT_NESTED: 9>: 3418, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1263, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 667, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 259})
# 2023-04-16 22:11:23 INFO: Fake transitions used: 43
# 2023-04-16 22:11:23 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:24<00:00,  4.51it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 77.02 LR: 72.54 F1: 74.71 Exact: 4.21 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 77.02 LR: 72.54 F1: 74.71 Exact: 4.21 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-16 22:12:57 INFO: New best dev score: 0.74715 > 0.00000
# 2023-04-16 22:12:57 INFO: Model saved to ./output_stanza_en/en_wsj_constituency.pt
# 2023-04-16 22:12:57 INFO: Epoch 1 finished
#   Transitions correct: Counter({'Shift': 87974, 'Open': 51539, 'Close': 45916})
#   Transitions incorrect: Counter({('Open', 'Shift'): 24601, ('Open', 'Close'): 18722, ('Open', 'Open'): 16418, ('Close', 'Shift'): 14915, ('Shift', 'Close'): 14790, ('Shift', 'Open'): 11414, ('Close', 'Open'): 8079})
#   Total loss for epoch: 461900.81697
#   Dev score      (    1): 0.747148
#   Best dev score (    1): 0.747148
# 2023-04-16 22:12:57 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-16 22:12:57 INFO: Starting epoch 2
# 100%|████████████████████████████████| 167/167 [27:47<00:00,  9.98s/it, Epoch 2]
# 2023-04-16 22:40:44 INFO: Transitions correct: 274677
#   Counter({'Shift': 111659, 'Open': 84426, 'Close': 78592})
# 2023-04-16 22:40:44 INFO: Transitions incorrect: 31986
#   Counter({('Open', 'Close'): 6859, ('Open', 'Open'): 5859, ('Open', 'Shift'): 5291, ('Close', 'Shift'): 4659, ('Shift', 'Close'): 3558, ('Shift', 'Open'): 3019, ('Close', 'Open'): 2741})
# 2023-04-16 22:40:44 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 9750, <RepairType.WRONG_OPEN_GENERAL: 4>: 4990, <RepairType.OPEN_SHIFT: 6>: 4626, <RepairType.SHIFT_CLOSE: 8>: 3676, <RepairType.MISSED_UNARY: 5>: 3399, <RepairType.OPEN_CLOSE: 7>: 3362, <RepairType.CLOSE_SHIFT_NESTED: 9>: 1097, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 604, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 265})
# 2023-04-16 22:40:44 INFO: Fake transitions used: 80
# 2023-04-16 22:40:44 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:33<00:00,  4.08it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 88.87 LR: 86.51 F1: 87.68 Exact: 16.31 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 88.87 LR: 86.51 F1: 87.68 Exact: 16.31 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-16 22:42:28 INFO: New best dev score: 0.87682 > 0.74715
# 2023-04-16 22:42:28 INFO: Model saved to ./output_stanza_en/en_wsj_constituency.pt
# 2023-04-16 22:42:28 INFO: Epoch 2 finished
#   Transitions correct: Counter({'Shift': 111659, 'Open': 84426, 'Close': 78592})
#   Transitions incorrect: Counter({('Open', 'Close'): 6859, ('Open', 'Open'): 5859, ('Open', 'Shift'): 5291, ('Close', 'Shift'): 4659, ('Shift', 'Close'): 3558, ('Shift', 'Open'): 3019, ('Close', 'Open'): 2741})
#   Total loss for epoch: 106945.93544
#   Dev score      (    2): 0.876821
#   Best dev score (    2): 0.876821
# 2023-04-16 22:42:29 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-16 22:42:29 INFO: Starting epoch 3
# 100%|████████████████████████████████| 167/167 [29:22<00:00, 10.56s/it, Epoch 3]
# 2023-04-16 23:11:52 INFO: Transitions correct: 290950
#   Counter({'Shift': 114199, 'Open': 90401, 'Close': 86350})
# 2023-04-16 23:11:52 INFO: Transitions incorrect: 22875
#   Counter({('Open', 'Open'): 4296, ('Open', 'Close'): 3970, ('Open', 'Shift'): 3788, ('Shift', 'Close'): 3381, ('Close', 'Shift'): 3314, ('Shift', 'Open'): 2136, ('Close', 'Open'): 1990})
# 2023-04-16 23:11:52 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 6718, <RepairType.SHIFT_CLOSE: 8>: 3389, <RepairType.OPEN_SHIFT: 6>: 3178, <RepairType.WRONG_OPEN_GENERAL: 4>: 3145, <RepairType.OPEN_CLOSE: 7>: 2360, <RepairType.MISSED_UNARY: 5>: 1541, <RepairType.CLOSE_SHIFT_NESTED: 9>: 720, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 506, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 178, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 149})
# 2023-04-16 23:11:52 INFO: Fake transitions used: 89
# 2023-04-16 23:11:52 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:23<00:00,  4.55it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 86.22 LR: 78.08 F1: 81.95 Exact: 10.52 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 86.22 LR: 78.08 F1: 81.95 Exact: 10.52 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-16 23:13:25 INFO: Epoch 3 finished
#   Transitions correct: Counter({'Shift': 114199, 'Open': 90401, 'Close': 86350})
#   Transitions incorrect: Counter({('Open', 'Open'): 4296, ('Open', 'Close'): 3970, ('Open', 'Shift'): 3788, ('Shift', 'Close'): 3381, ('Close', 'Shift'): 3314, ('Shift', 'Open'): 2136, ('Close', 'Open'): 1990})
#   Total loss for epoch: 78369.38489
#   Dev score      (    3): 0.819521
#   Best dev score (    2): 0.876821
# 2023-04-16 23:13:25 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-16 23:13:25 INFO: Starting epoch 4
# 100%|████████████████████████████████| 167/167 [27:02<00:00,  9.71s/it, Epoch 4]
# 2023-04-16 23:40:27 INFO: Transitions correct: 298571
#   Counter({'Shift': 115815, 'Open': 92714, 'Close': 90042})
# 2023-04-16 23:40:27 INFO: Transitions incorrect: 15540
#   Counter({('Open', 'Open'): 2909, ('Open', 'Shift'): 2839, ('Open', 'Close'): 2595, ('Close', 'Shift'): 2312, ('Shift', 'Close'): 2001, ('Shift', 'Open'): 1544, ('Close', 'Open'): 1340})
# 2023-04-16 23:40:27 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 4918, <RepairType.OPEN_SHIFT: 6>: 2394, <RepairType.WRONG_OPEN_GENERAL: 4>: 2277, <RepairType.SHIFT_CLOSE: 8>: 2036, <RepairType.OPEN_CLOSE: 7>: 1828, <RepairType.MISSED_UNARY: 5>: 895, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 513, <RepairType.CLOSE_SHIFT_NESTED: 9>: 513, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 118})
# 2023-04-16 23:40:27 INFO: Fake transitions used: 84
# 2023-04-16 23:40:27 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:23<00:00,  4.54it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 92.86 LR: 91.91 F1: 92.38 Exact: 34.21 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 92.86 LR: 91.91 F1: 92.38 Exact: 34.21 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-16 23:42:00 INFO: New best dev score: 0.92387 > 0.87682
# 2023-04-16 23:42:00 INFO: Model saved to ./output_stanza_en/en_wsj_constituency.pt
# 2023-04-16 23:42:00 INFO: Epoch 4 finished
#   Transitions correct: Counter({'Shift': 115815, 'Open': 92714, 'Close': 90042})
#   Transitions incorrect: Counter({('Open', 'Open'): 2909, ('Open', 'Shift'): 2839, ('Open', 'Close'): 2595, ('Close', 'Shift'): 2312, ('Shift', 'Close'): 2001, ('Shift', 'Open'): 1544, ('Close', 'Open'): 1340})
#   Total loss for epoch: 51194.00693
#   Dev score      (    4): 0.923875
#   Best dev score (    4): 0.923875
# 2023-04-16 23:42:00 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-16 23:42:00 INFO: Starting epoch 5
# 100%|████████████████████████████████| 167/167 [27:16<00:00,  9.80s/it, Epoch 5]
# 2023-04-17 00:09:17 INFO: Transitions correct: 303409
#   Counter({'Shift': 116940, 'Open': 94227, 'Close': 92242})
# 2023-04-17 00:09:17 INFO: Transitions incorrect: 12475
#   Counter({('Open', 'Open'): 2399, ('Open', 'Shift'): 2319, ('Open', 'Close'): 1989, ('Close', 'Shift'): 1819, ('Shift', 'Close'): 1571, ('Shift', 'Open'): 1358, ('Close', 'Open'): 1020})
# 2023-04-17 00:09:17 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 3909, <RepairType.OPEN_SHIFT: 6>: 1961, <RepairType.WRONG_OPEN_GENERAL: 4>: 1898, <RepairType.SHIFT_CLOSE: 8>: 1604, <RepairType.OPEN_CLOSE: 7>: 1397, <RepairType.MISSED_UNARY: 5>: 741, <RepairType.CLOSE_SHIFT_NESTED: 9>: 435, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 391, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 110})
# 2023-04-17 00:09:17 INFO: Fake transitions used: 98
# 2023-04-17 00:09:17 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:23<00:00,  4.53it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 91.6 LR: 89.44 F1: 90.51 Exact: 31.05 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 91.6 LR: 89.44 F1: 90.51 Exact: 31.05 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 00:10:50 INFO: Epoch 5 finished
#   Transitions correct: Counter({'Shift': 116940, 'Open': 94227, 'Close': 92242})
#   Transitions incorrect: Counter({('Open', 'Open'): 2399, ('Open', 'Shift'): 2319, ('Open', 'Close'): 1989, ('Close', 'Shift'): 1819, ('Shift', 'Close'): 1571, ('Shift', 'Open'): 1358, ('Close', 'Open'): 1020})
#   Total loss for epoch: 41228.20797
#   Dev score      (    5): 0.905130
#   Best dev score (    4): 0.923875
# 2023-04-17 00:10:50 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 00:10:50 INFO: Starting epoch 6
# 100%|████████████████████████████████| 167/167 [27:00<00:00,  9.70s/it, Epoch 6]
# 2023-04-17 00:37:51 INFO: Transitions correct: 304703
#   Counter({'Shift': 117023, 'Open': 94845, 'Close': 92835})
# 2023-04-17 00:37:51 INFO: Transitions incorrect: 11133
#   Counter({('Open', 'Open'): 2047, ('Open', 'Shift'): 1982, ('Open', 'Close'): 1768, ('Close', 'Shift'): 1741, ('Shift', 'Close'): 1461, ('Shift', 'Open'): 1183, ('Close', 'Open'): 951})
# 2023-04-17 00:37:51 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 3564, <RepairType.OPEN_SHIFT: 6>: 1671, <RepairType.WRONG_OPEN_GENERAL: 4>: 1632, <RepairType.SHIFT_CLOSE: 8>: 1491, <RepairType.OPEN_CLOSE: 7>: 1269, <RepairType.MISSED_UNARY: 5>: 615, <RepairType.CLOSE_SHIFT_NESTED: 9>: 436, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 315, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 96, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 2})
# 2023-04-17 00:37:51 INFO: Fake transitions used: 86
# 2023-04-17 00:37:51 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:23<00:00,  4.54it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 94.1 LR: 93.53 F1: 93.81 Exact: 38.94 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.1 LR: 93.53 F1: 93.81 Exact: 38.94 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 00:39:24 INFO: New best dev score: 0.93818 > 0.92387
# 2023-04-17 00:39:24 INFO: Model saved to ./output_stanza_en/en_wsj_constituency.pt
# 2023-04-17 00:39:24 INFO: Epoch 6 finished
#   Transitions correct: Counter({'Shift': 117023, 'Open': 94845, 'Close': 92835})
#   Transitions incorrect: Counter({('Open', 'Open'): 2047, ('Open', 'Shift'): 1982, ('Open', 'Close'): 1768, ('Close', 'Shift'): 1741, ('Shift', 'Close'): 1461, ('Shift', 'Open'): 1183, ('Close', 'Open'): 951})
#   Total loss for epoch: 37790.78372
#   Dev score      (    6): 0.938181
#   Best dev score (    6): 0.938181
# 2023-04-17 00:39:24 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 00:39:24 INFO: Starting epoch 7
# 100%|████████████████████████████████| 167/167 [26:59<00:00,  9.70s/it, Epoch 7]
# 2023-04-17 01:06:24 INFO: Transitions correct: 306041
#   Counter({'Shift': 117429, 'Open': 95207, 'Close': 93405})
# 2023-04-17 01:06:24 INFO: Transitions incorrect: 9760
#   Counter({('Open', 'Open'): 1792, ('Open', 'Shift'): 1760, ('Open', 'Close'): 1556, ('Close', 'Shift'): 1511, ('Shift', 'Close'): 1264, ('Shift', 'Open'): 965, ('Close', 'Open'): 912})
# 2023-04-17 01:06:24 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 3132, <RepairType.OPEN_SHIFT: 6>: 1516, <RepairType.WRONG_OPEN_GENERAL: 4>: 1426, <RepairType.SHIFT_CLOSE: 8>: 1297, <RepairType.OPEN_CLOSE: 7>: 1155, <RepairType.MISSED_UNARY: 5>: 496, <RepairType.CLOSE_SHIFT_NESTED: 9>: 349, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 259, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 106})
# 2023-04-17 01:06:24 INFO: Fake transitions used: 88
# 2023-04-17 01:06:24 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:23<00:00,  4.53it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 93.84 LR: 93.9 F1: 93.87 Exact: 42.1 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 93.84 LR: 93.9 F1: 93.87 Exact: 42.1 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 01:07:57 INFO: New best dev score: 0.93873 > 0.93818
# 2023-04-17 01:07:57 INFO: Model saved to ./output_stanza_en/en_wsj_constituency.pt
# 2023-04-17 01:07:57 INFO: Epoch 7 finished
#   Transitions correct: Counter({'Shift': 117429, 'Open': 95207, 'Close': 93405})
#   Transitions incorrect: Counter({('Open', 'Open'): 1792, ('Open', 'Shift'): 1760, ('Open', 'Close'): 1556, ('Close', 'Shift'): 1511, ('Shift', 'Close'): 1264, ('Shift', 'Open'): 965, ('Close', 'Open'): 912})
#   Total loss for epoch: 32124.63315
#   Dev score      (    7): 0.938733
#   Best dev score (    7): 0.938733
# 2023-04-17 01:07:57 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 01:07:57 INFO: Starting epoch 8
# 100%|████████████████████████████████| 167/167 [27:03<00:00,  9.72s/it, Epoch 8]
# 2023-04-17 01:35:01 INFO: Transitions correct: 308567
#   Counter({'Shift': 118044, 'Open': 96014, 'Close': 94509})
# 2023-04-17 01:35:01 INFO: Transitions incorrect: 8436
#   Counter({('Open', 'Open'): 1557, ('Open', 'Shift'): 1490, ('Open', 'Close'): 1362, ('Close', 'Shift'): 1307, ('Shift', 'Close'): 1119, ('Shift', 'Open'): 924, ('Close', 'Open'): 677})
# 2023-04-17 01:35:01 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 2667, <RepairType.OPEN_SHIFT: 6>: 1246, <RepairType.WRONG_OPEN_GENERAL: 4>: 1238, <RepairType.SHIFT_CLOSE: 8>: 1147, <RepairType.OPEN_CLOSE: 7>: 986, <RepairType.MISSED_UNARY: 5>: 484, <RepairType.CLOSE_SHIFT_NESTED: 9>: 343, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 239, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 79})
# 2023-04-17 01:35:01 INFO: Fake transitions used: 102
# 2023-04-17 01:35:01 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:23<00:00,  4.55it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 93.81 LR: 94.46 F1: 94.13 Exact: 40.26 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 93.81 LR: 94.46 F1: 94.13 Exact: 40.26 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 01:36:34 INFO: New best dev score: 0.94139 > 0.93873
# 2023-04-17 01:36:34 INFO: Model saved to ./output_stanza_en/en_wsj_constituency.pt
# 2023-04-17 01:36:34 INFO: Epoch 8 finished
#   Transitions correct: Counter({'Shift': 118044, 'Open': 96014, 'Close': 94509})
#   Transitions incorrect: Counter({('Open', 'Open'): 1557, ('Open', 'Shift'): 1490, ('Open', 'Close'): 1362, ('Close', 'Shift'): 1307, ('Shift', 'Close'): 1119, ('Shift', 'Open'): 924, ('Close', 'Open'): 677})
#   Total loss for epoch: 27733.50651
#   Dev score      (    8): 0.941394
#   Best dev score (    8): 0.941394
# 2023-04-17 01:36:35 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 01:36:35 INFO: Starting epoch 9
# 100%|████████████████████████████████| 167/167 [26:57<00:00,  9.69s/it, Epoch 9]
# 2023-04-17 02:03:32 INFO: Transitions correct: 307458
#   Counter({'Shift': 117658, 'Open': 95637, 'Close': 94163})
# 2023-04-17 02:03:32 INFO: Transitions incorrect: 8480
#   Counter({('Open', 'Open'): 1589, ('Open', 'Shift'): 1448, ('Open', 'Close'): 1418, ('Close', 'Shift'): 1340, ('Shift', 'Close'): 1155, ('Shift', 'Open'): 825, ('Close', 'Open'): 705})
# 2023-04-17 02:03:32 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 2560, <RepairType.OPEN_SHIFT: 6>: 1187, <RepairType.SHIFT_CLOSE: 8>: 1176, <RepairType.WRONG_OPEN_GENERAL: 4>: 1101, <RepairType.OPEN_CLOSE: 7>: 983, <RepairType.MISSED_UNARY: 5>: 465, <RepairType.CLOSE_SHIFT_NESTED: 9>: 279, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 233, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 99, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 75})
# 2023-04-17 02:03:32 INFO: Fake transitions used: 82
# 2023-04-17 02:03:32 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:23<00:00,  4.55it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 94.21 LR: 94.7 F1: 94.45 Exact: 45.78 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.21 LR: 94.7 F1: 94.45 Exact: 45.78 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 02:05:06 INFO: New best dev score: 0.94457 > 0.94139
# 2023-04-17 02:05:06 INFO: Model saved to ./output_stanza_en/en_wsj_constituency.pt
# 2023-04-17 02:05:06 INFO: Epoch 9 finished
#   Transitions correct: Counter({'Shift': 117658, 'Open': 95637, 'Close': 94163})
#   Transitions incorrect: Counter({('Open', 'Open'): 1589, ('Open', 'Shift'): 1448, ('Open', 'Close'): 1418, ('Close', 'Shift'): 1340, ('Shift', 'Close'): 1155, ('Shift', 'Open'): 825, ('Close', 'Open'): 705})
#   Total loss for epoch: 31734.79753
#   Dev score      (    9): 0.944566
#   Best dev score (    9): 0.944566
# 2023-04-17 02:05:06 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 02:05:06 INFO: Starting epoch 10
# 100%|███████████████████████████████| 167/167 [27:01<00:00,  9.71s/it, Epoch 10]
# 2023-04-17 02:32:08 INFO: Transitions correct: 310951
#   Counter({'Shift': 118657, 'Open': 96708, 'Close': 95586})
# 2023-04-17 02:32:08 INFO: Transitions incorrect: 6840
#   Counter({('Open', 'Open'): 1320, ('Open', 'Shift'): 1198, ('Close', 'Shift'): 1105, ('Open', 'Close'): 1018, ('Shift', 'Close'): 924, ('Shift', 'Open'): 753, ('Close', 'Open'): 522})
# 2023-04-17 02:32:08 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 2172, <RepairType.WRONG_OPEN_GENERAL: 4>: 1061, <RepairType.OPEN_SHIFT: 6>: 996, <RepairType.SHIFT_CLOSE: 8>: 939, <RepairType.OPEN_CLOSE: 7>: 701, <RepairType.MISSED_UNARY: 5>: 415, <RepairType.CLOSE_SHIFT_NESTED: 9>: 273, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 198, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 59, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 1})
# 2023-04-17 02:32:08 INFO: Fake transitions used: 89
# 2023-04-17 02:32:08 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:23<00:00,  4.54it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 93.45 LR: 93.5 F1: 93.48 Exact: 39.73 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 93.45 LR: 93.5 F1: 93.48 Exact: 39.73 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 02:33:41 INFO: Epoch 10 finished
#   Transitions correct: Counter({'Shift': 118657, 'Open': 96708, 'Close': 95586})
#   Transitions incorrect: Counter({('Open', 'Open'): 1320, ('Open', 'Shift'): 1198, ('Close', 'Shift'): 1105, ('Open', 'Close'): 1018, ('Shift', 'Close'): 924, ('Shift', 'Open'): 753, ('Close', 'Open'): 522})
#   Total loss for epoch: 22609.36635
#   Dev score      (   10): 0.934810
#   Best dev score (    9): 0.944566
# 2023-04-17 02:33:41 INFO: Finished stage at epoch 10.  Restarting optimizer
# 2023-04-17 02:33:41 INFO: Previous best model was at epoch 9
# 2023-04-17 02:33:41 INFO: Switching to a model with 0 pattn layers and NO lattn
# 2023-04-17 02:33:42 INFO: Building AdamW with lr=0.000200, beta2=0.999000, eps=0.000000, weight_decay=0.050000
# 2023-04-17 02:33:42 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 02:33:42 INFO: Starting epoch 11
# 100%|███████████████████████████████| 167/167 [27:00<00:00,  9.70s/it, Epoch 11]
# 2023-04-17 03:00:42 INFO: Transitions correct: 311610
#   Counter({'Shift': 118468, 'Open': 96994, 'Close': 96148})
# 2023-04-17 03:00:42 INFO: Transitions incorrect: 4161
#   Counter({('Close', 'Shift'): 740, ('Open', 'Open'): 735, ('Open', 'Shift'): 735, ('Open', 'Close'): 651, ('Shift', 'Close'): 613, ('Shift', 'Open'): 391, ('Close', 'Open'): 296})
# 2023-04-17 03:00:42 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 1298, <RepairType.SHIFT_CLOSE: 8>: 627, <RepairType.OPEN_SHIFT: 6>: 606, <RepairType.WRONG_OPEN_GENERAL: 4>: 575, <RepairType.OPEN_CLOSE: 7>: 427, <RepairType.MISSED_UNARY: 5>: 291, <RepairType.CLOSE_SHIFT_NESTED: 9>: 175, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 112, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 47})
# 2023-04-17 03:00:42 INFO: Fake transitions used: 95
# 2023-04-17 03:00:42 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:23<00:00,  4.55it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 94.79 LR: 95.41 F1: 95.1 Exact: 47.1 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.79 LR: 95.41 F1: 95.1 Exact: 47.1 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 03:02:15 INFO: New best dev score: 0.95105 > 0.94457
# 2023-04-17 03:02:15 INFO: Model saved to ./output_stanza_en/en_wsj_constituency.pt
# 2023-04-17 03:02:15 INFO: Epoch 11 finished
#   Transitions correct: Counter({'Shift': 118468, 'Open': 96994, 'Close': 96148})
#   Transitions incorrect: Counter({('Close', 'Shift'): 740, ('Open', 'Open'): 735, ('Open', 'Shift'): 735, ('Open', 'Close'): 651, ('Shift', 'Close'): 613, ('Shift', 'Open'): 391, ('Close', 'Open'): 296})
#   Total loss for epoch: 13328.86186
#   Dev score      (   11): 0.951049
#   Best dev score (   11): 0.951049
# 2023-04-17 03:02:15 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 03:02:15 INFO: Starting epoch 12
# 100%|███████████████████████████████| 167/167 [27:04<00:00,  9.73s/it, Epoch 12]
# 2023-04-17 03:29:20 INFO: Transitions correct: 317334
#   Counter({'Shift': 120531, 'Open': 98736, 'Close': 98067})
# 2023-04-17 03:29:20 INFO: Transitions incorrect: 3294
#   Counter({('Close', 'Shift'): 613, ('Open', 'Shift'): 589, ('Open', 'Open'): 580, ('Open', 'Close'): 511, ('Shift', 'Close'): 443, ('Shift', 'Open'): 339, ('Close', 'Open'): 219})
# 2023-04-17 03:29:20 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 1048, <RepairType.WRONG_OPEN_GENERAL: 4>: 472, <RepairType.OPEN_SHIFT: 6>: 465, <RepairType.SHIFT_CLOSE: 8>: 451, <RepairType.OPEN_CLOSE: 7>: 333, <RepairType.MISSED_UNARY: 5>: 258, <RepairType.CLOSE_SHIFT_NESTED: 9>: 155, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 76, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 32})
# 2023-04-17 03:29:20 INFO: Fake transitions used: 108
# 2023-04-17 03:29:20 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:24<00:00,  4.52it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 94.59 LR: 95.13 F1: 94.86 Exact: 47.1 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.59 LR: 95.13 F1: 94.86 Exact: 47.1 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 03:30:54 INFO: Epoch 12 finished
#   Transitions correct: Counter({'Shift': 120531, 'Open': 98736, 'Close': 98067})
#   Transitions incorrect: Counter({('Close', 'Shift'): 613, ('Open', 'Shift'): 589, ('Open', 'Open'): 580, ('Open', 'Close'): 511, ('Shift', 'Close'): 443, ('Shift', 'Open'): 339, ('Close', 'Open'): 219})
#   Total loss for epoch: 10588.90718
#   Dev score      (   12): 0.948625
#   Best dev score (   11): 0.951049
# 2023-04-17 03:30:54 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 03:30:54 INFO: Starting epoch 13
# 100%|███████████████████████████████| 167/167 [27:09<00:00,  9.76s/it, Epoch 13]
# 2023-04-17 03:58:03 INFO: Transitions correct: 314680
#   Counter({'Shift': 119334, 'Open': 97945, 'Close': 97401})
# 2023-04-17 03:58:03 INFO: Transitions incorrect: 2835
#   Counter({('Open', 'Open'): 531, ('Close', 'Shift'): 507, ('Open', 'Shift'): 474, ('Open', 'Close'): 463, ('Shift', 'Close'): 403, ('Shift', 'Open'): 267, ('Close', 'Open'): 190})
# 2023-04-17 03:58:03 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 855, <RepairType.WRONG_OPEN_GENERAL: 4>: 412, <RepairType.SHIFT_CLOSE: 8>: 408, <RepairType.OPEN_SHIFT: 6>: 374, <RepairType.OPEN_CLOSE: 7>: 298, <RepairType.MISSED_UNARY: 5>: 233, <RepairType.CLOSE_SHIFT_NESTED: 9>: 134, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 91, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 28})
# 2023-04-17 03:58:03 INFO: Fake transitions used: 102
# 2023-04-17 03:58:03 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:30<00:00,  4.18it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 94.45 LR: 94.97 F1: 94.71 Exact: 46.84 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.45 LR: 94.97 F1: 94.71 Exact: 46.84 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 03:59:44 INFO: Epoch 13 finished
#   Transitions correct: Counter({'Shift': 119334, 'Open': 97945, 'Close': 97401})
#   Transitions incorrect: Counter({('Open', 'Open'): 531, ('Close', 'Shift'): 507, ('Open', 'Shift'): 474, ('Open', 'Close'): 463, ('Shift', 'Close'): 403, ('Shift', 'Open'): 267, ('Close', 'Open'): 190})
#   Total loss for epoch: 9057.02279
#   Dev score      (   13): 0.947181
#   Best dev score (   11): 0.951049
# 2023-04-17 03:59:44 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 03:59:44 INFO: Starting epoch 14
# 100%|███████████████████████████████| 167/167 [26:53<00:00,  9.66s/it, Epoch 14]
# 2023-04-17 04:26:37 INFO: Transitions correct: 315114
#   Counter({'Shift': 119713, 'Open': 97920, 'Close': 97481})
# 2023-04-17 04:26:37 INFO: Transitions incorrect: 2508
#   Counter({('Open', 'Open'): 481, ('Close', 'Shift'): 468, ('Open', 'Shift'): 433, ('Open', 'Close'): 374, ('Shift', 'Close'): 366, ('Shift', 'Open'): 230, ('Close', 'Open'): 156})
# 2023-04-17 04:26:37 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 742, <RepairType.SHIFT_CLOSE: 8>: 372, <RepairType.WRONG_OPEN_GENERAL: 4>: 370, <RepairType.OPEN_SHIFT: 6>: 354, <RepairType.OPEN_CLOSE: 7>: 229, <RepairType.MISSED_UNARY: 5>: 199, <RepairType.CLOSE_SHIFT_NESTED: 9>: 126, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 86, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 25})
# 2023-04-17 04:26:37 INFO: Fake transitions used: 102
# 2023-04-17 04:26:37 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:23<00:00,  4.53it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 94.53 LR: 95.13 F1: 94.82 Exact: 47.36 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.53 LR: 95.13 F1: 94.82 Exact: 47.36 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 04:28:10 INFO: Epoch 14 finished
#   Transitions correct: Counter({'Shift': 119713, 'Open': 97920, 'Close': 97481})
#   Transitions incorrect: Counter({('Open', 'Open'): 481, ('Close', 'Shift'): 468, ('Open', 'Shift'): 433, ('Open', 'Close'): 374, ('Shift', 'Close'): 366, ('Shift', 'Open'): 230, ('Close', 'Open'): 156})
#   Total loss for epoch: 7965.82217
#   Dev score      (   14): 0.948300
#   Best dev score (   11): 0.951049
# 2023-04-17 04:28:10 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 04:28:10 INFO: Starting epoch 15
# 100%|███████████████████████████████| 167/167 [26:54<00:00,  9.67s/it, Epoch 15]
# 2023-04-17 04:55:05 INFO: Transitions correct: 315494
#   Counter({'Shift': 119506, 'Open': 98217, 'Close': 97771})
# 2023-04-17 04:55:05 INFO: Transitions incorrect: 2283
#   Counter({('Close', 'Shift'): 420, ('Open', 'Open'): 411, ('Open', 'Shift'): 388, ('Open', 'Close'): 361, ('Shift', 'Close'): 351, ('Shift', 'Open'): 207, ('Close', 'Open'): 145})
# 2023-04-17 04:55:05 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 672, <RepairType.SHIFT_CLOSE: 8>: 359, <RepairType.WRONG_OPEN_GENERAL: 4>: 329, <RepairType.OPEN_SHIFT: 6>: 313, <RepairType.OPEN_CLOSE: 7>: 234, <RepairType.MISSED_UNARY: 5>: 179, <RepairType.CLOSE_SHIFT_NESTED: 9>: 115, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 54, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 28})
# 2023-04-17 04:55:05 INFO: Fake transitions used: 85
# 2023-04-17 04:55:05 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:31<00:00,  4.17it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 94.15 LR: 95.03 F1: 94.59 Exact: 45.26 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.15 LR: 95.03 F1: 94.59 Exact: 45.26 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 04:56:47 INFO: Epoch 15 finished
#   Transitions correct: Counter({'Shift': 119506, 'Open': 98217, 'Close': 97771})
#   Transitions incorrect: Counter({('Close', 'Shift'): 420, ('Open', 'Open'): 411, ('Open', 'Shift'): 388, ('Open', 'Close'): 361, ('Shift', 'Close'): 351, ('Shift', 'Open'): 207, ('Close', 'Open'): 145})
#   Total loss for epoch: 7211.46452
#   Dev score      (   15): 0.945913
#   Best dev score (   11): 0.951049
# 2023-04-17 04:56:47 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 04:56:47 INFO: Starting epoch 16
# 100%|███████████████████████████████| 167/167 [26:56<00:00,  9.68s/it, Epoch 16]
# 2023-04-17 05:23:43 INFO: Transitions correct: 316052
#   Counter({'Shift': 119782, 'Open': 98324, 'Close': 97946})
# 2023-04-17 05:23:43 INFO: Transitions incorrect: 2000
#   Counter({('Open', 'Open'): 383, ('Close', 'Shift'): 351, ('Open', 'Shift'): 317, ('Shift', 'Close'): 309, ('Open', 'Close'): 301, ('Shift', 'Open'): 182, ('Close', 'Open'): 157})
# 2023-04-17 05:23:43 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 600, <RepairType.SHIFT_CLOSE: 8>: 314, <RepairType.WRONG_OPEN_GENERAL: 4>: 279, <RepairType.OPEN_SHIFT: 6>: 255, <RepairType.OPEN_CLOSE: 7>: 193, <RepairType.MISSED_UNARY: 5>: 155, <RepairType.CLOSE_SHIFT_NESTED: 9>: 100, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 80, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 24})
# 2023-04-17 05:23:43 INFO: Fake transitions used: 91
# 2023-04-17 05:23:43 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:23<00:00,  4.55it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.0 sec].
# pcfg LP/LR summary evalb: LP: 94.37 LR: 95.13 F1: 94.75 Exact: 46.57 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.37 LR: 95.13 F1: 94.75 Exact: 46.57 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 05:25:17 INFO: Epoch 16 finished
#   Transitions correct: Counter({'Shift': 119782, 'Open': 98324, 'Close': 97946})
#   Transitions incorrect: Counter({('Open', 'Open'): 383, ('Close', 'Shift'): 351, ('Open', 'Shift'): 317, ('Shift', 'Close'): 309, ('Open', 'Close'): 301, ('Shift', 'Open'): 182, ('Close', 'Open'): 157})
#   Total loss for epoch: 6398.59987
#   Dev score      (   16): 0.947520
#   Best dev score (   11): 0.951049
# 2023-04-17 05:25:17 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 05:25:17 INFO: Starting epoch 17
# 100%|███████████████████████████████| 167/167 [26:59<00:00,  9.70s/it, Epoch 17]
# 2023-04-17 05:52:17 INFO: Transitions correct: 316751
#   Counter({'Shift': 120025, 'Open': 98546, 'Close': 98180})
# 2023-04-17 05:52:17 INFO: Transitions incorrect: 1837
#   Counter({('Open', 'Open'): 345, ('Close', 'Shift'): 339, ('Open', 'Shift'): 297, ('Open', 'Close'): 295, ('Shift', 'Close'): 270, ('Shift', 'Open'): 173, ('Close', 'Open'): 118})
# 2023-04-17 05:52:17 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 557, <RepairType.SHIFT_CLOSE: 8>: 275, <RepairType.WRONG_OPEN_GENERAL: 4>: 266, <RepairType.OPEN_SHIFT: 6>: 233, <RepairType.OPEN_CLOSE: 7>: 187, <RepairType.MISSED_UNARY: 5>: 154, <RepairType.CLOSE_SHIFT_NESTED: 9>: 86, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 61, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 18})
# 2023-04-17 05:52:17 INFO: Fake transitions used: 111
# 2023-04-17 05:52:17 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:23<00:00,  4.54it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 94.44 LR: 95.18 F1: 94.81 Exact: 46.84 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.44 LR: 95.18 F1: 94.81 Exact: 46.84 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 05:53:50 INFO: Epoch 17 finished
#   Transitions correct: Counter({'Shift': 120025, 'Open': 98546, 'Close': 98180})
#   Transitions incorrect: Counter({('Open', 'Open'): 345, ('Close', 'Shift'): 339, ('Open', 'Shift'): 297, ('Open', 'Close'): 295, ('Shift', 'Close'): 270, ('Shift', 'Open'): 173, ('Close', 'Open'): 118})
#   Total loss for epoch: 5902.01197
#   Dev score      (   17): 0.948133
#   Best dev score (   11): 0.951049
# 2023-04-17 05:53:50 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 05:53:50 INFO: Starting epoch 18
# 100%|███████████████████████████████| 167/167 [27:08<00:00,  9.75s/it, Epoch 18]
# 2023-04-17 06:20:59 INFO: Transitions correct: 317151
#   Counter({'Shift': 120105, 'Open': 98689, 'Close': 98357})
# 2023-04-17 06:20:59 INFO: Transitions incorrect: 1561
#   Counter({('Open', 'Open'): 294, ('Close', 'Shift'): 285, ('Open', 'Shift'): 262, ('Shift', 'Close'): 245, ('Open', 'Close'): 240, ('Shift', 'Open'): 127, ('Close', 'Open'): 108})
# 2023-04-17 06:20:59 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 468, <RepairType.SHIFT_CLOSE: 8>: 246, <RepairType.WRONG_OPEN_GENERAL: 4>: 226, <RepairType.OPEN_SHIFT: 6>: 213, <RepairType.OPEN_CLOSE: 7>: 143, <RepairType.MISSED_UNARY: 5>: 133, <RepairType.CLOSE_SHIFT_NESTED: 9>: 62, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 49, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 19})
# 2023-04-17 06:20:59 INFO: Fake transitions used: 82
# 2023-04-17 06:20:59 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:24<00:00,  4.52it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 94.66 LR: 95.19 F1: 94.93 Exact: 46.05 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.66 LR: 95.19 F1: 94.93 Exact: 46.05 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 06:22:32 INFO: Epoch 18 finished
#   Transitions correct: Counter({'Shift': 120105, 'Open': 98689, 'Close': 98357})
#   Transitions incorrect: Counter({('Open', 'Open'): 294, ('Close', 'Shift'): 285, ('Open', 'Shift'): 262, ('Shift', 'Close'): 245, ('Open', 'Close'): 240, ('Shift', 'Open'): 127, ('Close', 'Open'): 108})
#   Total loss for epoch: 5040.77925
#   Dev score      (   18): 0.949311
#   Best dev score (   11): 0.951049
# 2023-04-17 06:22:32 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 06:22:32 INFO: Starting epoch 19
# 100%|███████████████████████████████| 167/167 [27:00<00:00,  9.70s/it, Epoch 19]
# 2023-04-17 06:49:33 INFO: Transitions correct: 317332
#   Counter({'Shift': 120072, 'Open': 98789, 'Close': 98471})
# 2023-04-17 06:49:33 INFO: Transitions incorrect: 1413
#   Counter({('Close', 'Shift'): 259, ('Open', 'Open'): 247, ('Open', 'Shift'): 226, ('Open', 'Close'): 218, ('Shift', 'Close'): 214, ('Shift', 'Open'): 140, ('Close', 'Open'): 109})
# 2023-04-17 06:49:33 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 458, <RepairType.SHIFT_CLOSE: 8>: 220, <RepairType.WRONG_OPEN_GENERAL: 4>: 183, <RepairType.OPEN_SHIFT: 6>: 178, <RepairType.MISSED_UNARY: 5>: 126, <RepairType.OPEN_CLOSE: 7>: 120, <RepairType.CLOSE_SHIFT_NESTED: 9>: 63, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 49, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 15})
# 2023-04-17 06:49:33 INFO: Fake transitions used: 104
# 2023-04-17 06:49:33 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:23<00:00,  4.53it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.0 sec].
# pcfg LP/LR summary evalb: LP: 94.54 LR: 95.04 F1: 94.79 Exact: 46.31 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.54 LR: 95.04 F1: 94.79 Exact: 46.31 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 06:51:06 INFO: Epoch 19 finished
#   Transitions correct: Counter({'Shift': 120072, 'Open': 98789, 'Close': 98471})
#   Transitions incorrect: Counter({('Close', 'Shift'): 259, ('Open', 'Open'): 247, ('Open', 'Shift'): 226, ('Open', 'Close'): 218, ('Shift', 'Close'): 214, ('Shift', 'Open'): 140, ('Close', 'Open'): 109})
#   Total loss for epoch: 4654.75282
#   Dev score      (   19): 0.947932
#   Best dev score (   11): 0.951049
# 2023-04-17 06:51:06 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 06:51:06 INFO: Starting epoch 20
# 100%|███████████████████████████████| 167/167 [27:06<00:00,  9.74s/it, Epoch 20]
# 2023-04-17 07:18:13 INFO: Transitions correct: 315681
#   Counter({'Shift': 119534, 'Open': 98209, 'Close': 97938})
# 2023-04-17 07:18:13 INFO: Transitions incorrect: 1254
#   Counter({('Open', 'Close'): 230, ('Open', 'Open'): 225, ('Close', 'Shift'): 217, ('Open', 'Shift'): 206, ('Shift', 'Close'): 171, ('Shift', 'Open'): 109, ('Close', 'Open'): 96})
# 2023-04-17 07:18:13 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 368, <RepairType.SHIFT_CLOSE: 8>: 174, <RepairType.WRONG_OPEN_GENERAL: 4>: 170, <RepairType.OPEN_SHIFT: 6>: 167, <RepairType.OPEN_CLOSE: 7>: 151, <RepairType.MISSED_UNARY: 5>: 110, <RepairType.CLOSE_SHIFT_NESTED: 9>: 59, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 39, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 16})
# 2023-04-17 07:18:13 INFO: Fake transitions used: 93
# 2023-04-17 07:18:13 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:24<00:00,  4.51it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 94.33 LR: 95.3 F1: 94.81 Exact: 45.26 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.33 LR: 95.3 F1: 94.81 Exact: 45.26 N: 380
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 380
# 2023-04-17 07:19:47 INFO: Epoch 20 finished
#   Transitions correct: Counter({'Shift': 119534, 'Open': 98209, 'Close': 97938})
#   Transitions incorrect: Counter({('Open', 'Close'): 230, ('Open', 'Open'): 225, ('Close', 'Shift'): 217, ('Open', 'Shift'): 206, ('Shift', 'Close'): 171, ('Shift', 'Open'): 109, ('Close', 'Open'): 96})
#   Total loss for epoch: 3985.50003
#   Dev score      (   20): 0.948197
#   Best dev score (   11): 0.951049
# 2023-04-17 07:19:47 INFO: Model saved to ./output_stanza_en/en_wsj_constituency_checkpoint.pt
# 2023-04-17 07:19:47 INFO: Running dev step with args: ['--eval_file', 'data/constituency/en_wsj_dev.mrg', '--shorthand', 'en_wsj', '--mode', 'predict', '--wordvec_pretrain_file', '/Users/gonzalojaimovitch/stanza_resources/en/pretrain/combined.pt', '--charlm_forward_file', '/Users/gonzalojaimovitch/stanza_resources/en/forward_charlm/1billion.pt', '--charlm_backward_file', '/Users/gonzalojaimovitch/stanza_resources/en/backward_charlm/1billion.pt', '--bert_model', 'roberta-base', '--epochs', '20', '--save_dir', './output_stanza_en', '--save_name', 'en_wsj_constituency.pt']
# 2023-04-17 07:19:47 INFO: Running constituency parser in predict mode
# 2023-04-17 07:19:47 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json: 200kB [00:00, 35.3MB/s]
# 2023-04-17 07:19:48 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# ========================
#
# 2023-04-17 07:19:48 INFO: Using device: cpu
# 2023-04-17 07:19:48 INFO: Loading: tokenize
# 2023-04-17 07:19:48 INFO: Loading: pos
# 2023-04-17 07:19:49 INFO: Done loading processors!
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-04-17 07:19:52 INFO: Reading trees from data/constituency/en_wsj_dev.mrg
# 2023-04-17 07:19:52 INFO: Read 380 trees for evaluation
# 2023-04-17 07:19:52 INFO: Retagging trees using the xpos tags from the default package...
# 100%|█████████████████████████████████████████| 380/380 [00:22<00:00, 16.97it/s]
# 2023-04-17 07:20:14 INFO: Retagging finished
# 2023-04-17 07:20:14 INFO: Processing 380 trees from data/constituency/en_wsj_dev.mrg
# 100%|█████████████████████████████████████████| 380/380 [01:23<00:00,  4.56it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 94.79 LR: 95.41 F1: 95.1 Exact: 47.1 N: 380
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.79 LR: 95.41 F1: 95.1 Exact: 47.1 N: 380
# factor Tag summary evalb: LP: 94.98 LR: 94.98 F1: 94.98 Exact: 31.57 N: 380
# 2023-04-17 07:21:47 INFO: F1 score on data/constituency/en_wsj_dev.mrg: 0.951049
# 2023-04-17 07:21:47 INFO: Running test step with args: ['--eval_file', 'data/constituency/en_wsj_test.mrg', '--shorthand', 'en_wsj', '--mode', 'predict', '--wordvec_pretrain_file', '/Users/gonzalojaimovitch/stanza_resources/en/pretrain/combined.pt', '--charlm_forward_file', '/Users/gonzalojaimovitch/stanza_resources/en/forward_charlm/1billion.pt', '--charlm_backward_file', '/Users/gonzalojaimovitch/stanza_resources/en/backward_charlm/1billion.pt', '--bert_model', 'roberta-base', '--epochs', '20', '--save_dir', './output_stanza_en', '--save_name', 'en_wsj_constituency.pt']
# 2023-04-17 07:21:47 INFO: Running constituency parser in predict mode
# 2023-04-17 07:21:47 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json: 200kB [00:00, 34.8MB/s]
# 2023-04-17 07:21:48 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# ========================
#
# 2023-04-17 07:21:48 INFO: Using device: cpu
# 2023-04-17 07:21:48 INFO: Loading: tokenize
# 2023-04-17 07:21:48 INFO: Loading: pos
# 2023-04-17 07:21:48 INFO: Done loading processors!
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-04-17 07:21:51 INFO: Reading trees from data/constituency/en_wsj_test.mrg
# 2023-04-17 07:21:52 INFO: Read 381 trees for evaluation
# 2023-04-17 07:21:52 INFO: Retagging trees using the xpos tags from the default package...
# 100%|█████████████████████████████████████████| 381/381 [00:20<00:00, 18.24it/s]
# 2023-04-17 07:22:13 INFO: Retagging finished
# 2023-04-17 07:22:13 INFO: Processing 381 trees from data/constituency/en_wsj_test.mrg
# 100%|█████████████████████████████████████████| 381/381 [01:09<00:00,  5.52it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 94.77 LR: 94.96 F1: 94.86 Exact: 48.29 N: 381
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.77 LR: 94.96 F1: 94.86 Exact: 48.29 N: 381
# factor Tag summary evalb: LP: 95.59 LR: 95.59 F1: 95.59 Exact: 36.74 N: 381
# 2023-04-17 07:23:33 INFO: F1 score on data/constituency/en_wsj_test.mrg: 0.948666
# 35044.143652677536

# %% [markdown]
# ### Portuguese

# %% [markdown]
# #### Data preparation

# %%
import xml.etree.ElementTree as ET

from stanza.models.constituency import tree_reader
from stanza.utils.datasets.constituency import utils

def read_xml_file(input_filename):
    """
    Convert the CINTIL xml file to id & test
    Returns a list of tuples: (id, text)
    """
    with open(input_filename, encoding="utf-8") as fin:
        dataset = ET.parse(fin)
    dataset = dataset.getroot()
    corpus = dataset.find("{http://www.iula.upf.edu}corpus")
    if not corpus:
        raise ValueError("Unexpected dataset structure : no 'corpus'")
    trees = []
    for sentence in corpus:
        if sentence.tag != "{http://www.iula.upf.edu}sentence":
            raise ValueError("Unexpected sentence tag: {}".format(sentence.tag))
        id_node = None
        raw_node = None
        tree_node = None
        for node in sentence:
            if node.tag == '{http://www.iula.upf.edu}id':
                id_node = node
            elif node.tag == '{http://www.iula.upf.edu}raw':
                raw_node = node
            elif node.tag == '{http://www.iula.upf.edu}tree':
                tree_node = node
            else:
                raise ValueError("Unexpected tag in sentence {}: {}".format(sentence, node.tag))
        if id_node is None or raw_node is None or tree_node is None:
            raise ValueError("Missing node in sentence {}".format(sentence))
        tree_id = "".join(id_node.itertext())
        tree_text = "".join(tree_node.itertext())
        trees.append((tree_id, tree_text))
    return trees

def convert_cintil_treebank(input_filename, train_size=0.8, dev_size=0.1):
    """
    dev_size is the size for splitting train & dev
    """
    trees = read_xml_file(input_filename)

    synthetic_trees = []
    natural_trees = []
    for tree_id, tree_text in trees:
        if tree_text.find(" _") >= 0:
            raise ValueError("Unexpected underscore")
        tree_text = tree_text.replace("_)", ")")
        tree_text = tree_text.replace("(A (", "(A' (")
        # trees don't have ROOT, but we typically use a ROOT label at the top
        tree_text = "(ROOT %s)" % tree_text
        trees = tree_reader.read_trees(tree_text)
        if len(trees) != 1:
            raise ValueError("Unexpectedly found %d trees in %s" % (len(trees), tree_id))
        tree = trees[0]
        if tree_id.startswith("aTSTS"):
            synthetic_trees.append(tree)
        elif tree_id.find("TSTS") >= 0:
            raise ValueError("Unexpected TSTS")
        else:
            natural_trees.append(tree)

    print("Read %d synthetic trees" % len(synthetic_trees))
    print("Read %d natural trees" % len(natural_trees))
    train_trees, dev_trees, test_trees = utils.split_treebank(natural_trees, train_size, dev_size)
    print("Split %d trees into %d train %d dev %d test" % (len(natural_trees), len(train_trees), len(dev_trees), len(test_trees)))
    train_trees = synthetic_trees + train_trees
    print("Total lengths %d train %d dev %d test" % (len(train_trees), len(dev_trees), len(test_trees)))
    return train_trees, dev_trees, test_trees

# %%
from stanza.utils.datasets.constituency.utils import write_dataset
datasets = convert_cintil_treebank("./datasets/portuguese/CINTIL/CINTIL-Treebank.xml")
write_dataset(datasets, "./datasets/portuguese/CINTIL", "pt_cintil")

# %% [markdown]
# #### Train

# %%
import time
start = time.time()

# !python3 -m stanza.utils.training.run_constituency --train pt_cintil --save_dir ./output_stanza_pt --epochs 20

end = time.time()
print(end - start)
# Out:
# 2023-04-17 15:13:08 INFO: Training program called with:
# /Users/gonzalojaimovitch/Desktop/projects/constituency_parser/.env/lib/python3.8/site-packages/stanza/utils/training/run_constituency.py --train pt_cintil --save_dir ./output_stanza_pt --epochs 20
# 2023-04-17 15:13:08 INFO: Save file for pt_cintil model: pt_cintil_constituency.pt
# 2023-04-17 15:13:08 INFO: pt_cintil: ./output_stanza_pt/pt_cintil_constituency.pt does not exist, training new model
# 2023-04-17 15:13:09 INFO: Using default pretrain for language, found in /Users/gonzalojaimovitch/stanza_resources/pt/pretrain/bosque.pt  To use a different pretrain, specify --wordvec_pretrain_file
# 2023-04-17 15:13:09 INFO: Running train step with args: ['--train_file', 'data/constituency/pt_cintil_train.mrg', '--eval_file', 'data/constituency/pt_cintil_dev.mrg', '--shorthand', 'pt_cintil', '--mode', 'train', '--retag_method', 'upos', '--wordvec_pretrain_file', '/Users/gonzalojaimovitch/stanza_resources/pt/pretrain/bosque.pt', '--bert_model', 'neuralmind/bert-large-portuguese-cased', '--epochs', '20', '--save_dir', './output_stanza_pt', '--save_name', 'pt_cintil_constituency.pt']
# 2023-04-17 15:13:09 WARNING: Multistage training is set.  Best models are with MADGRAD, but it is not installed.  Will use AdamW for the second stage optimizer.  Consider installing MADGRAD
# 2023-04-17 15:13:09 INFO: Running constituency parser in train mode
# 2023-04-17 15:13:09 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json: 200kB [00:00, 38.5MB/s]
# 2023-04-17 15:13:09 INFO: Loading these models for language: pt (Portuguese):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | bosque  |
# | pos       | bosque  |
# =======================
#
# 2023-04-17 15:13:09 INFO: Using device: cpu
# 2023-04-17 15:13:09 INFO: Loading: tokenize
# 2023-04-17 15:13:09 INFO: Loading: pos
# 2023-04-17 15:13:09 INFO: Done loading processors!
# 2023-04-17 15:13:09 INFO: ARGS USED AT TRAINING TIME:
# bert_hidden_layers: 4
# bert_model: neuralmind/bert-large-portuguese-cased
# charlm_backward_file: None
# charlm_forward_file: None
# checkpoint: True
# checkpoint_save_name: ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# combined_dummy_embedding: True
# constituency_composition: ConstituencyComposition.MAX
# constituent_heads: 8
# constituent_stack: StackHistory.LSTM
# data_dir: data/constituency
# delta_embedding_dim: 100
# device: cpu
# epoch_size: 5000
# epochs: 20
# eval_batch_size: 50
# eval_file: data/constituency/pt_cintil_dev.mrg
# finetune: False
# grad_clipping: None
# hidden_size: 512
# lang: pt
# lattn_attention_dropout: 0.2
# lattn_combine_as_self: False
# lattn_combined_input: True
# lattn_d_ff: 2048
# lattn_d_input_proj: None
# lattn_d_kv: 64
# lattn_d_l: 32
# lattn_d_proj: 64
# lattn_partitioned: True
# lattn_pwff: True
# lattn_q_as_matrix: False
# lattn_relu_dropout: 0.2
# lattn_resdrop: True
# lattn_residual_dropout: 0.2
# learning_beta2: 0.999
# learning_eps: 1e-08
# learning_momentum: None
# learning_rate: 0.0002
# learning_rate_warmup: 0
# learning_rho: 0.9
# learning_weight_decay: 0.05
# load_name: None
# log_norms: False
# loss: cross
# loss_focal_gamma: 2
# lstm_input_dropout: 0.2
# lstm_layer_dropout: 0.0
# maxout_k: None
# mode: train
# multistage: True
# nonlinearity: relu
# num_generate: 0
# num_lstm_layers: 2
# num_output_layers: 3
# num_tree_lstm_layers: 1
# optim: adamw
# oracle_forced_errors: 0.001
# oracle_frequency: 0.8
# oracle_initial_epoch: 1
# oracle_level: None
# pattn_attention_dropout: 0.2
# pattn_bias: False
# pattn_d_ff: 2048
# pattn_d_kv: 64
# pattn_d_model: 1024
# pattn_encoder_max_len: 512
# pattn_morpho_emb_dropout: 0.2
# pattn_num_heads: 8
# pattn_num_layers: 0
# pattn_relu_dropout: 0.1
# pattn_residual_dropout: 0.2
# pattn_timing: sin
# predict_dir: .
# predict_dropout: 0.2
# predict_file: None
# predict_format: {:_O}
# pretrain_max_vocab: 250000
# rare_word_threshold: 0.02
# rare_word_unknown_frequency: 0.02
# reduce_heads: 8
# reduce_position: 128
# relearn_structure: False
# retag_charlm_backward_file: None
# retag_charlm_forward_file: None
# retag_method: upos
# retag_model_path: None
# retag_package: default
# retag_pretrain_path: None
# retag_xpos: False
# reversed: False
# save_dir: ./output_stanza_pt
# save_each_name: None
# save_name: ./output_stanza_pt/pt_cintil_constituency.pt
# seed: 1234
# sentence_boundary_vectors: SentenceBoundary.EVERYTHING
# shorthand: pt_cintil
# silver_epoch_size: None
# silver_file: None
# silver_remove_duplicates: False
# stage1_learning_rate: 1.0
# tag_embedding_dim: 20
# tag_unknown_frequency: 0.001
# tokenized_file: None
# train_batch_size: 30
# train_file: data/constituency/pt_cintil_train.mrg
# transition_embedding_dim: 20
# transition_heads: 4
# transition_hidden_size: 20
# transition_scheme: TransitionScheme.IN_ORDER
# transition_stack: StackHistory.LSTM
# use_lattn: False
# use_silver_words: True
# wandb: False
# wandb_name: None
# wandb_norm_regex: None
# watch_regex: None
# word_dropout: 0.2
# wordvec_dir: extern_data/wordvec
# wordvec_file:
# wordvec_pretrain_file: /Users/gonzalojaimovitch/stanza_resources/pt/pretrain/bosque.pt
#
# 2023-04-17 15:13:09 INFO: Directory ./output_stanza_pt does not exist; creating...
# 2023-04-17 15:13:09 INFO: Reading trees from data/constituency/pt_cintil_train.mrg
# 100%|█████████████████████████████████████| 8743/8743 [00:01<00:00, 6050.36it/s]
# 2023-04-17 15:13:12 INFO: Read 8743 trees for the training set
# 2023-04-17 15:13:13 INFO: Filtered 101 duplicates from train dataset
# 2023-04-17 15:13:13 INFO: Reading trees from data/constituency/pt_cintil_dev.mrg
# 2023-04-17 15:13:13 INFO: Read 995 trees for the dev set
# 2023-04-17 15:13:13 INFO: Filtered 1 duplicates from dev dataset
# 2023-04-17 15:13:13 INFO: Retagging trees using the upos tags from the default package...
# 100%|██████████████████████████████████████| 8642/8642 [00:40<00:00, 215.10it/s]
# 100%|████████████████████████████████████████| 994/994 [00:04<00:00, 228.73it/s]
# 2023-04-17 15:13:58 INFO: Retagging finished
# 2023-04-17 15:13:58 INFO: Unique constituents in training set: ["A'", "ADV'", 'ADVP', 'AP', "ART'", "C'", "CARD'", "CONJ'", 'CONJP', 'CP', "ITJ'", "N'", 'NP', "P'", "PERCENT'", 'PERCENTP', "POSS'", 'PP', "QNT'", 'ROOT', 'S', "V'", 'VP']
# 2023-04-17 15:13:58 INFO: Constituent node counts: Counter({'NP': 27314, 'S': 20890, "N'": 15070, 'VP': 13038, 'PP': 12962, 'ROOT': 8642, "V'": 2317, 'AP': 1232, 'CP': 1219, "ADV'": 763, 'CONJP': 522, "CARD'": 433, 'ADVP': 354, "P'": 286, "A'": 96, "CONJ'": 78, "PERCENT'": 70, 'PERCENTP': 32, "QNT'": 15, "POSS'": 10, "ITJ'": 3, "C'": 2, "ART'": 1})
# 2023-04-17 15:13:58 INFO: Unique tags in training set: ['ADJ', 'ADP', 'ADV', 'AUX', 'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PRON', 'PROPN', 'PUNCT', 'SCONJ', 'SYM', 'VERB', 'X']
# 2023-04-17 15:13:59 INFO: Building training transition sequences
# 100%|█████████████████████████████████████| 8642/8642 [00:00<00:00, 8876.44it/s]
# 2023-04-17 15:14:00 INFO: Building dev transition sequences
# 100%|██████████████████████████████████████| 994/994 [00:00<00:00, 22353.19it/s]
# 2023-04-17 15:14:00 INFO: Building silver transition sequences
# 0it [00:00, ?it/s]
# 2023-04-17 15:14:00 INFO: Total unique transitions in train set: 25
# 2023-04-17 15:14:00 INFO: Unique transitions in training set: [Shift, CloseConstituent, OpenConstituent(("A'",)), OpenConstituent(("ADV'",)), OpenConstituent(("ART'",)), OpenConstituent(("C'",)), OpenConstituent(("CARD'",)), OpenConstituent(("CONJ'",)), OpenConstituent(("ITJ'",)), OpenConstituent(("N'",)), OpenConstituent(("P'",)), OpenConstituent(("PERCENT'",)), OpenConstituent(("POSS'",)), OpenConstituent(("QNT'",)), OpenConstituent(("V'",)), OpenConstituent(('ADVP',)), OpenConstituent(('AP',)), OpenConstituent(('CONJP',)), OpenConstituent(('CP',)), OpenConstituent(('NP',)), OpenConstituent(('PERCENTP',)), OpenConstituent(('PP',)), OpenConstituent(('ROOT',)), OpenConstituent(('S',)), OpenConstituent(('VP',))]
# 2023-04-17 15:14:00 INFO: Verifying the transition sequences for 8642 trees
# 100%|█████████████████████████████████████| 8642/8642 [00:05<00:00, 1695.96it/s]
# 2023-04-17 15:14:05 INFO: Verifying the transition sequences for 994 trees
# 100%|███████████████████████████████████████| 994/994 [00:00<00:00, 1620.74it/s]
# 2023-04-17 15:14:06 INFO: Using the following open nodes:
#   ("A'",)
#   ("ADV'",)
#   ('ADVP',)
#   ('AP',)
#   ("ART'",)
#   ("C'",)
#   ("CARD'",)
#   ("CONJ'",)
#   ('CONJP',)
#   ('CP',)
#   ("ITJ'",)
#   ("N'",)
#   ('NP',)
#   ("P'",)
#   ("PERCENT'",)
#   ('PERCENTP',)
#   ("POSS'",)
#   ('PP',)
#   ("QNT'",)
#   ('ROOT',)
#   ('S',)
#   ("V'",)
#   ('VP',)
# Some weights of the model checkpoint at neuralmind/bert-large-portuguese-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-04-17 15:14:13 INFO: Warming up model for 10 iterations using AdaDelta to train the embeddings
# 2023-04-17 15:14:13 INFO: Building Adadelta with lr=1.000000, eps=0.000001, weight_decay=0.020000, rho=0.900000
# 2023-04-17 15:14:13 INFO: Number of words in the training set found in the embedding: 14427 out of 15504
# 2023-04-17 15:14:13 INFO: Building CrossEntropyLoss(sum)
# 2023-04-17 15:14:14 INFO: Starting epoch 1
# 100%|████████████████████████████████| 167/167 [21:58<00:00,  7.89s/it, Epoch 1]
# 2023-04-17 15:36:12 INFO: Transitions correct: 106688
#   Counter({'Shift': 44283, 'Close': 31896, 'Open': 30509})
# 2023-04-17 15:36:12 INFO: Transitions incorrect: 59213
#   Counter({('Open', 'Open'): 16528, ('Open', 'Close'): 12997, ('Close', 'Open'): 7334, ('Open', 'Shift'): 6850, ('Shift', 'Close'): 5959, ('Close', 'Shift'): 5299, ('Shift', 'Open'): 4246})
# 2023-04-17 15:36:12 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 13608, <RepairType.WRONG_OPEN_GENERAL: 4>: 10714, <RepairType.OPEN_CLOSE: 7>: 7126, <RepairType.SHIFT_CLOSE: 8>: 5833, <RepairType.OPEN_SHIFT: 6>: 4613, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 3145, <RepairType.MISSED_UNARY: 5>: 2273, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 1364, <RepairType.CLOSE_SHIFT_NESTED: 9>: 1254, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 591})
# 2023-04-17 15:36:12 INFO: Fake transitions used: 27
# 2023-04-17 15:36:12 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [03:57<00:00,  4.19it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 74.58 LR: 69.76 F1: 72.09 Exact: 14.38 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 74.58 LR: 69.76 F1: 72.09 Exact: 14.38 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 15:40:24 INFO: New best dev score: 0.72098 > 0.00000
# 2023-04-17 15:40:24 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency.pt
# 2023-04-17 15:40:24 INFO: Epoch 1 finished
#   Transitions correct: Counter({'Shift': 44283, 'Close': 31896, 'Open': 30509})
#   Transitions incorrect: Counter({('Open', 'Open'): 16528, ('Open', 'Close'): 12997, ('Close', 'Open'): 7334, ('Open', 'Shift'): 6850, ('Shift', 'Close'): 5959, ('Close', 'Shift'): 5299, ('Shift', 'Open'): 4246})
#   Total loss for epoch: 220245.68475
#   Dev score      (    1): 0.720976
#   Best dev score (    1): 0.720976
# 2023-04-17 15:40:24 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 15:40:24 INFO: Starting epoch 2
# 100%|████████████████████████████████| 167/167 [50:04<00:00, 17.99s/it, Epoch 2]
# 2023-04-17 16:30:29 INFO: Transitions correct: 148404
#   Counter({'Shift': 52138, 'Open': 48837, 'Close': 47429})
# 2023-04-17 16:30:29 INFO: Transitions incorrect: 22387
#   Counter({('Open', 'Open'): 7090, ('Open', 'Close'): 6179, ('Close', 'Open'): 3278, ('Close', 'Shift'): 2114, ('Shift', 'Close'): 1802, ('Shift', 'Open'): 1176, ('Open', 'Shift'): 748})
# 2023-04-17 16:30:29 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 5981, <RepairType.WRONG_OPEN_GENERAL: 4>: 4301, <RepairType.OPEN_CLOSE: 7>: 4038, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1935, <RepairType.SHIFT_CLOSE: 8>: 1815, <RepairType.MISSED_UNARY: 5>: 1423, <RepairType.CLOSE_SHIFT_NESTED: 9>: 746, <RepairType.OPEN_SHIFT: 6>: 532, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 363, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 272})
# 2023-04-17 16:30:29 INFO: Fake transitions used: 40
# 2023-04-17 16:30:29 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [04:28<00:00,  3.70it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 85.5 LR: 82.02 F1: 83.72 Exact: 36.21 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 85.5 LR: 82.02 F1: 83.72 Exact: 36.21 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 16:35:14 INFO: New best dev score: 0.83728 > 0.72098
# 2023-04-17 16:35:14 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency.pt
# 2023-04-17 16:35:14 INFO: Epoch 2 finished
#   Transitions correct: Counter({'Shift': 52138, 'Open': 48837, 'Close': 47429})
#   Transitions incorrect: Counter({('Open', 'Open'): 7090, ('Open', 'Close'): 6179, ('Close', 'Open'): 3278, ('Close', 'Shift'): 2114, ('Shift', 'Close'): 1802, ('Shift', 'Open'): 1176, ('Open', 'Shift'): 748})
#   Total loss for epoch: 75921.07404
#   Dev score      (    2): 0.837277
#   Best dev score (    2): 0.837277
# 2023-04-17 16:35:14 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 16:35:15 INFO: Starting epoch 3
# 100%|████████████████████████████████| 167/167 [21:27<00:00,  7.71s/it, Epoch 3]
# 2023-04-17 16:56:42 INFO: Transitions correct: 159717
#   Counter({'Open': 53918, 'Shift': 53247, 'Close': 52552})
# 2023-04-17 16:56:42 INFO: Transitions incorrect: 13640
#   Counter({('Open', 'Open'): 4387, ('Open', 'Close'): 3550, ('Close', 'Open'): 2120, ('Close', 'Shift'): 1347, ('Shift', 'Close'): 1274, ('Shift', 'Open'): 563, ('Open', 'Shift'): 399})
# 2023-04-17 16:56:42 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 3808, <RepairType.WRONG_OPEN_GENERAL: 4>: 2753, <RepairType.OPEN_CLOSE: 7>: 2357, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1319, <RepairType.SHIFT_CLOSE: 8>: 1299, <RepairType.MISSED_UNARY: 5>: 936, <RepairType.CLOSE_SHIFT_NESTED: 9>: 514, <RepairType.OPEN_SHIFT: 6>: 303, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 220, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 88})
# 2023-04-17 16:56:42 INFO: Fake transitions used: 54
# 2023-04-17 16:56:42 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [04:24<00:00,  3.75it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 88.66 LR: 86.66 F1: 87.65 Exact: 42.05 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 88.66 LR: 86.66 F1: 87.65 Exact: 42.05 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 17:01:24 INFO: New best dev score: 0.87658 > 0.83728
# 2023-04-17 17:01:24 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency.pt
# 2023-04-17 17:01:24 INFO: Epoch 3 finished
#   Transitions correct: Counter({'Open': 53918, 'Shift': 53247, 'Close': 52552})
#   Transitions incorrect: Counter({('Open', 'Open'): 4387, ('Open', 'Close'): 3550, ('Close', 'Open'): 2120, ('Close', 'Shift'): 1347, ('Shift', 'Close'): 1274, ('Shift', 'Open'): 563, ('Open', 'Shift'): 399})
#   Total loss for epoch: 44658.28749
#   Dev score      (    3): 0.876582
#   Best dev score (    3): 0.876582
# 2023-04-17 17:01:24 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 17:01:24 INFO: Starting epoch 4
# 100%|████████████████████████████████| 167/167 [21:59<00:00,  7.90s/it, Epoch 4]
# 2023-04-17 17:23:23 INFO: Transitions correct: 161965
#   Counter({'Open': 55051, 'Close': 53971, 'Shift': 52943})
# 2023-04-17 17:23:23 INFO: Transitions incorrect: 10413
#   Counter({('Open', 'Open'): 3373, ('Open', 'Close'): 2598, ('Close', 'Open'): 1627, ('Shift', 'Close'): 1108, ('Close', 'Shift'): 1004, ('Shift', 'Open'): 405, ('Open', 'Shift'): 298})
# 2023-04-17 17:23:23 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 2836, <RepairType.WRONG_OPEN_GENERAL: 4>: 2151, <RepairType.OPEN_CLOSE: 7>: 1701, <RepairType.SHIFT_CLOSE: 8>: 1116, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 984, <RepairType.MISSED_UNARY: 5>: 753, <RepairType.CLOSE_SHIFT_NESTED: 9>: 374, <RepairType.OPEN_SHIFT: 6>: 230, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 167, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 61})
# 2023-04-17 17:23:23 INFO: Fake transitions used: 56
# 2023-04-17 17:23:23 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [04:24<00:00,  3.75it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 86.91 LR: 85.42 F1: 86.16 Exact: 42.25 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 86.91 LR: 85.42 F1: 86.16 Exact: 42.25 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 17:28:02 INFO: Epoch 4 finished
#   Transitions correct: Counter({'Open': 55051, 'Close': 53971, 'Shift': 52943})
#   Transitions incorrect: Counter({('Open', 'Open'): 3373, ('Open', 'Close'): 2598, ('Close', 'Open'): 1627, ('Shift', 'Close'): 1108, ('Close', 'Shift'): 1004, ('Shift', 'Open'): 405, ('Open', 'Shift'): 298})
#   Total loss for epoch: 34411.18360
#   Dev score      (    4): 0.861632
#   Best dev score (    3): 0.876582
# 2023-04-17 17:28:02 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 17:28:02 INFO: Starting epoch 5
# 100%|████████████████████████████████| 167/167 [21:33<00:00,  7.75s/it, Epoch 5]
# 2023-04-17 17:49:36 INFO: Transitions correct: 165827
#   Counter({'Open': 56344, 'Close': 55510, 'Shift': 53973})
# 2023-04-17 17:49:36 INFO: Transitions incorrect: 9396
#   Counter({('Open', 'Open'): 3077, ('Open', 'Close'): 2421, ('Close', 'Open'): 1514, ('Shift', 'Close'): 898, ('Close', 'Shift'): 860, ('Shift', 'Open'): 344, ('Open', 'Shift'): 282})
# 2023-04-17 17:49:36 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 2524, <RepairType.WRONG_OPEN_GENERAL: 4>: 1965, <RepairType.OPEN_CLOSE: 7>: 1622, <RepairType.SHIFT_CLOSE: 8>: 909, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 879, <RepairType.MISSED_UNARY: 5>: 646, <RepairType.CLOSE_SHIFT_NESTED: 9>: 348, <RepairType.OPEN_SHIFT: 6>: 223, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 170, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 58})
# 2023-04-17 17:49:36 INFO: Fake transitions used: 48
# 2023-04-17 17:49:36 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [04:18<00:00,  3.84it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 89.76 LR: 88.6 F1: 89.18 Exact: 52.01 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 89.76 LR: 88.6 F1: 89.18 Exact: 52.01 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 17:54:10 INFO: New best dev score: 0.89181 > 0.87658
# 2023-04-17 17:54:10 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency.pt
# 2023-04-17 17:54:10 INFO: Epoch 5 finished
#   Transitions correct: Counter({'Open': 56344, 'Close': 55510, 'Shift': 53973})
#   Transitions incorrect: Counter({('Open', 'Open'): 3077, ('Open', 'Close'): 2421, ('Close', 'Open'): 1514, ('Shift', 'Close'): 898, ('Close', 'Shift'): 860, ('Shift', 'Open'): 344, ('Open', 'Shift'): 282})
#   Total loss for epoch: 31305.27266
#   Dev score      (    5): 0.891814
#   Best dev score (    5): 0.891814
# 2023-04-17 17:54:10 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 17:54:10 INFO: Starting epoch 6
# 100%|████████████████████████████████| 167/167 [22:30<00:00,  8.09s/it, Epoch 6]
# 2023-04-17 18:16:41 INFO: Transitions correct: 165899
#   Counter({'Open': 56496, 'Close': 55871, 'Shift': 53532})
# 2023-04-17 18:16:41 INFO: Transitions incorrect: 7581
#   Counter({('Open', 'Open'): 2558, ('Open', 'Close'): 1934, ('Close', 'Open'): 1194, ('Close', 'Shift'): 720, ('Shift', 'Close'): 699, ('Shift', 'Open'): 268, ('Open', 'Shift'): 208})
# 2023-04-17 18:16:41 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 1991, <RepairType.WRONG_OPEN_GENERAL: 4>: 1572, <RepairType.OPEN_CLOSE: 7>: 1277, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 774, <RepairType.SHIFT_CLOSE: 8>: 707, <RepairType.MISSED_UNARY: 5>: 560, <RepairType.CLOSE_SHIFT_NESTED: 9>: 309, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 169, <RepairType.OPEN_SHIFT: 6>: 163, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 41})
# 2023-04-17 18:16:41 INFO: Fake transitions used: 65
# 2023-04-17 18:16:41 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [04:09<00:00,  3.99it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 91.43 LR: 90.65 F1: 91.04 Exact: 56.74 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 91.43 LR: 90.65 F1: 91.04 Exact: 56.74 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 18:21:06 INFO: New best dev score: 0.91040 > 0.89181
# 2023-04-17 18:21:06 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency.pt
# 2023-04-17 18:21:06 INFO: Epoch 6 finished
#   Transitions correct: Counter({'Open': 56496, 'Close': 55871, 'Shift': 53532})
#   Transitions incorrect: Counter({('Open', 'Open'): 2558, ('Open', 'Close'): 1934, ('Close', 'Open'): 1194, ('Close', 'Shift'): 720, ('Shift', 'Close'): 699, ('Shift', 'Open'): 268, ('Open', 'Shift'): 208})
#   Total loss for epoch: 25364.67642
#   Dev score      (    6): 0.910401
#   Best dev score (    6): 0.910401
# 2023-04-17 18:21:06 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 18:21:06 INFO: Starting epoch 7
# 100%|████████████████████████████████| 167/167 [22:50<00:00,  8.20s/it, Epoch 7]
# 2023-04-17 18:43:56 INFO: Transitions correct: 167742
#   Counter({'Open': 57175, 'Close': 56491, 'Shift': 54076})
# 2023-04-17 18:43:56 INFO: Transitions incorrect: 8134
#   Counter({('Open', 'Open'): 2683, ('Open', 'Close'): 1963, ('Close', 'Open'): 1289, ('Close', 'Shift'): 857, ('Shift', 'Close'): 834, ('Shift', 'Open'): 281, ('Open', 'Shift'): 227})
# 2023-04-17 18:43:56 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 2142, <RepairType.WRONG_OPEN_GENERAL: 4>: 1517, <RepairType.OPEN_CLOSE: 7>: 1264, <RepairType.SHIFT_CLOSE: 8>: 834, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 714, <RepairType.MISSED_UNARY: 5>: 518, <RepairType.CLOSE_SHIFT_NESTED: 9>: 281, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 226, <RepairType.OPEN_SHIFT: 6>: 183, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 131})
# 2023-04-17 18:43:56 INFO: Fake transitions used: 58
# 2023-04-17 18:43:56 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [04:33<00:00,  3.64it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 92.31 LR: 91.35 F1: 91.82 Exact: 57.94 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 92.31 LR: 91.35 F1: 91.82 Exact: 57.94 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 18:48:45 INFO: New best dev score: 0.91829 > 0.91040
# 2023-04-17 18:48:46 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency.pt
# 2023-04-17 18:48:46 INFO: Epoch 7 finished
#   Transitions correct: Counter({'Open': 57175, 'Close': 56491, 'Shift': 54076})
#   Transitions incorrect: Counter({('Open', 'Open'): 2683, ('Open', 'Close'): 1963, ('Close', 'Open'): 1289, ('Close', 'Shift'): 857, ('Shift', 'Close'): 834, ('Shift', 'Open'): 281, ('Open', 'Shift'): 227})
#   Total loss for epoch: 27887.62422
#   Dev score      (    7): 0.918288
#   Best dev score (    7): 0.918288
# 2023-04-17 18:48:46 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 18:48:46 INFO: Starting epoch 8
# 100%|████████████████████████████████| 167/167 [22:26<00:00,  8.07s/it, Epoch 8]
# 2023-04-17 19:11:13 INFO: Transitions correct: 168856
#   Counter({'Open': 57654, 'Close': 56989, 'Shift': 54213})
# 2023-04-17 19:11:13 INFO: Transitions incorrect: 6616
#   Counter({('Open', 'Open'): 2187, ('Open', 'Close'): 1679, ('Close', 'Open'): 1052, ('Shift', 'Close'): 654, ('Close', 'Shift'): 618, ('Shift', 'Open'): 232, ('Open', 'Shift'): 194})
# 2023-04-17 19:11:13 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 1746, <RepairType.WRONG_OPEN_GENERAL: 4>: 1369, <RepairType.OPEN_CLOSE: 7>: 1138, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 669, <RepairType.SHIFT_CLOSE: 8>: 660, <RepairType.MISSED_UNARY: 5>: 458, <RepairType.CLOSE_SHIFT_NESTED: 9>: 245, <RepairType.OPEN_SHIFT: 6>: 168, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 122, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 24})
# 2023-04-17 19:11:13 INFO: Fake transitions used: 48
# 2023-04-17 19:11:13 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [04:36<00:00,  3.59it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.3 sec].
# pcfg LP/LR summary evalb: LP: 92.2 LR: 91.37 F1: 91.78 Exact: 58.35 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 92.2 LR: 91.37 F1: 91.78 Exact: 58.35 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 19:16:06 INFO: Epoch 8 finished
#   Transitions correct: Counter({'Open': 57654, 'Close': 56989, 'Shift': 54213})
#   Transitions incorrect: Counter({('Open', 'Open'): 2187, ('Open', 'Close'): 1679, ('Close', 'Open'): 1052, ('Shift', 'Close'): 654, ('Close', 'Shift'): 618, ('Shift', 'Open'): 232, ('Open', 'Shift'): 194})
#   Total loss for epoch: 21900.10533
#   Dev score      (    8): 0.917868
#   Best dev score (    7): 0.918288
# 2023-04-17 19:16:06 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 19:16:06 INFO: Starting epoch 9
# 100%|████████████████████████████████| 167/167 [21:39<00:00,  7.78s/it, Epoch 9]
# 2023-04-17 19:37:46 INFO: Transitions correct: 166990
#   Counter({'Open': 57139, 'Close': 56467, 'Shift': 53384})
# 2023-04-17 19:37:46 INFO: Transitions incorrect: 6995
#   Counter({('Open', 'Open'): 2209, ('Open', 'Close'): 1700, ('Close', 'Open'): 1104, ('Close', 'Shift'): 820, ('Shift', 'Close'): 750, ('Shift', 'Open'): 216, ('Open', 'Shift'): 196})
# 2023-04-17 19:37:46 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 1832, <RepairType.WRONG_OPEN_GENERAL: 4>: 1225, <RepairType.OPEN_CLOSE: 7>: 1026, <RepairType.SHIFT_CLOSE: 8>: 734, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 578, <RepairType.MISSED_UNARY: 5>: 438, <RepairType.CLOSE_SHIFT_NESTED: 9>: 263, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 203, <RepairType.OPEN_SHIFT: 6>: 163, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 130})
# 2023-04-17 19:37:46 INFO: Fake transitions used: 60
# 2023-04-17 19:37:46 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [04:21<00:00,  3.81it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 92.83 LR: 91.68 F1: 92.25 Exact: 58.04 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 92.83 LR: 91.68 F1: 92.25 Exact: 58.04 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 19:42:24 INFO: New best dev score: 0.92257 > 0.91829
# 2023-04-17 19:42:24 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency.pt
# 2023-04-17 19:42:24 INFO: Epoch 9 finished
#   Transitions correct: Counter({'Open': 57139, 'Close': 56467, 'Shift': 53384})
#   Transitions incorrect: Counter({('Open', 'Open'): 2209, ('Open', 'Close'): 1700, ('Close', 'Open'): 1104, ('Close', 'Shift'): 820, ('Shift', 'Close'): 750, ('Shift', 'Open'): 216, ('Open', 'Shift'): 196})
#   Total loss for epoch: 25478.00241
#   Dev score      (    9): 0.922573
#   Best dev score (    9): 0.922573
# 2023-04-17 19:42:24 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 19:42:24 INFO: Starting epoch 10
# 100%|███████████████████████████████| 167/167 [21:21<00:00,  7.68s/it, Epoch 10]
# 2023-04-17 20:03:46 INFO: Transitions correct: 169206
#   Counter({'Open': 57858, 'Close': 57391, 'Shift': 53957})
# 2023-04-17 20:03:46 INFO: Transitions incorrect: 5559
#   Counter({('Open', 'Open'): 1829, ('Open', 'Close'): 1493, ('Close', 'Open'): 924, ('Shift', 'Close'): 489, ('Close', 'Shift'): 454, ('Shift', 'Open'): 205, ('Open', 'Shift'): 165})
# 2023-04-17 20:03:46 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 1486, <RepairType.WRONG_OPEN_GENERAL: 4>: 1148, <RepairType.OPEN_CLOSE: 7>: 996, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 538, <RepairType.SHIFT_CLOSE: 8>: 495, <RepairType.MISSED_UNARY: 5>: 412, <RepairType.CLOSE_SHIFT_NESTED: 9>: 200, <RepairType.OPEN_SHIFT: 6>: 136, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 121, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 22})
# 2023-04-17 20:03:46 INFO: Fake transitions used: 59
# 2023-04-17 20:03:46 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [03:59<00:00,  4.15it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 92.74 LR: 91.94 F1: 92.34 Exact: 60.46 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 92.74 LR: 91.94 F1: 92.34 Exact: 60.46 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 20:08:00 INFO: New best dev score: 0.92343 > 0.92257
# 2023-04-17 20:08:00 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency.pt
# 2023-04-17 20:08:00 INFO: Epoch 10 finished
#   Transitions correct: Counter({'Open': 57858, 'Close': 57391, 'Shift': 53957})
#   Transitions incorrect: Counter({('Open', 'Open'): 1829, ('Open', 'Close'): 1493, ('Close', 'Open'): 924, ('Shift', 'Close'): 489, ('Close', 'Shift'): 454, ('Shift', 'Open'): 205, ('Open', 'Shift'): 165})
#   Total loss for epoch: 18841.73862
#   Dev score      (   10): 0.923434
#   Best dev score (   10): 0.923434
# 2023-04-17 20:08:00 INFO: Finished stage at epoch 10.  Restarting optimizer
# 2023-04-17 20:08:00 INFO: Previous best model was at epoch 10
# 2023-04-17 20:08:00 INFO: Switching to a model with 0 pattn layers and NO lattn
# 2023-04-17 20:08:01 INFO: Building AdamW with lr=0.000200, beta2=0.999000, eps=0.000000, weight_decay=0.050000
# 2023-04-17 20:08:01 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 20:08:01 INFO: Starting epoch 11
# 100%|███████████████████████████████| 167/167 [20:08<00:00,  7.24s/it, Epoch 11]
# 2023-04-17 20:28:09 INFO: Transitions correct: 171606
#   Counter({'Open': 58836, 'Close': 58501, 'Shift': 54269})
# 2023-04-17 20:28:09 INFO: Transitions incorrect: 3724
#   Counter({('Open', 'Open'): 1237, ('Open', 'Close'): 934, ('Close', 'Open'): 632, ('Shift', 'Close'): 350, ('Close', 'Shift'): 340, ('Shift', 'Open'): 128, ('Open', 'Shift'): 103})
# 2023-04-17 20:28:09 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 1011, <RepairType.WRONG_OPEN_GENERAL: 4>: 768, <RepairType.OPEN_CLOSE: 7>: 597, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 383, <RepairType.SHIFT_CLOSE: 8>: 351, <RepairType.MISSED_UNARY: 5>: 281, <RepairType.CLOSE_SHIFT_NESTED: 9>: 160, <RepairType.OPEN_SHIFT: 6>: 86, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 78, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 8})
# 2023-04-17 20:28:09 INFO: Fake transitions used: 54
# 2023-04-17 20:28:09 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [03:56<00:00,  4.21it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 94.56 LR: 94.19 F1: 94.38 Exact: 68.91 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.56 LR: 94.19 F1: 94.38 Exact: 68.91 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 20:32:20 INFO: New best dev score: 0.94381 > 0.92343
# 2023-04-17 20:32:20 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency.pt
# 2023-04-17 20:32:20 INFO: Epoch 11 finished
#   Transitions correct: Counter({'Open': 58836, 'Close': 58501, 'Shift': 54269})
#   Transitions incorrect: Counter({('Open', 'Open'): 1237, ('Open', 'Close'): 934, ('Close', 'Open'): 632, ('Shift', 'Close'): 350, ('Close', 'Shift'): 340, ('Shift', 'Open'): 128, ('Open', 'Shift'): 103})
#   Total loss for epoch: 11806.98015
#   Dev score      (   11): 0.943809
#   Best dev score (   11): 0.943809
# 2023-04-17 20:32:20 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 20:32:20 INFO: Starting epoch 12
# 100%|███████████████████████████████| 167/167 [19:46<00:00,  7.10s/it, Epoch 12]
# 2023-04-17 20:52:06 INFO: Transitions correct: 173953
#   Counter({'Open': 59741, 'Close': 59467, 'Shift': 54745})
# 2023-04-17 20:52:06 INFO: Transitions incorrect: 2996
#   Counter({('Open', 'Open'): 985, ('Open', 'Close'): 793, ('Close', 'Open'): 481, ('Shift', 'Close'): 301, ('Close', 'Shift'): 260, ('Shift', 'Open'): 102, ('Open', 'Shift'): 74})
# 2023-04-17 20:52:06 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 791, <RepairType.WRONG_OPEN_GENERAL: 4>: 588, <RepairType.OPEN_CLOSE: 7>: 516, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 326, <RepairType.SHIFT_CLOSE: 8>: 305, <RepairType.MISSED_UNARY: 5>: 232, <RepairType.CLOSE_SHIFT_NESTED: 9>: 105, <RepairType.OPEN_SHIFT: 6>: 62, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 62, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 9})
# 2023-04-17 20:52:06 INFO: Fake transitions used: 54
# 2023-04-17 20:52:06 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [03:56<00:00,  4.20it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 94.84 LR: 94.23 F1: 94.53 Exact: 68.91 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.84 LR: 94.23 F1: 94.53 Exact: 68.91 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 20:56:17 INFO: New best dev score: 0.94539 > 0.94381
# 2023-04-17 20:56:17 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency.pt
# 2023-04-17 20:56:17 INFO: Epoch 12 finished
#   Transitions correct: Counter({'Open': 59741, 'Close': 59467, 'Shift': 54745})
#   Transitions incorrect: Counter({('Open', 'Open'): 985, ('Open', 'Close'): 793, ('Close', 'Open'): 481, ('Shift', 'Close'): 301, ('Close', 'Shift'): 260, ('Shift', 'Open'): 102, ('Open', 'Shift'): 74})
#   Total loss for epoch: 9928.25080
#   Dev score      (   12): 0.945394
#   Best dev score (   12): 0.945394
# 2023-04-17 20:56:17 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 20:56:17 INFO: Starting epoch 13
# 100%|███████████████████████████████| 167/167 [19:41<00:00,  7.08s/it, Epoch 13]
# 2023-04-17 21:15:59 INFO: Transitions correct: 172506
#   Counter({'Open': 59276, 'Close': 59020, 'Shift': 54210})
# 2023-04-17 21:15:59 INFO: Transitions incorrect: 2766
#   Counter({('Open', 'Open'): 890, ('Open', 'Close'): 711, ('Close', 'Open'): 489, ('Close', 'Shift'): 265, ('Shift', 'Close'): 252, ('Shift', 'Open'): 86, ('Open', 'Shift'): 73})
# 2023-04-17 21:15:59 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 783, <RepairType.WRONG_OPEN_GENERAL: 4>: 546, <RepairType.OPEN_CLOSE: 7>: 454, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 266, <RepairType.SHIFT_CLOSE: 8>: 253, <RepairType.MISSED_UNARY: 5>: 205, <RepairType.CLOSE_SHIFT_NESTED: 9>: 119, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 67, <RepairType.OPEN_SHIFT: 6>: 62, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 11})
# 2023-04-17 21:15:59 INFO: Fake transitions used: 40
# 2023-04-17 21:15:59 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [03:56<00:00,  4.21it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 94.74 LR: 94.22 F1: 94.48 Exact: 68.81 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.74 LR: 94.22 F1: 94.48 Exact: 68.81 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 21:20:09 INFO: Epoch 13 finished
#   Transitions correct: Counter({'Open': 59276, 'Close': 59020, 'Shift': 54210})
#   Transitions incorrect: Counter({('Open', 'Open'): 890, ('Open', 'Close'): 711, ('Close', 'Open'): 489, ('Close', 'Shift'): 265, ('Shift', 'Close'): 252, ('Shift', 'Open'): 86, ('Open', 'Shift'): 73})
#   Total loss for epoch: 8737.85581
#   Dev score      (   13): 0.944807
#   Best dev score (   12): 0.945394
# 2023-04-17 21:20:09 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 21:20:09 INFO: Starting epoch 14
# 100%|███████████████████████████████| 167/167 [19:59<00:00,  7.18s/it, Epoch 14]
# 2023-04-17 21:40:08 INFO: Transitions correct: 172917
#   Counter({'Open': 59493, 'Close': 59156, 'Shift': 54268})
# 2023-04-17 21:40:08 INFO: Transitions incorrect: 2630
#   Counter({('Open', 'Open'): 852, ('Open', 'Close'): 719, ('Close', 'Open'): 429, ('Close', 'Shift'): 248, ('Shift', 'Close'): 233, ('Shift', 'Open'): 75, ('Open', 'Shift'): 74})
# 2023-04-17 21:40:08 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 681, <RepairType.WRONG_OPEN_GENERAL: 4>: 520, <RepairType.OPEN_CLOSE: 7>: 470, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 270, <RepairType.SHIFT_CLOSE: 8>: 234, <RepairType.MISSED_UNARY: 5>: 224, <RepairType.CLOSE_SHIFT_NESTED: 9>: 105, <RepairType.OPEN_SHIFT: 6>: 64, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 54, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 8})
# 2023-04-17 21:40:08 INFO: Fake transitions used: 62
# 2023-04-17 21:40:08 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [03:56<00:00,  4.21it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 94.84 LR: 94.41 F1: 94.62 Exact: 70.72 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.84 LR: 94.41 F1: 94.62 Exact: 70.72 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 21:44:18 INFO: New best dev score: 0.94630 > 0.94539
# 2023-04-17 21:44:18 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency.pt
# 2023-04-17 21:44:18 INFO: Epoch 14 finished
#   Transitions correct: Counter({'Open': 59493, 'Close': 59156, 'Shift': 54268})
#   Transitions incorrect: Counter({('Open', 'Open'): 852, ('Open', 'Close'): 719, ('Close', 'Open'): 429, ('Close', 'Shift'): 248, ('Shift', 'Close'): 233, ('Shift', 'Open'): 75, ('Open', 'Shift'): 74})
#   Total loss for epoch: 8562.59364
#   Dev score      (   14): 0.946298
#   Best dev score (   14): 0.946298
# 2023-04-17 21:44:18 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 21:44:18 INFO: Starting epoch 15
# 100%|███████████████████████████████| 167/167 [19:35<00:00,  7.04s/it, Epoch 15]
# 2023-04-17 22:03:53 INFO: Transitions correct: 173685
#   Counter({'Open': 59760, 'Close': 59506, 'Shift': 54419})
# 2023-04-17 22:03:53 INFO: Transitions incorrect: 2368
#   Counter({('Open', 'Open'): 751, ('Open', 'Close'): 641, ('Close', 'Open'): 390, ('Close', 'Shift'): 229, ('Shift', 'Close'): 225, ('Shift', 'Open'): 67, ('Open', 'Shift'): 65})
# 2023-04-17 22:03:53 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 614, <RepairType.WRONG_OPEN_GENERAL: 4>: 446, <RepairType.OPEN_CLOSE: 7>: 424, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 243, <RepairType.SHIFT_CLOSE: 8>: 226, <RepairType.MISSED_UNARY: 5>: 189, <RepairType.CLOSE_SHIFT_NESTED: 9>: 108, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 56, <RepairType.OPEN_SHIFT: 6>: 55, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 6})
# 2023-04-17 22:03:53 INFO: Fake transitions used: 61
# 2023-04-17 22:03:53 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [04:14<00:00,  3.90it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 95.0 LR: 94.46 F1: 94.73 Exact: 70.02 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 95.0 LR: 94.46 F1: 94.73 Exact: 70.02 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 22:08:24 INFO: New best dev score: 0.94736 > 0.94630
# 2023-04-17 22:08:24 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency.pt
# 2023-04-17 22:08:24 INFO: Epoch 15 finished
#   Transitions correct: Counter({'Open': 59760, 'Close': 59506, 'Shift': 54419})
#   Transitions incorrect: Counter({('Open', 'Open'): 751, ('Open', 'Close'): 641, ('Close', 'Open'): 390, ('Close', 'Shift'): 229, ('Shift', 'Close'): 225, ('Shift', 'Open'): 67, ('Open', 'Shift'): 65})
#   Total loss for epoch: 7552.15718
#   Dev score      (   15): 0.947358
#   Best dev score (   15): 0.947358
# 2023-04-17 22:08:24 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 22:08:24 INFO: Starting epoch 16
# 100%|███████████████████████████████| 167/167 [22:19<00:00,  8.02s/it, Epoch 16]
# 2023-04-17 22:30:43 INFO: Transitions correct: 174043
#   Counter({'Open': 59903, 'Close': 59614, 'Shift': 54526})
# 2023-04-17 22:30:43 INFO: Transitions incorrect: 2358
#   Counter({('Open', 'Open'): 771, ('Open', 'Close'): 601, ('Close', 'Open'): 424, ('Close', 'Shift'): 235, ('Shift', 'Close'): 205, ('Shift', 'Open'): 67, ('Open', 'Shift'): 55})
# 2023-04-17 22:30:43 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 675, <RepairType.WRONG_OPEN_GENERAL: 4>: 482, <RepairType.OPEN_CLOSE: 7>: 382, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 219, <RepairType.SHIFT_CLOSE: 8>: 205, <RepairType.MISSED_UNARY: 5>: 182, <RepairType.CLOSE_SHIFT_NESTED: 9>: 98, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 61, <RepairType.OPEN_SHIFT: 6>: 45, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 9})
# 2023-04-17 22:30:43 INFO: Fake transitions used: 61
# 2023-04-17 22:30:43 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [04:27<00:00,  3.72it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 94.63 LR: 94.14 F1: 94.39 Exact: 68.61 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.63 LR: 94.14 F1: 94.39 Exact: 68.61 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 22:35:26 INFO: Epoch 16 finished
#   Transitions correct: Counter({'Open': 59903, 'Close': 59614, 'Shift': 54526})
#   Transitions incorrect: Counter({('Open', 'Open'): 771, ('Open', 'Close'): 601, ('Close', 'Open'): 424, ('Close', 'Shift'): 235, ('Shift', 'Close'): 205, ('Shift', 'Open'): 67, ('Open', 'Shift'): 55})
#   Total loss for epoch: 7460.73029
#   Dev score      (   16): 0.943916
#   Best dev score (   15): 0.947358
# 2023-04-17 22:35:27 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 22:35:27 INFO: Starting epoch 17
# 100%|███████████████████████████████| 167/167 [22:38<00:00,  8.14s/it, Epoch 17]
# 2023-04-17 22:58:05 INFO: Transitions correct: 172638
#   Counter({'Open': 59373, 'Close': 59153, 'Shift': 54112})
# 2023-04-17 22:58:05 INFO: Transitions incorrect: 2092
#   Counter({('Open', 'Open'): 682, ('Open', 'Close'): 528, ('Close', 'Open'): 350, ('Shift', 'Close'): 208, ('Close', 'Shift'): 200, ('Shift', 'Open'): 65, ('Open', 'Shift'): 59})
# 2023-04-17 22:58:05 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 548, <RepairType.WRONG_OPEN_GENERAL: 4>: 402, <RepairType.OPEN_CLOSE: 7>: 334, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 229, <RepairType.SHIFT_CLOSE: 8>: 209, <RepairType.MISSED_UNARY: 5>: 171, <RepairType.CLOSE_SHIFT_NESTED: 9>: 96, <RepairType.OPEN_SHIFT: 6>: 51, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 47, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 3})
# 2023-04-17 22:58:05 INFO: Fake transitions used: 70
# 2023-04-17 22:58:05 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [04:35<00:00,  3.61it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.3 sec].
# pcfg LP/LR summary evalb: LP: 94.93 LR: 94.46 F1: 94.69 Exact: 71.12 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.93 LR: 94.46 F1: 94.69 Exact: 71.12 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 23:02:56 INFO: Epoch 17 finished
#   Transitions correct: Counter({'Open': 59373, 'Close': 59153, 'Shift': 54112})
#   Transitions incorrect: Counter({('Open', 'Open'): 682, ('Open', 'Close'): 528, ('Close', 'Open'): 350, ('Shift', 'Close'): 208, ('Close', 'Shift'): 200, ('Shift', 'Open'): 65, ('Open', 'Shift'): 59})
#   Total loss for epoch: 6669.13174
#   Dev score      (   17): 0.947000
#   Best dev score (   15): 0.947358
# 2023-04-17 23:02:56 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 23:02:56 INFO: Starting epoch 18
# 100%|███████████████████████████████| 167/167 [22:05<00:00,  7.94s/it, Epoch 18]
# 2023-04-17 23:25:02 INFO: Transitions correct: 173654
#   Counter({'Open': 59799, 'Close': 59507, 'Shift': 54348})
# 2023-04-17 23:25:02 INFO: Transitions incorrect: 2052
#   Counter({('Open', 'Open'): 633, ('Open', 'Close'): 555, ('Close', 'Open'): 353, ('Shift', 'Close'): 207, ('Close', 'Shift'): 207, ('Shift', 'Open'): 56, ('Open', 'Shift'): 41})
# 2023-04-17 23:25:02 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 554, <RepairType.WRONG_OPEN_GENERAL: 4>: 366, <RepairType.OPEN_CLOSE: 7>: 334, <RepairType.SHIFT_CLOSE: 8>: 207, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 202, <RepairType.MISSED_UNARY: 5>: 201, <RepairType.CLOSE_SHIFT_NESTED: 9>: 90, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 56, <RepairType.OPEN_SHIFT: 6>: 33, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 9})
# 2023-04-17 23:25:02 INFO: Fake transitions used: 68
# 2023-04-17 23:25:02 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [04:36<00:00,  3.59it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 94.73 LR: 94.35 F1: 94.54 Exact: 70.52 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.73 LR: 94.35 F1: 94.54 Exact: 70.52 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 23:29:56 INFO: Epoch 18 finished
#   Transitions correct: Counter({'Open': 59799, 'Close': 59507, 'Shift': 54348})
#   Transitions incorrect: Counter({('Open', 'Open'): 633, ('Open', 'Close'): 555, ('Close', 'Open'): 353, ('Shift', 'Close'): 207, ('Close', 'Shift'): 207, ('Shift', 'Open'): 56, ('Open', 'Shift'): 41})
#   Total loss for epoch: 6444.98324
#   Dev score      (   18): 0.945461
#   Best dev score (   15): 0.947358
# 2023-04-17 23:29:56 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 23:29:56 INFO: Starting epoch 19
# 100%|███████████████████████████████| 167/167 [21:22<00:00,  7.68s/it, Epoch 19]
# 2023-04-17 23:51:18 INFO: Transitions correct: 174245
#   Counter({'Open': 60018, 'Close': 59749, 'Shift': 54478})
# 2023-04-17 23:51:18 INFO: Transitions incorrect: 1952
#   Counter({('Open', 'Open'): 612, ('Open', 'Close'): 514, ('Close', 'Open'): 346, ('Shift', 'Close'): 195, ('Close', 'Shift'): 177, ('Shift', 'Open'): 60, ('Open', 'Shift'): 48})
# 2023-04-17 23:51:18 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 529, <RepairType.WRONG_OPEN_GENERAL: 4>: 364, <RepairType.OPEN_CLOSE: 7>: 315, <RepairType.SHIFT_CLOSE: 8>: 197, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 196, <RepairType.MISSED_UNARY: 5>: 167, <RepairType.CLOSE_SHIFT_NESTED: 9>: 89, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 48, <RepairType.OPEN_SHIFT: 6>: 43, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 4})
# 2023-04-17 23:51:18 INFO: Fake transitions used: 60
# 2023-04-17 23:51:18 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [03:55<00:00,  4.22it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 94.86 LR: 94.36 F1: 94.61 Exact: 71.02 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 94.86 LR: 94.36 F1: 94.61 Exact: 71.02 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-17 23:55:28 INFO: Epoch 19 finished
#   Transitions correct: Counter({'Open': 60018, 'Close': 59749, 'Shift': 54478})
#   Transitions incorrect: Counter({('Open', 'Open'): 612, ('Open', 'Close'): 514, ('Close', 'Open'): 346, ('Shift', 'Close'): 195, ('Close', 'Shift'): 177, ('Shift', 'Open'): 60, ('Open', 'Shift'): 48})
#   Total loss for epoch: 6178.60784
#   Dev score      (   19): 0.946138
#   Best dev score (   15): 0.947358
# 2023-04-17 23:55:28 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-17 23:55:28 INFO: Starting epoch 20
# 100%|███████████████████████████████| 167/167 [19:40<00:00,  7.07s/it, Epoch 20]
# 2023-04-18 00:15:09 INFO: Transitions correct: 174454
#   Counter({'Open': 60093, 'Close': 59860, 'Shift': 54501})
# 2023-04-18 00:15:09 INFO: Transitions incorrect: 1820
#   Counter({('Open', 'Open'): 575, ('Open', 'Close'): 477, ('Close', 'Open'): 305, ('Shift', 'Close'): 186, ('Close', 'Shift'): 170, ('Shift', 'Open'): 59, ('Open', 'Shift'): 48})
# 2023-04-18 00:15:09 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 479, <RepairType.WRONG_OPEN_GENERAL: 4>: 331, <RepairType.OPEN_CLOSE: 7>: 296, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 194, <RepairType.SHIFT_CLOSE: 8>: 187, <RepairType.MISSED_UNARY: 5>: 159, <RepairType.CLOSE_SHIFT_NESTED: 9>: 86, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 43, <RepairType.OPEN_SHIFT: 6>: 38, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 7})
# 2023-04-18 00:15:09 INFO: Fake transitions used: 58
# 2023-04-18 00:15:09 INFO: Processing 994 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 994/994 [03:55<00:00,  4.22it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 95.17 LR: 94.67 F1: 94.92 Exact: 71.22 N: 994
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 95.17 LR: 94.67 F1: 94.92 Exact: 71.22 N: 994
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 994
# 2023-04-18 00:19:18 INFO: New best dev score: 0.94926 > 0.94736
# 2023-04-18 00:19:18 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency.pt
# 2023-04-18 00:19:18 INFO: Epoch 20 finished
#   Transitions correct: Counter({'Open': 60093, 'Close': 59860, 'Shift': 54501})
#   Transitions incorrect: Counter({('Open', 'Open'): 575, ('Open', 'Close'): 477, ('Close', 'Open'): 305, ('Shift', 'Close'): 186, ('Close', 'Shift'): 170, ('Shift', 'Open'): 59, ('Open', 'Shift'): 48})
#   Total loss for epoch: 5509.09719
#   Dev score      (   20): 0.949262
#   Best dev score (   20): 0.949262
# 2023-04-18 00:19:19 INFO: Model saved to ./output_stanza_pt/pt_cintil_constituency_checkpoint.pt
# 2023-04-18 00:19:19 INFO: Running dev step with args: ['--eval_file', 'data/constituency/pt_cintil_dev.mrg', '--shorthand', 'pt_cintil', '--mode', 'predict', '--retag_method', 'upos', '--wordvec_pretrain_file', '/Users/gonzalojaimovitch/stanza_resources/pt/pretrain/bosque.pt', '--bert_model', 'neuralmind/bert-large-portuguese-cased', '--epochs', '20', '--save_dir', './output_stanza_pt', '--save_name', 'pt_cintil_constituency.pt']
# 2023-04-18 00:19:19 INFO: Running constituency parser in predict mode
# 2023-04-18 00:19:19 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json: 200kB [00:00, 33.7MB/s]
# 2023-04-18 00:19:22 INFO: Loading these models for language: pt (Portuguese):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | bosque  |
# | pos       | bosque  |
# =======================
#
# 2023-04-18 00:19:22 INFO: Using device: cpu
# 2023-04-18 00:19:22 INFO: Loading: tokenize
# 2023-04-18 00:19:22 INFO: Loading: pos
# 2023-04-18 00:19:22 INFO: Done loading processors!
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Some weights of the model checkpoint at neuralmind/bert-large-portuguese-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-04-18 00:19:28 INFO: Reading trees from data/constituency/pt_cintil_dev.mrg
# 2023-04-18 00:19:29 INFO: Read 995 trees for evaluation
# 2023-04-18 00:19:29 INFO: Retagging trees using the upos tags from the default package...
# 100%|████████████████████████████████████████| 995/995 [00:04<00:00, 242.60it/s]
# 2023-04-18 00:19:33 INFO: Retagging finished
# 2023-04-18 00:19:33 INFO: Processing 995 trees from data/constituency/pt_cintil_dev.mrg
# 100%|█████████████████████████████████████████| 995/995 [03:54<00:00,  4.25it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 95.17 LR: 94.66 F1: 94.92 Exact: 71.15 N: 995
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 95.17 LR: 94.66 F1: 94.92 Exact: 71.15 N: 995
# factor Tag summary evalb: LP: 4.17 LR: 4.17 F1: 4.17 Exact: 0.0 N: 995
# 2023-04-18 00:23:41 INFO: F1 score on data/constituency/pt_cintil_dev.mrg: 0.949201
# 2023-04-18 00:23:41 INFO: Running test step with args: ['--eval_file', 'data/constituency/pt_cintil_test.mrg', '--shorthand', 'pt_cintil', '--mode', 'predict', '--retag_method', 'upos', '--wordvec_pretrain_file', '/Users/gonzalojaimovitch/stanza_resources/pt/pretrain/bosque.pt', '--bert_model', 'neuralmind/bert-large-portuguese-cased', '--epochs', '20', '--save_dir', './output_stanza_pt', '--save_name', 'pt_cintil_constituency.pt']
# 2023-04-18 00:23:41 INFO: Running constituency parser in predict mode
# 2023-04-18 00:23:41 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json: 200kB [00:00, 24.4MB/s]
# 2023-04-18 00:23:42 INFO: Loading these models for language: pt (Portuguese):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | bosque  |
# | pos       | bosque  |
# =======================
#
# 2023-04-18 00:23:42 INFO: Using device: cpu
# 2023-04-18 00:23:42 INFO: Loading: tokenize
# 2023-04-18 00:23:42 INFO: Loading: pos
# 2023-04-18 00:23:42 INFO: Done loading processors!
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Some weights of the model checkpoint at neuralmind/bert-large-portuguese-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-04-18 00:23:45 INFO: Reading trees from data/constituency/pt_cintil_test.mrg
# 2023-04-18 00:23:46 INFO: Read 995 trees for evaluation
# 2023-04-18 00:23:46 INFO: Retagging trees using the upos tags from the default package...
# 100%|████████████████████████████████████████| 995/995 [00:04<00:00, 229.82it/s]
# 2023-04-18 00:23:50 INFO: Retagging finished
# 2023-04-18 00:23:50 INFO: Processing 995 trees from data/constituency/pt_cintil_test.mrg
# 100%|█████████████████████████████████████████| 995/995 [03:53<00:00,  4.26it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 93.64 LR: 93.35 F1: 93.49 Exact: 64.42 N: 995
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 93.64 LR: 93.35 F1: 93.49 Exact: 64.42 N: 995
# factor Tag summary evalb: LP: 4.07 LR: 4.07 F1: 4.07 Exact: 0.0 N: 995
# 2023-04-18 00:27:57 INFO: F1 score on data/constituency/pt_cintil_test.mrg: 0.934989
# 33293.73518204689

# %% [markdown]
# ### Turkish

# %%
# !python3 -m stanza.utils.datasets.constituency.prepare_con_dataset tr_starlang
# Out:
# Reading 25329 total files
# 100%|███████████████████████████████████| 22975/22975 [00:19<00:00, 1177.58it/s]
# 100%|███████████████████████████████████████| 959/959 [00:00<00:00, 1477.74it/s]
# 100%|█████████████████████████████████████| 1395/1395 [00:00<00:00, 1795.46it/s]
# Writing 22975 trees to data/constituency/tr_starlang_train.mrg
# Writing 959 trees to data/constituency/tr_starlang_dev.mrg
# Writing 1395 trees to data/constituency/tr_starlang_test.mrg

# %%
import time
start = time.time()

# !python3 -m stanza.utils.training.run_constituency --train tr_starlang --save_dir ./output_stanza_tr --epochs 20

end = time.time()
print(end - start)
# Out:
# 2023-05-14 01:47:18 INFO: Training program called with:
# /Users/gonzalojaimovitch/Desktop/projects/master/constituency_parser/.env/lib/python3.8/site-packages/stanza/utils/training/run_constituency.py --train tr_starlang --save_dir ./output_stanza_tr --epochs 20
# 2023-05-14 01:47:18 INFO: Save file for tr_starlang model: tr_starlang_constituency.pt
# 2023-05-14 01:47:18 INFO: tr_starlang: ./output_stanza_tr/tr_starlang_constituency.pt does not exist, training new model
# 2023-05-14 01:47:18 INFO: Using default pretrain for language, found in /Users/gonzalojaimovitch/stanza_resources/tr/pretrain/imst.pt  To use a different pretrain, specify --wordvec_pretrain_file
# 2023-05-14 01:47:18 INFO: Using model /Users/gonzalojaimovitch/stanza_resources/tr/forward_charlm/conll17.pt for forward charlm
# 2023-05-14 01:47:18 INFO: Using model /Users/gonzalojaimovitch/stanza_resources/tr/backward_charlm/conll17.pt for backward charlm
# 2023-05-14 01:47:18 INFO: Running train step with args: ['--train_file', 'data/constituency/tr_starlang_train.mrg', '--eval_file', 'data/constituency/tr_starlang_dev.mrg', '--shorthand', 'tr_starlang', '--mode', 'train', '--wordvec_pretrain_file', '/Users/gonzalojaimovitch/stanza_resources/tr/pretrain/imst.pt', '--charlm_forward_file', '/Users/gonzalojaimovitch/stanza_resources/tr/forward_charlm/conll17.pt', '--charlm_backward_file', '/Users/gonzalojaimovitch/stanza_resources/tr/backward_charlm/conll17.pt', '--bert_model', 'dbmdz/bert-base-turkish-128k-cased', '--epochs', '20', '--save_dir', './output_stanza_tr', '--save_name', 'tr_starlang_constituency.pt']
# 2023-05-14 01:47:18 WARNING: Multistage training is set.  Best models are with MADGRAD, but it is not installed.  Will use AdamW for the second stage optimizer.  Consider installing MADGRAD
# 2023-05-14 01:47:18 INFO: Running constituency parser in train mode
# 2023-05-14 01:47:18 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json: 216kB [00:00, 86.4MB/s]
# 2023-05-14 01:47:19 INFO: Loading these models for language: tr (Turkish):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | imst    |
# | pos       | imst    |
# =======================
#
# 2023-05-14 01:47:19 INFO: Using device: cpu
# 2023-05-14 01:47:19 INFO: Loading: tokenize
# 2023-05-14 01:47:19 INFO: Loading: pos
# 2023-05-14 01:47:19 INFO: Done loading processors!
# 2023-05-14 01:47:19 INFO: ARGS USED AT TRAINING TIME:
# bert_hidden_layers: 4
# bert_model: dbmdz/bert-base-turkish-128k-cased
# charlm_backward_file: /Users/gonzalojaimovitch/stanza_resources/tr/backward_charlm/conll17.pt
# charlm_forward_file: /Users/gonzalojaimovitch/stanza_resources/tr/forward_charlm/conll17.pt
# checkpoint: True
# checkpoint_save_name: ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# combined_dummy_embedding: True
# constituency_composition: ConstituencyComposition.MAX
# constituent_heads: 8
# constituent_stack: StackHistory.LSTM
# data_dir: data/constituency
# delta_embedding_dim: 100
# device: cpu
# epoch_size: 5000
# epochs: 20
# eval_batch_size: 50
# eval_file: data/constituency/tr_starlang_dev.mrg
# finetune: False
# grad_clipping: None
# hidden_size: 512
# lang: tr
# lattn_attention_dropout: 0.2
# lattn_combine_as_self: False
# lattn_combined_input: True
# lattn_d_ff: 2048
# lattn_d_input_proj: None
# lattn_d_kv: 64
# lattn_d_l: 32
# lattn_d_proj: 64
# lattn_partitioned: True
# lattn_pwff: True
# lattn_q_as_matrix: False
# lattn_relu_dropout: 0.2
# lattn_resdrop: True
# lattn_residual_dropout: 0.2
# learning_beta2: 0.999
# learning_eps: 1e-08
# learning_momentum: None
# learning_rate: 0.0002
# learning_rate_warmup: 0
# learning_rho: 0.9
# learning_weight_decay: 0.05
# load_name: None
# log_norms: False
# loss: cross
# loss_focal_gamma: 2
# lstm_input_dropout: 0.2
# lstm_layer_dropout: 0.0
# maxout_k: None
# mode: train
# multistage: True
# nonlinearity: relu
# num_generate: 0
# num_lstm_layers: 2
# num_output_layers: 3
# num_tree_lstm_layers: 1
# optim: adamw
# oracle_forced_errors: 0.001
# oracle_frequency: 0.8
# oracle_initial_epoch: 1
# oracle_level: None
# pattn_attention_dropout: 0.2
# pattn_bias: False
# pattn_d_ff: 2048
# pattn_d_kv: 64
# pattn_d_model: 1024
# pattn_encoder_max_len: 512
# pattn_morpho_emb_dropout: 0.2
# pattn_num_heads: 8
# pattn_num_layers: 0
# pattn_relu_dropout: 0.1
# pattn_residual_dropout: 0.2
# pattn_timing: sin
# predict_dir: .
# predict_dropout: 0.2
# predict_file: None
# predict_format: {:_O}
# pretrain_max_vocab: 250000
# rare_word_threshold: 0.02
# rare_word_unknown_frequency: 0.02
# reduce_heads: 8
# reduce_position: 128
# relearn_structure: False
# retag_charlm_backward_file: None
# retag_charlm_forward_file: None
# retag_method: xpos
# retag_model_path: None
# retag_package: default
# retag_pretrain_path: None
# retag_xpos: True
# reversed: False
# save_dir: ./output_stanza_tr
# save_each_name: None
# save_name: ./output_stanza_tr/tr_starlang_constituency.pt
# seed: 1234
# sentence_boundary_vectors: SentenceBoundary.EVERYTHING
# shorthand: tr_starlang
# silver_epoch_size: None
# silver_file: None
# silver_remove_duplicates: False
# stage1_learning_rate: 1.0
# tag_embedding_dim: 20
# tag_unknown_frequency: 0.001
# tokenized_file: None
# train_batch_size: 30
# train_file: data/constituency/tr_starlang_train.mrg
# transition_embedding_dim: 20
# transition_heads: 4
# transition_hidden_size: 20
# transition_scheme: TransitionScheme.IN_ORDER
# transition_stack: StackHistory.LSTM
# use_lattn: False
# use_silver_words: True
# wandb: False
# wandb_name: None
# wandb_norm_regex: None
# watch_regex: None
# word_dropout: 0.2
# wordvec_dir: extern_data/wordvec
# wordvec_file:
# wordvec_pretrain_file: /Users/gonzalojaimovitch/stanza_resources/tr/pretrain/imst.pt
#
# 2023-05-14 01:47:19 INFO: Directory ./output_stanza_tr does not exist; creating...
# 2023-05-14 01:47:19 INFO: Reading trees from data/constituency/tr_starlang_train.mrg
# 100%|███████████████████████████████████| 22975/22975 [00:03<00:00, 6726.15it/s]
# 2023-05-14 01:47:26 INFO: Read 22975 trees for the training set
# 2023-05-14 01:47:28 INFO: Filtered 367 duplicates from train dataset
# 2023-05-14 01:47:28 INFO: Eliminated 58 trees with missing structure
# 2023-05-14 01:47:28 INFO: Reading trees from data/constituency/tr_starlang_dev.mrg
# 2023-05-14 01:47:28 INFO: Read 959 trees for the dev set
# 2023-05-14 01:47:28 INFO: Filtered 9 duplicates from dev dataset
# 2023-05-14 01:47:28 INFO: Retagging trees using the xpos tags from the default package...
# 100%|█████████████████████████████████████| 22550/22550 [10:01<00:00, 37.52it/s]
# 100%|█████████████████████████████████████████| 950/950 [00:25<00:00, 37.84it/s]
# 2023-05-14 01:57:54 INFO: Retagging finished
# 2023-05-14 01:57:55 INFO: Unique constituents in training set: ['$', '&', "'", ',', '.', '/', ':', 'ADJP', 'ADVP', 'CONJP', 'DP', 'INTJP', 'NEG', 'NOMP', 'NP', 'NUM', 'PP', 'ROOT', 'S', 'SQ', 'VP', 'WP']
# 2023-05-14 01:57:55 INFO: Constituent node counts: Counter({'NP': 64396, 'S': 23432, 'ROOT': 22550, 'VP': 19289, 'ADJP': 9279, 'PP': 6037, 'NOMP': 4955, 'ADVP': 4939, 'NUM': 2946, 'DP': 422, 'CONJP': 250, 'INTJP': 33, '&': 33, '$': 28, 'WP': 17, '.': 11, 'NEG': 7, '/': 4, ':': 2, ',': 1, 'SQ': 1, "'": 1})
# 2023-05-14 01:57:56 INFO: Unique tags in training set: ['ANum', 'Abr', 'Adj', 'Adverb', 'Conj', 'Demons', 'Det', 'Dup', 'Interj', 'NAdj', 'NNum', 'Neg', 'Ness', 'Noun', 'PCAbl', 'PCAcc', 'PCDat', 'PCIns', 'PCNom', 'Pers', 'Postp', 'Prop', 'Punc', 'Quant', 'Ques', 'Reflex', 'Rel', 'Verb', 'With', 'Zero']
# 2023-05-14 01:57:56 INFO: Building training transition sequences
# 100%|██████████████████████████████████| 22550/22550 [00:01<00:00, 13520.82it/s]
# 2023-05-14 01:57:58 INFO: Building dev transition sequences
# 100%|██████████████████████████████████████| 950/950 [00:00<00:00, 34662.46it/s]
# 2023-05-14 01:57:58 INFO: Building silver transition sequences
# 0it [00:00, ?it/s]
# 2023-05-14 01:57:58 INFO: Total unique transitions in train set: 24
# 2023-05-14 01:57:58 INFO: Unique transitions in training set: [Shift, CloseConstituent, OpenConstituent(("'",)), OpenConstituent(('$',)), OpenConstituent(('&',)), OpenConstituent((',',)), OpenConstituent(('.',)), OpenConstituent(('/',)), OpenConstituent((':',)), OpenConstituent(('ADJP',)), OpenConstituent(('ADVP',)), OpenConstituent(('CONJP',)), OpenConstituent(('DP',)), OpenConstituent(('INTJP',)), OpenConstituent(('NEG',)), OpenConstituent(('NOMP',)), OpenConstituent(('NP',)), OpenConstituent(('NUM',)), OpenConstituent(('PP',)), OpenConstituent(('ROOT',)), OpenConstituent(('S',)), OpenConstituent(('SQ',)), OpenConstituent(('VP',)), OpenConstituent(('WP',))]
# 2023-05-14 01:57:58 INFO: Verifying the transition sequences for 22550 trees
# 100%|███████████████████████████████████| 22550/22550 [00:10<00:00, 2224.32it/s]
# 2023-05-14 01:58:08 INFO: Verifying the transition sequences for 950 trees
# 100%|███████████████████████████████████████| 950/950 [00:00<00:00, 2250.12it/s]
# 2023-05-14 01:58:11 INFO: Using the following open nodes:
#   ('$',)
#   ('&',)
#   ("'",)
#   (',',)
#   ('.',)
#   ('/',)
#   (':',)
#   ('ADJP',)
#   ('ADVP',)
#   ('CONJP',)
#   ('DP',)
#   ('INTJP',)
#   ('NEG',)
#   ('NOMP',)
#   ('NP',)
#   ('NUM',)
#   ('PP',)
#   ('ROOT',)
#   ('S',)
#   ('SQ',)
#   ('VP',)
#   ('WP',)
# Downloading (…)lve/main/config.json: 100%|█████| 386/386 [00:00<00:00, 45.1kB/s]
# Downloading pytorch_model.bin: 100%|█████████| 740M/740M [01:13<00:00, 10.1MB/s]
# Some weights of the model checkpoint at dbmdz/bert-base-turkish-128k-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading (…)okenizer_config.json: 100%|███| 60.0/60.0 [00:00<00:00, 7.85kB/s]
# Downloading (…)solve/main/vocab.txt: 100%|█| 1.18M/1.18M [00:00<00:00, 2.31MB/s]
# 2023-05-14 01:59:32 INFO: Warming up model for 10 iterations using AdaDelta to train the embeddings
# 2023-05-14 01:59:33 INFO: Building Adadelta with lr=1.000000, eps=0.000001, weight_decay=0.020000, rho=0.900000
# 2023-05-14 01:59:33 INFO: Number of words in the training set found in the embedding: 28162 out of 40523
# 2023-05-14 01:59:33 INFO: Building CrossEntropyLoss(sum)
# 2023-05-14 01:59:34 INFO: Starting epoch 1
# 100%|████████████████████████████████| 167/167 [13:12<00:00,  4.75s/it, Epoch 1]
# 2023-05-14 02:12:47 INFO: Transitions correct: 74806
#   Counter({'Shift': 39147, 'Close': 19643, 'Open': 16016})
# 2023-05-14 02:12:47 INFO: Transitions incorrect: 45091
#   Counter({('Open', 'Open'): 10290, ('Open', 'Shift'): 8524, ('Shift', 'Close'): 7340, ('Open', 'Close'): 5969, ('Close', 'Shift'): 5247, ('Shift', 'Open'): 5061, ('Close', 'Open'): 2660})
# 2023-05-14 02:12:47 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 14831, <RepairType.WRONG_OPEN_GENERAL: 4>: 7477, <RepairType.SHIFT_CLOSE: 8>: 7100, <RepairType.OPEN_SHIFT: 6>: 4367, <RepairType.OPEN_CLOSE: 7>: 2954, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 2129, <RepairType.CLOSE_SHIFT_NESTED: 9>: 816, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 329, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 19, <RepairType.MISSED_UNARY: 5>: 8})
# 2023-05-14 02:12:47 INFO: Fake transitions used: 21
# 2023-05-14 02:12:47 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:33<00:00, 10.14it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 32.07 LR: 41.54 F1: 36.19 Exact: 4.63 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 32.07 LR: 41.54 F1: 36.19 Exact: 4.63 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 02:14:24 INFO: New best dev score: 0.36199 > 0.00000
# 2023-05-14 02:14:24 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency.pt
# 2023-05-14 02:14:24 INFO: Epoch 1 finished
#   Transitions correct: Counter({'Shift': 39147, 'Close': 19643, 'Open': 16016})
#   Transitions incorrect: Counter({('Open', 'Open'): 10290, ('Open', 'Shift'): 8524, ('Shift', 'Close'): 7340, ('Open', 'Close'): 5969, ('Close', 'Shift'): 5247, ('Shift', 'Open'): 5061, ('Close', 'Open'): 2660})
#   Total loss for epoch: 167237.89467
#   Dev score      (    1): 0.361990
#   Best dev score (    1): 0.361990
# 2023-05-14 02:14:25 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 02:14:25 INFO: Starting epoch 2
# 100%|████████████████████████████████| 167/167 [12:45<00:00,  4.58s/it, Epoch 2]
# 2023-05-14 02:27:10 INFO: Transitions correct: 93453
#   Counter({'Shift': 43410, 'Close': 27053, 'Open': 22990})
# 2023-05-14 02:27:10 INFO: Transitions incorrect: 24154
#   Counter({('Open', 'Open'): 8501, ('Open', 'Shift'): 4025, ('Shift', 'Close'): 3541, ('Shift', 'Open'): 3448, ('Close', 'Shift'): 2095, ('Open', 'Close'): 1466, ('Close', 'Open'): 1078})
# 2023-05-14 02:27:10 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 6636, <RepairType.WRONG_OPEN_GENERAL: 4>: 5866, <RepairType.SHIFT_CLOSE: 8>: 3486, <RepairType.OPEN_SHIFT: 6>: 3172, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 2180, <RepairType.OPEN_CLOSE: 7>: 1210, <RepairType.CLOSE_SHIFT_NESTED: 9>: 637, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 245, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 16, <RepairType.MISSED_UNARY: 5>: 13})
# 2023-05-14 02:27:10 INFO: Fake transitions used: 18
# 2023-05-14 02:27:10 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:26<00:00, 11.04it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 68.29 LR: 58.65 F1: 63.1 Exact: 11.15 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 68.29 LR: 58.65 F1: 63.1 Exact: 11.15 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 02:28:38 INFO: New best dev score: 0.63106 > 0.36199
# 2023-05-14 02:28:38 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency.pt
# 2023-05-14 02:28:38 INFO: Epoch 2 finished
#   Transitions correct: Counter({'Shift': 43410, 'Close': 27053, 'Open': 22990})
#   Transitions incorrect: Counter({('Open', 'Open'): 8501, ('Open', 'Shift'): 4025, ('Shift', 'Close'): 3541, ('Shift', 'Open'): 3448, ('Close', 'Shift'): 2095, ('Open', 'Close'): 1466, ('Close', 'Open'): 1078})
#   Total loss for epoch: 72558.97200
#   Dev score      (    2): 0.631056
#   Best dev score (    2): 0.631056
# 2023-05-14 02:28:38 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 02:28:38 INFO: Starting epoch 3
# 100%|████████████████████████████████| 167/167 [12:49<00:00,  4.61s/it, Epoch 3]
# 2023-05-14 02:41:28 INFO: Transitions correct: 98690
#   Counter({'Shift': 44618, 'Close': 28655, 'Open': 25417})
# 2023-05-14 02:41:28 INFO: Transitions incorrect: 19004
#   Counter({('Open', 'Open'): 6526, ('Open', 'Shift'): 3340, ('Shift', 'Open'): 2903, ('Shift', 'Close'): 2627, ('Close', 'Shift'): 1691, ('Open', 'Close'): 1142, ('Close', 'Open'): 775})
# 2023-05-14 02:41:28 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 5216, <RepairType.WRONG_OPEN_GENERAL: 4>: 4870, <RepairType.OPEN_SHIFT: 6>: 2808, <RepairType.SHIFT_CLOSE: 8>: 2617, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1569, <RepairType.OPEN_CLOSE: 7>: 939, <RepairType.CLOSE_SHIFT_NESTED: 9>: 621, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 33, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 25, <RepairType.MISSED_UNARY: 5>: 18})
# 2023-05-14 02:41:28 INFO: Fake transitions used: 22
# 2023-05-14 02:41:28 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:25<00:00, 11.14it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 67.14 LR: 66.64 F1: 66.89 Exact: 15.36 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 67.14 LR: 66.64 F1: 66.89 Exact: 15.36 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 02:42:56 INFO: New best dev score: 0.66892 > 0.63106
# 2023-05-14 02:42:57 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency.pt
# 2023-05-14 02:42:57 INFO: Epoch 3 finished
#   Transitions correct: Counter({'Shift': 44618, 'Close': 28655, 'Open': 25417})
#   Transitions incorrect: Counter({('Open', 'Open'): 6526, ('Open', 'Shift'): 3340, ('Shift', 'Open'): 2903, ('Shift', 'Close'): 2627, ('Close', 'Shift'): 1691, ('Open', 'Close'): 1142, ('Close', 'Open'): 775})
#   Total loss for epoch: 57264.25012
#   Dev score      (    3): 0.668925
#   Best dev score (    3): 0.668925
# 2023-05-14 02:42:57 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 02:42:57 INFO: Starting epoch 4
# 100%|████████████████████████████████| 167/167 [12:39<00:00,  4.55s/it, Epoch 4]
# 2023-05-14 02:55:36 INFO: Transitions correct: 99586
#   Counter({'Shift': 44677, 'Close': 28938, 'Open': 25971})
# 2023-05-14 02:55:36 INFO: Transitions incorrect: 16913
#   Counter({('Open', 'Open'): 5762, ('Open', 'Shift'): 3144, ('Shift', 'Open'): 2795, ('Shift', 'Close'): 2111, ('Close', 'Shift'): 1512, ('Open', 'Close'): 898, ('Close', 'Open'): 691})
# 2023-05-14 02:55:36 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 4950, <RepairType.WRONG_OPEN_GENERAL: 4>: 4256, <RepairType.OPEN_SHIFT: 6>: 2657, <RepairType.SHIFT_CLOSE: 8>: 2114, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1470, <RepairType.OPEN_CLOSE: 7>: 786, <RepairType.CLOSE_SHIFT_NESTED: 9>: 612, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 24, <RepairType.MISSED_UNARY: 5>: 20, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 10})
# 2023-05-14 02:55:36 INFO: Fake transitions used: 20
# 2023-05-14 02:55:36 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:25<00:00, 11.07it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 73.01 LR: 67.19 F1: 69.98 Exact: 16.21 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 73.01 LR: 67.19 F1: 69.98 Exact: 16.21 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 02:57:05 INFO: New best dev score: 0.69984 > 0.66892
# 2023-05-14 02:57:05 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency.pt
# 2023-05-14 02:57:05 INFO: Epoch 4 finished
#   Transitions correct: Counter({'Shift': 44677, 'Close': 28938, 'Open': 25971})
#   Transitions incorrect: Counter({('Open', 'Open'): 5762, ('Open', 'Shift'): 3144, ('Shift', 'Open'): 2795, ('Shift', 'Close'): 2111, ('Close', 'Shift'): 1512, ('Open', 'Close'): 898, ('Close', 'Open'): 691})
#   Total loss for epoch: 49866.45276
#   Dev score      (    4): 0.699843
#   Best dev score (    4): 0.699843
# 2023-05-14 02:57:05 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 02:57:05 INFO: Starting epoch 5
# 100%|████████████████████████████████| 167/167 [12:35<00:00,  4.53s/it, Epoch 5]
# 2023-05-14 03:09:41 INFO: Transitions correct: 101170
#   Counter({'Shift': 45070, 'Close': 29396, 'Open': 26704})
# 2023-05-14 03:09:41 INFO: Transitions incorrect: 15715
#   Counter({('Open', 'Open'): 5250, ('Open', 'Shift'): 2990, ('Shift', 'Open'): 2595, ('Shift', 'Close'): 2055, ('Close', 'Shift'): 1388, ('Open', 'Close'): 876, ('Close', 'Open'): 561})
# 2023-05-14 03:09:41 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 4459, <RepairType.WRONG_OPEN_GENERAL: 4>: 3838, <RepairType.OPEN_SHIFT: 6>: 2568, <RepairType.SHIFT_CLOSE: 8>: 2056, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1341, <RepairType.OPEN_CLOSE: 7>: 763, <RepairType.CLOSE_SHIFT_NESTED: 9>: 567, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 36, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 21, <RepairType.MISSED_UNARY: 5>: 19})
# 2023-05-14 03:09:41 INFO: Fake transitions used: 32
# 2023-05-14 03:09:41 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:24<00:00, 11.28it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 78.6 LR: 69.04 F1: 73.51 Exact: 18.84 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 78.6 LR: 69.04 F1: 73.51 Exact: 18.84 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 03:11:08 INFO: New best dev score: 0.73513 > 0.69984
# 2023-05-14 03:11:08 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency.pt
# 2023-05-14 03:11:08 INFO: Epoch 5 finished
#   Transitions correct: Counter({'Shift': 45070, 'Close': 29396, 'Open': 26704})
#   Transitions incorrect: Counter({('Open', 'Open'): 5250, ('Open', 'Shift'): 2990, ('Shift', 'Open'): 2595, ('Shift', 'Close'): 2055, ('Close', 'Shift'): 1388, ('Open', 'Close'): 876, ('Close', 'Open'): 561})
#   Total loss for epoch: 46293.80009
#   Dev score      (    5): 0.735130
#   Best dev score (    5): 0.735130
# 2023-05-14 03:11:09 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 03:11:09 INFO: Starting epoch 6
# 100%|████████████████████████████████| 167/167 [12:38<00:00,  4.54s/it, Epoch 6]
# 2023-05-14 03:23:48 INFO: Transitions correct: 101285
#   Counter({'Shift': 45034, 'Close': 29558, 'Open': 26693})
# 2023-05-14 03:23:48 INFO: Transitions incorrect: 15034
#   Counter({('Open', 'Open'): 5118, ('Open', 'Shift'): 3056, ('Shift', 'Open'): 2420, ('Shift', 'Close'): 1844, ('Close', 'Shift'): 1331, ('Open', 'Close'): 708, ('Close', 'Open'): 557})
# 2023-05-14 03:23:48 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 4155, <RepairType.WRONG_OPEN_GENERAL: 4>: 3749, <RepairType.OPEN_SHIFT: 6>: 2643, <RepairType.SHIFT_CLOSE: 8>: 1844, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1329, <RepairType.CLOSE_SHIFT_NESTED: 9>: 628, <RepairType.OPEN_CLOSE: 7>: 628, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 24, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 13, <RepairType.MISSED_UNARY: 5>: 10})
# 2023-05-14 03:23:48 INFO: Fake transitions used: 32
# 2023-05-14 03:23:48 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:26<00:00, 10.95it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 68.93 LR: 76.51 F1: 72.53 Exact: 16.42 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 68.93 LR: 76.51 F1: 72.53 Exact: 16.42 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 03:25:17 INFO: Epoch 6 finished
#   Transitions correct: Counter({'Shift': 45034, 'Close': 29558, 'Open': 26693})
#   Transitions incorrect: Counter({('Open', 'Open'): 5118, ('Open', 'Shift'): 3056, ('Shift', 'Open'): 2420, ('Shift', 'Close'): 1844, ('Close', 'Shift'): 1331, ('Open', 'Close'): 708, ('Close', 'Open'): 557})
#   Total loss for epoch: 43869.35866
#   Dev score      (    6): 0.725314
#   Best dev score (    5): 0.735130
# 2023-05-14 03:25:17 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 03:25:17 INFO: Starting epoch 7
# 100%|████████████████████████████████| 167/167 [12:43<00:00,  4.57s/it, Epoch 7]
# 2023-05-14 03:38:00 INFO: Transitions correct: 101222
#   Counter({'Shift': 44891, 'Close': 29525, 'Open': 26806})
# 2023-05-14 03:38:00 INFO: Transitions incorrect: 16232
#   Counter({('Open', 'Open'): 5401, ('Open', 'Shift'): 3085, ('Shift', 'Open'): 2521, ('Shift', 'Close'): 2368, ('Close', 'Shift'): 1414, ('Open', 'Close'): 856, ('Close', 'Open'): 587})
# 2023-05-14 03:38:00 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 4106, <RepairType.WRONG_OPEN_GENERAL: 4>: 3691, <RepairType.OPEN_SHIFT: 6>: 2628, <RepairType.SHIFT_CLOSE: 8>: 2292, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1298, <RepairType.OPEN_CLOSE: 7>: 704, <RepairType.CLOSE_SHIFT_NESTED: 9>: 568, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 157, <RepairType.MISSED_UNARY: 5>: 18, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 17})
# 2023-05-14 03:38:00 INFO: Fake transitions used: 27
# 2023-05-14 03:38:00 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:26<00:00, 11.03it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 64.17 LR: 72.48 F1: 68.07 Exact: 17.68 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 64.17 LR: 72.48 F1: 68.07 Exact: 17.68 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 03:39:29 INFO: Epoch 7 finished
#   Transitions correct: Counter({'Shift': 44891, 'Close': 29525, 'Open': 26806})
#   Transitions incorrect: Counter({('Open', 'Open'): 5401, ('Open', 'Shift'): 3085, ('Shift', 'Open'): 2521, ('Shift', 'Close'): 2368, ('Close', 'Shift'): 1414, ('Open', 'Close'): 856, ('Close', 'Open'): 587})
#   Total loss for epoch: 50205.17160
#   Dev score      (    7): 0.680791
#   Best dev score (    5): 0.735130
# 2023-05-14 03:39:29 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 03:39:29 INFO: Starting epoch 8
# 100%|████████████████████████████████| 167/167 [12:42<00:00,  4.57s/it, Epoch 8]
# 2023-05-14 03:52:12 INFO: Transitions correct: 102129
#   Counter({'Shift': 45317, 'Close': 29755, 'Open': 27057})
# 2023-05-14 03:52:12 INFO: Transitions incorrect: 14854
#   Counter({('Open', 'Open'): 5059, ('Open', 'Shift'): 2889, ('Shift', 'Open'): 2402, ('Shift', 'Close'): 1876, ('Close', 'Shift'): 1276, ('Open', 'Close'): 764, ('Close', 'Open'): 588})
# 2023-05-14 03:52:12 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 4104, <RepairType.WRONG_OPEN_GENERAL: 4>: 3777, <RepairType.OPEN_SHIFT: 6>: 2489, <RepairType.SHIFT_CLOSE: 8>: 1877, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1223, <RepairType.OPEN_CLOSE: 7>: 665, <RepairType.CLOSE_SHIFT_NESTED: 9>: 568, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 25, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 24, <RepairType.MISSED_UNARY: 5>: 13})
# 2023-05-14 03:52:12 INFO: Fake transitions used: 23
# 2023-05-14 03:52:12 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:25<00:00, 11.07it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 79.97 LR: 68.59 F1: 73.85 Exact: 19.89 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 79.97 LR: 68.59 F1: 73.85 Exact: 19.89 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 03:53:41 INFO: New best dev score: 0.73850 > 0.73513
# 2023-05-14 03:53:41 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency.pt
# 2023-05-14 03:53:41 INFO: Epoch 8 finished
#   Transitions correct: Counter({'Shift': 45317, 'Close': 29755, 'Open': 27057})
#   Transitions incorrect: Counter({('Open', 'Open'): 5059, ('Open', 'Shift'): 2889, ('Shift', 'Open'): 2402, ('Shift', 'Close'): 1876, ('Close', 'Shift'): 1276, ('Open', 'Close'): 764, ('Close', 'Open'): 588})
#   Total loss for epoch: 43528.83627
#   Dev score      (    8): 0.738503
#   Best dev score (    8): 0.738503
# 2023-05-14 03:53:41 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 03:53:41 INFO: Starting epoch 9
# 100%|████████████████████████████████| 167/167 [12:44<00:00,  4.58s/it, Epoch 9]
# 2023-05-14 04:06:25 INFO: Transitions correct: 103008
#   Counter({'Shift': 45663, 'Close': 30058, 'Open': 27287})
# 2023-05-14 04:06:25 INFO: Transitions incorrect: 14536
#   Counter({('Open', 'Open'): 4993, ('Open', 'Shift'): 2826, ('Shift', 'Open'): 2362, ('Shift', 'Close'): 1794, ('Close', 'Shift'): 1315, ('Open', 'Close'): 710, ('Close', 'Open'): 536})
# 2023-05-14 04:06:25 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 4026, <RepairType.WRONG_OPEN_GENERAL: 4>: 3636, <RepairType.OPEN_SHIFT: 6>: 2417, <RepairType.SHIFT_CLOSE: 8>: 1793, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1259, <RepairType.OPEN_CLOSE: 7>: 615, <RepairType.CLOSE_SHIFT_NESTED: 9>: 561, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 61, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 23, <RepairType.MISSED_UNARY: 5>: 17})
# 2023-05-14 04:06:25 INFO: Fake transitions used: 33
# 2023-05-14 04:06:25 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:25<00:00, 11.16it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 79.86 LR: 73.42 F1: 76.51 Exact: 22.52 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 79.86 LR: 73.42 F1: 76.51 Exact: 22.52 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 04:07:53 INFO: New best dev score: 0.76513 > 0.73850
# 2023-05-14 04:07:53 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency.pt
# 2023-05-14 04:07:53 INFO: Epoch 9 finished
#   Transitions correct: Counter({'Shift': 45663, 'Close': 30058, 'Open': 27287})
#   Transitions incorrect: Counter({('Open', 'Open'): 4993, ('Open', 'Shift'): 2826, ('Shift', 'Open'): 2362, ('Shift', 'Close'): 1794, ('Close', 'Shift'): 1315, ('Open', 'Close'): 710, ('Close', 'Open'): 536})
#   Total loss for epoch: 42873.95673
#   Dev score      (    9): 0.765130
#   Best dev score (    9): 0.765130
# 2023-05-14 04:07:54 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 04:07:54 INFO: Starting epoch 10
# 100%|███████████████████████████████| 167/167 [12:40<00:00,  4.55s/it, Epoch 10]
# 2023-05-14 04:20:34 INFO: Transitions correct: 103653
#   Counter({'Shift': 45674, 'Close': 30341, 'Open': 27638})
# 2023-05-14 04:20:34 INFO: Transitions incorrect: 13981
#   Counter({('Open', 'Open'): 4857, ('Open', 'Shift'): 2729, ('Shift', 'Open'): 2253, ('Shift', 'Close'): 1725, ('Close', 'Shift'): 1158, ('Open', 'Close'): 721, ('Close', 'Open'): 538})
# 2023-05-14 04:20:34 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 3817, <RepairType.WRONG_OPEN_GENERAL: 4>: 3565, <RepairType.OPEN_SHIFT: 6>: 2378, <RepairType.SHIFT_CLOSE: 8>: 1726, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1201, <RepairType.OPEN_CLOSE: 7>: 645, <RepairType.CLOSE_SHIFT_NESTED: 9>: 517, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 56, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 31, <RepairType.MISSED_UNARY: 5>: 23})
# 2023-05-14 04:20:34 INFO: Fake transitions used: 32
# 2023-05-14 04:20:34 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:26<00:00, 11.03it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 81.7 LR: 68.36 F1: 74.44 Exact: 19.36 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 81.7 LR: 68.36 F1: 74.44 Exact: 19.36 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 04:22:03 INFO: Epoch 10 finished
#   Transitions correct: Counter({'Shift': 45674, 'Close': 30341, 'Open': 27638})
#   Transitions incorrect: Counter({('Open', 'Open'): 4857, ('Open', 'Shift'): 2729, ('Shift', 'Open'): 2253, ('Shift', 'Close'): 1725, ('Close', 'Shift'): 1158, ('Open', 'Close'): 721, ('Close', 'Open'): 538})
#   Total loss for epoch: 40913.48973
#   Dev score      (   10): 0.744415
#   Best dev score (    9): 0.765130
# 2023-05-14 04:22:04 INFO: Finished stage at epoch 10.  Restarting optimizer
# 2023-05-14 04:22:04 INFO: Previous best model was at epoch 9
# 2023-05-14 04:22:04 INFO: Switching to a model with 0 pattn layers and NO lattn
# 2023-05-14 04:22:04 INFO: Building AdamW with lr=0.000200, beta2=0.999000, eps=0.000000, weight_decay=0.050000
# 2023-05-14 04:22:04 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 04:22:04 INFO: Starting epoch 11
# 100%|███████████████████████████████| 167/167 [12:28<00:00,  4.48s/it, Epoch 11]
# 2023-05-14 04:34:33 INFO: Transitions correct: 104314
#   Counter({'Shift': 45915, 'Close': 30511, 'Open': 27888})
# 2023-05-14 04:34:33 INFO: Transitions incorrect: 12704
#   Counter({('Open', 'Open'): 4322, ('Open', 'Shift'): 2713, ('Shift', 'Open'): 2116, ('Shift', 'Close'): 1492, ('Close', 'Shift'): 1034, ('Open', 'Close'): 613, ('Close', 'Open'): 414})
# 2023-05-14 04:34:33 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 3331, <RepairType.WRONG_OPEN_GENERAL: 4>: 3268, <RepairType.OPEN_SHIFT: 6>: 2389, <RepairType.SHIFT_CLOSE: 8>: 1492, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1035, <RepairType.CLOSE_SHIFT_NESTED: 9>: 596, <RepairType.OPEN_CLOSE: 7>: 560, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 18, <RepairType.MISSED_UNARY: 5>: 14, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 1})
# 2023-05-14 04:34:33 INFO: Fake transitions used: 32
# 2023-05-14 04:34:33 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:25<00:00, 11.12it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 79.23 LR: 77.51 F1: 78.36 Exact: 24.84 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 79.23 LR: 77.51 F1: 78.36 Exact: 24.84 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 04:36:01 INFO: New best dev score: 0.78362 > 0.76513
# 2023-05-14 04:36:01 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency.pt
# 2023-05-14 04:36:01 INFO: Epoch 11 finished
#   Transitions correct: Counter({'Shift': 45915, 'Close': 30511, 'Open': 27888})
#   Transitions incorrect: Counter({('Open', 'Open'): 4322, ('Open', 'Shift'): 2713, ('Shift', 'Open'): 2116, ('Shift', 'Close'): 1492, ('Close', 'Shift'): 1034, ('Open', 'Close'): 613, ('Close', 'Open'): 414})
#   Total loss for epoch: 35853.43921
#   Dev score      (   11): 0.783624
#   Best dev score (   11): 0.783624
# 2023-05-14 04:36:02 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 04:36:02 INFO: Starting epoch 12
# 100%|███████████████████████████████| 167/167 [12:30<00:00,  4.49s/it, Epoch 12]
# 2023-05-14 04:48:32 INFO: Transitions correct: 104428
#   Counter({'Shift': 45935, 'Close': 30554, 'Open': 27939})
# 2023-05-14 04:48:32 INFO: Transitions incorrect: 12210
#   Counter({('Open', 'Open'): 4282, ('Open', 'Shift'): 2522, ('Shift', 'Open'): 2014, ('Shift', 'Close'): 1485, ('Close', 'Shift'): 990, ('Open', 'Close'): 547, ('Close', 'Open'): 370})
# 2023-05-14 04:48:32 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 3182, <RepairType.WRONG_OPEN_GENERAL: 4>: 3150, <RepairType.OPEN_SHIFT: 6>: 2249, <RepairType.SHIFT_CLOSE: 8>: 1487, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1106, <RepairType.CLOSE_SHIFT_NESTED: 9>: 514, <RepairType.OPEN_CLOSE: 7>: 484, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 22, <RepairType.MISSED_UNARY: 5>: 12, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 4})
# 2023-05-14 04:48:32 INFO: Fake transitions used: 36
# 2023-05-14 04:48:32 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:25<00:00, 11.13it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 81.09 LR: 78.15 F1: 79.59 Exact: 26.0 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 81.09 LR: 78.15 F1: 79.59 Exact: 26.0 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 04:50:00 INFO: New best dev score: 0.79595 > 0.78362
# 2023-05-14 04:50:00 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency.pt
# 2023-05-14 04:50:00 INFO: Epoch 12 finished
#   Transitions correct: Counter({'Shift': 45935, 'Close': 30554, 'Open': 27939})
#   Transitions incorrect: Counter({('Open', 'Open'): 4282, ('Open', 'Shift'): 2522, ('Shift', 'Open'): 2014, ('Shift', 'Close'): 1485, ('Close', 'Shift'): 990, ('Open', 'Close'): 547, ('Close', 'Open'): 370})
#   Total loss for epoch: 34779.85880
#   Dev score      (   12): 0.795948
#   Best dev score (   12): 0.795948
# 2023-05-14 04:50:00 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 04:50:00 INFO: Starting epoch 13
# 100%|███████████████████████████████| 167/167 [12:33<00:00,  4.51s/it, Epoch 13]
# 2023-05-14 05:02:33 INFO: Transitions correct: 104678
#   Counter({'Shift': 45789, 'Close': 30645, 'Open': 28244})
# 2023-05-14 05:02:33 INFO: Transitions incorrect: 11847
#   Counter({('Open', 'Open'): 4087, ('Open', 'Shift'): 2369, ('Shift', 'Open'): 2037, ('Shift', 'Close'): 1365, ('Close', 'Shift'): 988, ('Open', 'Close'): 578, ('Close', 'Open'): 423})
# 2023-05-14 05:02:33 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 3208, <RepairType.WRONG_OPEN_GENERAL: 4>: 3058, <RepairType.OPEN_SHIFT: 6>: 2119, <RepairType.SHIFT_CLOSE: 8>: 1367, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 995, <RepairType.CLOSE_SHIFT_NESTED: 9>: 551, <RepairType.OPEN_CLOSE: 7>: 504, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 25, <RepairType.MISSED_UNARY: 5>: 11, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 9})
# 2023-05-14 05:02:33 INFO: Fake transitions used: 27
# 2023-05-14 05:02:33 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:25<00:00, 11.13it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 78.8 LR: 79.69 F1: 79.24 Exact: 25.15 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 78.8 LR: 79.69 F1: 79.24 Exact: 25.15 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 05:04:02 INFO: Epoch 13 finished
#   Transitions correct: Counter({'Shift': 45789, 'Close': 30645, 'Open': 28244})
#   Transitions incorrect: Counter({('Open', 'Open'): 4087, ('Open', 'Shift'): 2369, ('Shift', 'Open'): 2037, ('Shift', 'Close'): 1365, ('Close', 'Shift'): 988, ('Open', 'Close'): 578, ('Close', 'Open'): 423})
#   Total loss for epoch: 33856.56174
#   Dev score      (   13): 0.792476
#   Best dev score (   12): 0.795948
# 2023-05-14 05:04:02 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 05:04:02 INFO: Starting epoch 14
# 100%|███████████████████████████████| 167/167 [12:33<00:00,  4.51s/it, Epoch 14]
# 2023-05-14 05:16:36 INFO: Transitions correct: 106340
#   Counter({'Shift': 46577, 'Close': 31110, 'Open': 28653})
# 2023-05-14 05:16:36 INFO: Transitions incorrect: 11918
#   Counter({('Open', 'Open'): 4101, ('Open', 'Shift'): 2372, ('Shift', 'Open'): 2116, ('Shift', 'Close'): 1409, ('Close', 'Shift'): 962, ('Open', 'Close'): 553, ('Close', 'Open'): 405})
# 2023-05-14 05:16:36 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 3250, <RepairType.WRONG_OPEN_GENERAL: 4>: 3056, <RepairType.OPEN_SHIFT: 6>: 2112, <RepairType.SHIFT_CLOSE: 8>: 1410, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1026, <RepairType.CLOSE_SHIFT_NESTED: 9>: 535, <RepairType.OPEN_CLOSE: 7>: 496, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 19, <RepairType.MISSED_UNARY: 5>: 12})
# 2023-05-14 05:16:36 INFO: Fake transitions used: 25
# 2023-05-14 05:16:36 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:26<00:00, 11.05it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 80.62 LR: 78.7 F1: 79.65 Exact: 27.36 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 80.62 LR: 78.7 F1: 79.65 Exact: 27.36 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 05:18:04 INFO: New best dev score: 0.79651 > 0.79595
# 2023-05-14 05:18:05 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency.pt
# 2023-05-14 05:18:05 INFO: Epoch 14 finished
#   Transitions correct: Counter({'Shift': 46577, 'Close': 31110, 'Open': 28653})
#   Transitions incorrect: Counter({('Open', 'Open'): 4101, ('Open', 'Shift'): 2372, ('Shift', 'Open'): 2116, ('Shift', 'Close'): 1409, ('Close', 'Shift'): 962, ('Open', 'Close'): 553, ('Close', 'Open'): 405})
#   Total loss for epoch: 33737.13756
#   Dev score      (   14): 0.796513
#   Best dev score (   14): 0.796513
# 2023-05-14 05:18:05 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 05:18:05 INFO: Starting epoch 15
# 100%|███████████████████████████████| 167/167 [12:29<00:00,  4.49s/it, Epoch 15]
# 2023-05-14 05:30:34 INFO: Transitions correct: 105645
#   Counter({'Shift': 46167, 'Close': 30922, 'Open': 28556})
# 2023-05-14 05:30:34 INFO: Transitions incorrect: 11533
#   Counter({('Open', 'Open'): 3964, ('Open', 'Shift'): 2344, ('Shift', 'Open'): 1998, ('Shift', 'Close'): 1380, ('Close', 'Shift'): 923, ('Open', 'Close'): 546, ('Close', 'Open'): 378})
# 2023-05-14 05:30:34 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 3093, <RepairType.WRONG_OPEN_GENERAL: 4>: 2940, <RepairType.OPEN_SHIFT: 6>: 2080, <RepairType.SHIFT_CLOSE: 8>: 1380, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1001, <RepairType.CLOSE_SHIFT_NESTED: 9>: 513, <RepairType.OPEN_CLOSE: 7>: 487, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 23, <RepairType.MISSED_UNARY: 5>: 15})
# 2023-05-14 05:30:34 INFO: Fake transitions used: 27
# 2023-05-14 05:30:34 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:25<00:00, 11.13it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.0 sec].
# pcfg LP/LR summary evalb: LP: 80.18 LR: 80.01 F1: 80.1 Exact: 27.05 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 80.18 LR: 80.01 F1: 80.1 Exact: 27.05 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 05:32:03 INFO: New best dev score: 0.80103 > 0.79651
# 2023-05-14 05:32:03 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency.pt
# 2023-05-14 05:32:03 INFO: Epoch 15 finished
#   Transitions correct: Counter({'Shift': 46167, 'Close': 30922, 'Open': 28556})
#   Transitions incorrect: Counter({('Open', 'Open'): 3964, ('Open', 'Shift'): 2344, ('Shift', 'Open'): 1998, ('Shift', 'Close'): 1380, ('Close', 'Shift'): 923, ('Open', 'Close'): 546, ('Close', 'Open'): 378})
#   Total loss for epoch: 33070.15636
#   Dev score      (   15): 0.801031
#   Best dev score (   15): 0.801031
# 2023-05-14 05:32:03 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 05:32:03 INFO: Starting epoch 16
# 100%|███████████████████████████████| 167/167 [12:32<00:00,  4.50s/it, Epoch 16]
# 2023-05-14 05:44:35 INFO: Transitions correct: 105792
#   Counter({'Shift': 46106, 'Close': 31062, 'Open': 28624})
# 2023-05-14 05:44:35 INFO: Transitions incorrect: 11402
#   Counter({('Open', 'Open'): 4002, ('Open', 'Shift'): 2314, ('Shift', 'Open'): 1972, ('Shift', 'Close'): 1302, ('Close', 'Shift'): 862, ('Open', 'Close'): 538, ('Close', 'Open'): 412})
# 2023-05-14 05:44:35 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 3087, <RepairType.WRONG_OPEN_GENERAL: 4>: 2964, <RepairType.OPEN_SHIFT: 6>: 2065, <RepairType.SHIFT_CLOSE: 8>: 1302, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 1016, <RepairType.OPEN_CLOSE: 7>: 479, <RepairType.CLOSE_SHIFT_NESTED: 9>: 450, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 22, <RepairType.MISSED_UNARY: 5>: 16})
# 2023-05-14 05:44:35 INFO: Fake transitions used: 23
# 2023-05-14 05:44:35 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:26<00:00, 11.02it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.0 sec].
# pcfg LP/LR summary evalb: LP: 80.99 LR: 79.87 F1: 80.43 Exact: 27.36 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 80.99 LR: 79.87 F1: 80.43 Exact: 27.36 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 05:46:04 INFO: New best dev score: 0.80433 > 0.80103
# 2023-05-14 05:46:04 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency.pt
# 2023-05-14 05:46:04 INFO: Epoch 16 finished
#   Transitions correct: Counter({'Shift': 46106, 'Close': 31062, 'Open': 28624})
#   Transitions incorrect: Counter({('Open', 'Open'): 4002, ('Open', 'Shift'): 2314, ('Shift', 'Open'): 1972, ('Shift', 'Close'): 1302, ('Close', 'Shift'): 862, ('Open', 'Close'): 538, ('Close', 'Open'): 412})
#   Total loss for epoch: 32612.58783
#   Dev score      (   16): 0.804328
#   Best dev score (   16): 0.804328
# 2023-05-14 05:46:05 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 05:46:05 INFO: Starting epoch 17
# 100%|███████████████████████████████| 167/167 [12:32<00:00,  4.51s/it, Epoch 17]
# 2023-05-14 05:58:37 INFO: Transitions correct: 105245
#   Counter({'Shift': 45984, 'Close': 30786, 'Open': 28475})
# 2023-05-14 05:58:37 INFO: Transitions incorrect: 11292
#   Counter({('Open', 'Open'): 3851, ('Open', 'Shift'): 2305, ('Shift', 'Open'): 1952, ('Shift', 'Close'): 1375, ('Close', 'Shift'): 891, ('Open', 'Close'): 539, ('Close', 'Open'): 379})
# 2023-05-14 05:58:37 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 3061, <RepairType.WRONG_OPEN_GENERAL: 4>: 2828, <RepairType.OPEN_SHIFT: 6>: 2024, <RepairType.SHIFT_CLOSE: 8>: 1377, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 995, <RepairType.CLOSE_SHIFT_NESTED: 9>: 478, <RepairType.OPEN_CLOSE: 7>: 478, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 26, <RepairType.MISSED_UNARY: 5>: 22, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 2})
# 2023-05-14 05:58:37 INFO: Fake transitions used: 32
# 2023-05-14 05:58:37 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:25<00:00, 11.11it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 80.98 LR: 80.69 F1: 80.83 Exact: 28.21 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 80.98 LR: 80.69 F1: 80.83 Exact: 28.21 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 06:00:06 INFO: New best dev score: 0.80836 > 0.80433
# 2023-05-14 06:00:06 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency.pt
# 2023-05-14 06:00:06 INFO: Epoch 17 finished
#   Transitions correct: Counter({'Shift': 45984, 'Close': 30786, 'Open': 28475})
#   Transitions incorrect: Counter({('Open', 'Open'): 3851, ('Open', 'Shift'): 2305, ('Shift', 'Open'): 1952, ('Shift', 'Close'): 1375, ('Close', 'Shift'): 891, ('Open', 'Close'): 539, ('Close', 'Open'): 379})
#   Total loss for epoch: 32269.75860
#   Dev score      (   17): 0.808363
#   Best dev score (   17): 0.808363
# 2023-05-14 06:00:06 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 06:00:06 INFO: Starting epoch 18
# 100%|███████████████████████████████| 167/167 [12:37<00:00,  4.54s/it, Epoch 18]
# 2023-05-14 06:12:44 INFO: Transitions correct: 105944
#   Counter({'Shift': 46362, 'Close': 31017, 'Open': 28565})
# 2023-05-14 06:12:44 INFO: Transitions incorrect: 11623
#   Counter({('Open', 'Open'): 4015, ('Open', 'Shift'): 2357, ('Shift', 'Open'): 2020, ('Shift', 'Close'): 1369, ('Close', 'Shift'): 912, ('Open', 'Close'): 569, ('Close', 'Open'): 381})
# 2023-05-14 06:12:44 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 3157, <RepairType.WRONG_OPEN_GENERAL: 4>: 3005, <RepairType.OPEN_SHIFT: 6>: 2067, <RepairType.SHIFT_CLOSE: 8>: 1371, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 994, <RepairType.OPEN_CLOSE: 7>: 503, <RepairType.CLOSE_SHIFT_NESTED: 9>: 490, <RepairType.MISSED_UNARY: 5>: 19, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 15, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 1})
# 2023-05-14 06:12:44 INFO: Fake transitions used: 23
# 2023-05-14 06:12:44 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:27<00:00, 10.90it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 81.5 LR: 79.98 F1: 80.73 Exact: 29.26 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 81.5 LR: 79.98 F1: 80.73 Exact: 29.26 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 06:14:13 INFO: Epoch 18 finished
#   Transitions correct: Counter({'Shift': 46362, 'Close': 31017, 'Open': 28565})
#   Transitions incorrect: Counter({('Open', 'Open'): 4015, ('Open', 'Shift'): 2357, ('Shift', 'Open'): 2020, ('Shift', 'Close'): 1369, ('Close', 'Shift'): 912, ('Open', 'Close'): 569, ('Close', 'Open'): 381})
#   Total loss for epoch: 33050.70825
#   Dev score      (   18): 0.807351
#   Best dev score (   17): 0.808363
# 2023-05-14 06:14:13 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 06:14:13 INFO: Starting epoch 19
# 100%|███████████████████████████████| 167/167 [12:40<00:00,  4.55s/it, Epoch 19]
# 2023-05-14 06:26:53 INFO: Transitions correct: 107597
#   Counter({'Shift': 46970, 'Close': 31446, 'Open': 29181})
# 2023-05-14 06:26:53 INFO: Transitions incorrect: 11082
#   Counter({('Open', 'Open'): 3855, ('Open', 'Shift'): 2177, ('Shift', 'Open'): 1899, ('Shift', 'Close'): 1313, ('Close', 'Shift'): 912, ('Open', 'Close'): 551, ('Close', 'Open'): 375})
# 2023-05-14 06:26:53 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 2986, <RepairType.WRONG_OPEN_GENERAL: 4>: 2930, <RepairType.OPEN_SHIFT: 6>: 1924, <RepairType.SHIFT_CLOSE: 8>: 1313, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 894, <RepairType.OPEN_CLOSE: 7>: 498, <RepairType.CLOSE_SHIFT_NESTED: 9>: 489, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 20, <RepairType.MISSED_UNARY: 5>: 14, <RepairType.WRONG_OPEN_ROOT_ERROR: 1>: 11})
# 2023-05-14 06:26:53 INFO: Fake transitions used: 31
# 2023-05-14 06:26:53 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:25<00:00, 11.07it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 80.34 LR: 79.21 F1: 79.77 Exact: 28.84 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 80.34 LR: 79.21 F1: 79.77 Exact: 28.84 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 06:28:22 INFO: Epoch 19 finished
#   Transitions correct: Counter({'Shift': 46970, 'Close': 31446, 'Open': 29181})
#   Transitions incorrect: Counter({('Open', 'Open'): 3855, ('Open', 'Shift'): 2177, ('Shift', 'Open'): 1899, ('Shift', 'Close'): 1313, ('Close', 'Shift'): 912, ('Open', 'Close'): 551, ('Close', 'Open'): 375})
#   Total loss for epoch: 31558.82105
#   Dev score      (   19): 0.797782
#   Best dev score (   17): 0.808363
# 2023-05-14 06:28:22 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 06:28:22 INFO: Starting epoch 20
# 100%|███████████████████████████████| 167/167 [12:30<00:00,  4.49s/it, Epoch 20]
# 2023-05-14 06:40:53 INFO: Transitions correct: 106451
#   Counter({'Shift': 46288, 'Close': 31240, 'Open': 28923})
# 2023-05-14 06:40:53 INFO: Transitions incorrect: 10733
#   Counter({('Open', 'Open'): 3822, ('Open', 'Shift'): 2123, ('Shift', 'Open'): 1878, ('Shift', 'Close'): 1263, ('Close', 'Shift'): 767, ('Open', 'Close'): 487, ('Close', 'Open'): 393})
# 2023-05-14 06:40:53 INFO: Oracle repairs:
#   Counter({<RepairType.UNKNOWN: 11>: 2924, <RepairType.WRONG_OPEN_GENERAL: 4>: 2864, <RepairType.OPEN_SHIFT: 6>: 1889, <RepairType.SHIFT_CLOSE: 8>: 1265, <RepairType.WRONG_OPEN_STUFF_UNARY: 3>: 937, <RepairType.OPEN_CLOSE: 7>: 434, <RepairType.CLOSE_SHIFT_NESTED: 9>: 388, <RepairType.WRONG_OPEN_UNARY_CHAIN: 2>: 21, <RepairType.MISSED_UNARY: 5>: 11})
# 2023-05-14 06:40:53 INFO: Fake transitions used: 28
# 2023-05-14 06:40:53 INFO: Processing 950 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 950/950 [01:25<00:00, 11.12it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.1 sec].
# pcfg LP/LR summary evalb: LP: 81.81 LR: 79.91 F1: 80.85 Exact: 29.15 N: 950
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 81.81 LR: 79.91 F1: 80.85 Exact: 29.15 N: 950
# factor Tag summary evalb: LP: 100.0 LR: 100.0 F1: 100.0 Exact: 100.0 N: 950
# 2023-05-14 06:42:21 INFO: New best dev score: 0.80852 > 0.80836
# 2023-05-14 06:42:21 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency.pt
# 2023-05-14 06:42:21 INFO: Epoch 20 finished
#   Transitions correct: Counter({'Shift': 46288, 'Close': 31240, 'Open': 28923})
#   Transitions incorrect: Counter({('Open', 'Open'): 3822, ('Open', 'Shift'): 2123, ('Shift', 'Open'): 1878, ('Shift', 'Close'): 1263, ('Close', 'Shift'): 767, ('Open', 'Close'): 487, ('Close', 'Open'): 393})
#   Total loss for epoch: 30640.06643
#   Dev score      (   20): 0.808518
#   Best dev score (   20): 0.808518
# 2023-05-14 06:42:21 INFO: Model saved to ./output_stanza_tr/tr_starlang_constituency_checkpoint.pt
# 2023-05-14 06:42:22 INFO: Running dev step with args: ['--eval_file', 'data/constituency/tr_starlang_dev.mrg', '--shorthand', 'tr_starlang', '--mode', 'predict', '--wordvec_pretrain_file', '/Users/gonzalojaimovitch/stanza_resources/tr/pretrain/imst.pt', '--charlm_forward_file', '/Users/gonzalojaimovitch/stanza_resources/tr/forward_charlm/conll17.pt', '--charlm_backward_file', '/Users/gonzalojaimovitch/stanza_resources/tr/backward_charlm/conll17.pt', '--bert_model', 'dbmdz/bert-base-turkish-128k-cased', '--epochs', '20', '--save_dir', './output_stanza_tr', '--save_name', 'tr_starlang_constituency.pt']
# 2023-05-14 06:42:22 INFO: Running constituency parser in predict mode
# 2023-05-14 06:42:22 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json: 216kB [00:00, 63.3MB/s]
# 2023-05-14 06:42:23 INFO: Loading these models for language: tr (Turkish):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | imst    |
# | pos       | imst    |
# =======================
#
# 2023-05-14 06:42:23 INFO: Using device: cpu
# 2023-05-14 06:42:23 INFO: Loading: tokenize
# 2023-05-14 06:42:23 INFO: Loading: pos
# 2023-05-14 06:42:23 INFO: Done loading processors!
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Some weights of the model checkpoint at dbmdz/bert-base-turkish-128k-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-14 06:42:27 INFO: Reading trees from data/constituency/tr_starlang_dev.mrg
# 2023-05-14 06:42:27 INFO: Read 959 trees for evaluation
# 2023-05-14 06:42:27 INFO: Retagging trees using the xpos tags from the default package...
# 100%|█████████████████████████████████████████| 959/959 [00:22<00:00, 43.58it/s]
# 2023-05-14 06:42:49 INFO: Retagging finished
# 2023-05-14 06:42:49 INFO: Processing 959 trees from data/constituency/tr_starlang_dev.mrg
# 100%|█████████████████████████████████████████| 959/959 [01:25<00:00, 11.26it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 81.81 LR: 79.96 F1: 80.88 Exact: 29.5 N: 959
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 81.81 LR: 79.96 F1: 80.88 Exact: 29.5 N: 959
# factor Tag summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 959
# 2023-05-14 06:44:19 INFO: F1 score on data/constituency/tr_starlang_dev.mrg: 0.808808
# 2023-05-14 06:44:19 INFO: Running test step with args: ['--eval_file', 'data/constituency/tr_starlang_test.mrg', '--shorthand', 'tr_starlang', '--mode', 'predict', '--wordvec_pretrain_file', '/Users/gonzalojaimovitch/stanza_resources/tr/pretrain/imst.pt', '--charlm_forward_file', '/Users/gonzalojaimovitch/stanza_resources/tr/forward_charlm/conll17.pt', '--charlm_backward_file', '/Users/gonzalojaimovitch/stanza_resources/tr/backward_charlm/conll17.pt', '--bert_model', 'dbmdz/bert-base-turkish-128k-cased', '--epochs', '20', '--save_dir', './output_stanza_tr', '--save_name', 'tr_starlang_constituency.pt']
# 2023-05-14 06:44:19 INFO: Running constituency parser in predict mode
# 2023-05-14 06:44:19 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json: 216kB [00:00, 39.5MB/s]
# 2023-05-14 06:44:19 INFO: Loading these models for language: tr (Turkish):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | imst    |
# | pos       | imst    |
# =======================
#
# 2023-05-14 06:44:19 INFO: Using device: cpu
# 2023-05-14 06:44:19 INFO: Loading: tokenize
# 2023-05-14 06:44:19 INFO: Loading: pos
# 2023-05-14 06:44:19 INFO: Done loading processors!
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Some weights of the model checkpoint at dbmdz/bert-base-turkish-128k-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-14 06:44:22 INFO: Reading trees from data/constituency/tr_starlang_test.mrg
# 100%|████████████████████████████████████| 1395/1395 [00:00<00:00, 17342.16it/s]
# 2023-05-14 06:44:22 INFO: Read 1395 trees for evaluation
# 2023-05-14 06:44:22 INFO: Retagging trees using the xpos tags from the default package...
# 100%|███████████████████████████████████████| 1395/1395 [00:31<00:00, 44.12it/s]
# 2023-05-14 06:44:54 INFO: Retagging finished
# 2023-05-14 06:44:54 INFO: Processing 1395 trees from data/constituency/tr_starlang_test.mrg
# 100%|███████████████████████████████████████| 1395/1395 [01:57<00:00, 11.83it/s]
# [main] INFO edu.stanford.nlp.parser.metrics.EvaluateTreebank - Testing on treebank
# [main] INFO edu.stanford.nlp.util.Timing - Testing on treebank done [0.2 sec].
# pcfg LP/LR summary evalb: LP: 75.56 LR: 75.11 F1: 75.33 Exact: 23.72 N: 1395
# dep DA summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 0
# factor LP/LR summary evalb: LP: 75.56 LR: 75.11 F1: 75.33 Exact: 23.72 N: 1395
# factor Tag summary evalb: LP: 0.0 LR: 0.0 F1: 0.0 Exact: 0.0 N: 1395
# 2023-05-14 06:47:01 INFO: F1 score on data/constituency/tr_starlang_test.mrg: 0.753381
# 17985.889305830002
